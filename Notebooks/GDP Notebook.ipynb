# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Load GDP Data into a new Data Frame

# %%
df_gdp = pd.read_csv("../data/GDP Data.csv")
df_gdp.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016          2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10  1.910135e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  9.463542e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527808e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 64 columns]

# %%
df_gdp.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Length: 64, dtype: object

# %% [markdown]
# # 2. Rename columns names

# %%
df_gdp= df_gdp.rename({'Country Name' : 'Country',
               '2017' : 'gdp_2017'},axis=1)

# %%
df_gdp.head()
# Out:
#        Country Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016      gdp_2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10  1.910135e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  9.463542e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527808e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 64 columns]

# %% [markdown]
# # 3. Drop the NaN values

# %%
df_gdp_new = df_gdp[['Country', 'gdp_2017']].copy()
df_gdp_new.dropna(inplace=True)
df_gdp_new.head()
# Out:
#        Country      gdp_2017
# 0        Aruba  3.056425e+09
# 1  Afghanistan  2.019176e+10
# 2       Angola  1.221240e+11
# 3      Albania  1.301969e+10
# 4      Andorra  3.000181e+09

# %% [markdown]
# # 4. Sort values by gdp_2017
# * the values are represented in scientific notation, make sure to pay attention to the power of e

# %%
df_gdp_new.sort_values(by=['gdp_2017'])
# Out:
#                        Country      gdp_2017
# 243                     Tuvalu  4.061925e+07
# 177                      Nauru  1.095859e+08
# 122                   Kiribati  1.872762e+08
# 153           Marshall Islands  2.128810e+08
# 186                      Palau  2.863218e+08
# ..                         ...           ...
# 101           IDA & IBRD total  3.094160e+13
# 196  Post-demographic dividend  4.741500e+13
# 179               OECD members  5.025760e+13
# 93                 High income  5.141610e+13
# 257                      World  8.122920e+13
#
# [249 rows x 2 columns]

# %% [markdown]
# # 5. Load Slavery Index Data into a new Data Frame

# %%
df_slavery = pd.read_csv("../data/clean_slavery_index.csv", header=1)
df_slavery.head()
# Out:
#                    Country   \
# 0                   Eritrea
# 1                   Burundi
# 2  Central African Republic
# 3                Mauritania
# 4               South Sudan
#
#   Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                          4,847,000
# 1                                         10,199,000
# 2                                          4,546,000
# 3                                          4,182,000
# 4                                         11,882,000
#
#    Region  \
# 0  Africa
# 1  Africa
# 2  Africa
# 3  Africa
# 4  Africa
#
#    Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                               93.0
# 1                                               40.0
# 2                                               22.3
# 3                                               21.4
# 4                                               20.5
#
#   Est. number of people in modern slavery  Factor One Governance Issues   \
# 0                                 451,000                           71.0
# 1                                 408,000                           72.4
# 2                                 101,000                           85.4
# 3                                  90,000                           67.3
# 4                                 243,000                           75.7
#
#    Factor Two Nourishment and Access   Factor Three Inequality  \
# 0                                50.6                     33.7
# 1                                42.6                     42.1
# 2                                50.2                     62.7
# 3                                33.7                     39.3
# 4                                51.1                     62.9
#
#    Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                48.1                             25.9  ...
# 1                                48.1                             41.7  ...
# 2                                58.0                             81.6  ...
# 3                                50.5                             22.3  ...
# 4                                56.1                             85.7  ...
#
#    NEG Government  complicity (1.4.3)  \
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
# 3                                -1.0
# 4                                 NaN
#
#    NEG State-imposed forced labour (1.8.1)  Address risk   %.3  Supply chains  \
# 0                                     -1.0           1.5  21.4            0.0
# 1                                     -1.0           1.8  26.2            0.0
# 2                                      0.0           1.5  21.4            0.0
# 3                                      0.0           2.5  35.7            0.0
# 4                                      NaN           NaN   NaN            NaN
#
#    %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0  0.0      1.4     -2.0   -2.0              D
# 1  0.0      5.0     -2.0   10.7              C
# 2  0.0      1.7     -1.0    2.5              D
# 3  0.0      5.3     -1.0   15.5              C
# 4  NaN      NaN      NaN    NaN            NaN
#
# [5 rows x 27 columns]

# %%
df_slavery.columns = df_slavery.columns.str.strip()
df_slavery.columns
# Out:
# Index(['Country',
#        'Population \n(from United Nations Population Division, World Population Prospects)',
#        'Region',
#        'Est. prevalence of population in modern slavery (victims per 1,000 population)',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %% [markdown]
# # 5. Merge Table with the Slavery Index Data

# %%
reunion = pd.merge(df_slavery, df_gdp_new, on="Country" )
reunion
# Out:
#                      Country  \
# 0                    Burundi
# 1   Central African Republic
# 2                 Mauritania
# 3                      Sudan
# 4                       Chad
# 5                     Rwanda
# 6                     Guinea
# 7                      Libya
# 8                    Nigeria
# 9                     Uganda
# 10                Madagascar
# 11                    Malawi
# 12             Guinea-Bissau
# 13                   Liberia
# 14                    Angola
# 15                  Djibouti
# 16                     Kenya
# 17                  Cameroon
# 18                      Togo
# 19                     Niger
# 20                  Zimbabwe
# 21         Equatorial Guinea
# 22                  Ethiopia
# 23                    Zambia
# 24                     Benin
# 25                Mozambique
# 26              Sierra Leone
# 27                     Ghana
# 28                     Gabon
# 29              Burkina Faso
# 30                   Lesotho
# 31                      Mali
# 32                  Botswana
# 33                   Namibia
# 34                   Senegal
# 35              South Africa
# 36                   Algeria
# 37                   Morocco
# 38                   Tunisia
# 39                 Mauritius
# 40                Seychelles
#
#    Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                          10,199,000
# 1                                           4,546,000
# 2                                           4,182,000
# 3                                          38,648,000
# 4                                          14,009,000
# 5                                          11,630,000
# 6                                          12,092,000
# 7                                           6,235,000
# 8                                         181,182,000
# 9                                          40,145,000
# 10                                         24,234,000
# 11                                         17,574,000
# 12                                          1,771,000
# 13                                          4,500,000
# 14                                         27,859,000
# 15                                            927,000
# 16                                         47,236,000
# 17                                         22,835,000
# 18                                          7,417,000
# 19                                         19,897,000
# 20                                         15,777,000
# 21                                          1,175,000
# 22                                         99,873,000
# 23                                         16,101,000
# 24                                         10,576,000
# 25                                         28,011,000
# 26                                          7,237,000
# 27                                         27,583,000
# 28                                          1,930,000
# 29                                         18,111,000
# 30                                          2,175,000
# 31                                         17,468,000
# 32                                          2,209,000
# 33                                          2,426,000
# 34                                         14,977,000
# 35                                         55,291,000
# 36                                         39,872,000
# 37                                         34,803,000
# 38                                         11,274,000
# 39                                          1,259,000
# 40                                             94,000
#
#     Region  \
# 0   Africa
# 1   Africa
# 2   Africa
# 3   Africa
# 4   Africa
# 5   Africa
# 6   Africa
# 7   Africa
# 8   Africa
# 9   Africa
# 10  Africa
# 11  Africa
# 12  Africa
# 13  Africa
# 14  Africa
# 15  Africa
# 16  Africa
# 17  Africa
# 18  Africa
# 19  Africa
# 20  Africa
# 21  Africa
# 22  Africa
# 23  Africa
# 24  Africa
# 25  Africa
# 26  Africa
# 27  Africa
# 28  Africa
# 29  Africa
# 30  Africa
# 31  Africa
# 32  Africa
# 33  Africa
# 34  Africa
# 35  Africa
# 36  Africa
# 37  Africa
# 38  Africa
# 39  Africa
# 40  Africa
#
#     Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                40.0
# 1                                                22.3
# 2                                                21.4
# 3                                                12.0
# 4                                                12.0
# 5                                                11.6
# 6                                                 7.8
# 7                                                 7.7
# 8                                                 7.7
# 9                                                 7.6
# 10                                                7.5
# 11                                                7.5
# 12                                                7.5
# 13                                                7.4
# 14                                                7.2
# 15                                                7.1
# 16                                                6.9
# 17                                                6.9
# 18                                                6.8
# 19                                                6.7
# 20                                                6.7
# 21                                                6.4
# 22                                                6.1
# 23                                                5.7
# 24                                                5.5
# 25                                                5.4
# 26                                                5.0
# 27                                                4.8
# 28                                                4.8
# 29                                                4.5
# 30                                                4.2
# 31                                                3.6
# 32                                                3.4
# 33                                                3.3
# 34                                                2.9
# 35                                                2.8
# 36                                                2.7
# 37                                                2.4
# 38                                                2.2
# 39                                                1.0
# 40                                                NaN
#
#    Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                  408,000                          72.4
# 1                                  101,000                          85.4
# 2                                   90,000                          67.3
# 3                                  465,000                          80.7
# 4                                  168,000                          71.8
# 5                                  134,000                          56.6
# 6                                   94,000                          68.3
# 7                                   48,000                          81.4
# 8                                1,386,000                          54.1
# 9                                  304,000                          52.8
# 10                                 182,000                          54.4
# 11                                 131,000                          55.4
# 12                                  13,000                          77.8
# 13                                  33,000                          55.0
# 14                                 199,000                          60.2
# 15                                   7,000                          66.8
# 16                                 328,000                          55.1
# 17                                 157,000                          65.9
# 18                                  50,000                          70.0
# 19                                 133,000                          61.9
# 20                                 105,000                          66.3
# 21                                   7,000                          68.4
# 22                                 614,000                          62.4
# 23                                  92,000                          45.8
# 24                                  58,000                          51.1
# 25                                 152,000                          48.6
# 26                                  36,000                          50.9
# 27                                 133,000                          52.6
# 28                                   9,000                          56.5
# 29                                  82,000                          58.4
# 30                                   9,000                          53.8
# 31                                  62,000                          55.3
# 32                                   8,000                          43.3
# 33                                   8,000                          44.6
# 34                                  43,000                          43.9
# 35                                 155,000                          46.7
# 36                                 106,000                          63.2
# 37                                  85,000                          60.7
# 38                                  25,000                          47.2
# 39                                   1,000                          25.5
# 40                                     NaN                           NaN
#
#     Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                42.6                     42.1
# 1                                50.2                     62.7
# 2                                33.7                     39.3
# 3                                46.6                     42.4
# 4                                43.2                     48.5
# 5                                40.8                     40.0
# 6                                32.4                     54.7
# 7                                23.0                     49.6
# 8                                41.3                     50.2
# 9                                48.3                     38.2
# 10                               46.8                     51.0
# 11                               51.5                     40.9
# 12                               40.1                     47.6
# 13                               44.0                     44.1
# 14                               43.4                     48.2
# 15                               38.0                     33.9
# 16                               48.7                     49.6
# 17                               36.5                     46.2
# 18                               31.5                     45.3
# 19                               41.2                     37.0
# 20                               45.5                     36.6
# 21                               40.8                     36.7
# 22                               47.5                     27.3
# 23                               54.4                     44.9
# 24                               28.8                     39.9
# 25                               48.3                     40.5
# 26                               46.1                     41.2
# 27                               29.1                     42.0
# 28                               27.1                     36.6
# 29                               31.6                     40.3
# 30                               50.7                     44.6
# 31                               24.4                     35.5
# 32                               37.9                     37.3
# 33                               38.4                     55.9
# 34                               34.8                     35.6
# 35                               38.3                     61.0
# 36                               17.9                     27.8
# 37                               18.8                     38.1
# 38                               15.4                     34.8
# 39                               17.7                     33.6
# 40                                NaN                      NaN
#
#     Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                 48.1                             41.7  ...
# 1                                 58.0                             81.6  ...
# 2                                 50.5                             22.3  ...
# 3                                 37.0                             87.4  ...
# 4                                 46.5                             46.1  ...
# 5                                 55.7                             34.0  ...
# 6                                 46.4                             28.6  ...
# 7                                 28.1                             63.1  ...
# 8                                 47.1                             95.5  ...
# 9                                 50.3                             35.3  ...
# 10                                56.8                             17.3  ...
# 11                                61.5                             19.1  ...
# 12                                44.1                             17.1  ...
# 13                                54.9                             18.2  ...
# 14                                48.5                             19.8  ...
# 15                                48.1                             21.3  ...
# 16                                44.5                             66.8  ...
# 17                                46.3                             53.9  ...
# 18                                42.3                             17.1  ...
# 19                                45.0                             50.4  ...
# 20                                53.0                             25.3  ...
# 21                                48.5                             10.1  ...
# 22                                34.6                             55.3  ...
# 23                                49.1                             13.1  ...
# 24                                35.3                             15.8  ...
# 25                                48.1                             30.0  ...
# 26                                48.1                             18.1  ...
# 27                                53.7                             21.6  ...
# 28                                47.5                             12.4  ...
# 29                                35.2                             26.2  ...
# 30                                41.9                             18.6  ...
# 31                                35.9                             66.3  ...
# 32                                37.6                              9.7  ...
# 33                                38.8                             10.4  ...
# 34                                41.0                             30.9  ...
# 35                                36.9                             26.9  ...
# 36                                37.0                             43.6  ...
# 37                                35.7                             22.0  ...
# 38                                31.9                             33.7  ...
# 39                                31.1                             12.2  ...
# 40                                 NaN                              NaN  ...
#
#     NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                      -1.0           1.8  26.2
# 1                                       0.0           1.5  21.4
# 2                                       0.0           2.5  35.7
# 3                                       0.0           2.3  33.3
# 4                                       0.0           2.8  40.5
# 5                                      -1.0           3.8  54.8
# 6                                       0.0           3.5  50.0
# 7                                      -1.0           0.0   0.0
# 8                                       0.0           3.3  47.6
# 9                                       0.0           3.8  54.8
# 10                                     -1.0           3.5  50.0
# 11                                      0.0           2.3  33.3
# 12                                      0.0           1.5  21.4
# 13                                      0.0           3.5  50.0
# 14                                      0.0           3.8  54.8
# 15                                      0.0           3.3  47.6
# 16                                      0.0           4.2  59.5
# 17                                      0.0           3.5  50.0
# 18                                      0.0           1.5  21.4
# 19                                      0.0           2.5  35.7
# 20                                      0.0           2.5  35.7
# 21                                      0.0           1.8  26.2
# 22                                      0.0           3.3  47.6
# 23                                      0.0           2.8  40.5
# 24                                      0.0           3.7  52.4
# 25                                      0.0           3.0  42.9
# 26                                      0.0           3.8  54.8
# 27                                      0.0           2.8  40.5
# 28                                      0.0           2.3  33.3
# 29                                      0.0           3.0  42.9
# 30                                      0.0           3.0  42.9
# 31                                     -1.0           2.0  28.6
# 32                                      0.0           3.2  45.2
# 33                                      0.0           3.8  54.8
# 34                                      0.0           3.8  54.8
# 35                                      0.0           4.0  57.1
# 36                                      0.0           3.2  45.2
# 37                                      0.0           5.0  71.4
# 38                                      0.0           4.0  57.1
# 39                                      0.0           3.5  50.0
# 40                                      NaN           NaN   NaN
#
#     Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating      gdp_2017
# 0             0.0  0.0      5.0     -2.0   10.7              C  3.172292e+09
# 1             0.0  0.0      1.7     -1.0    2.5              D  2.072350e+09
# 2             0.0  0.0      5.3     -1.0   15.5              C  6.758391e+09
# 3             0.0  0.0      5.2     -1.0   14.9              C  4.537913e+10
# 4             0.0  0.0      5.7     -1.0   16.7              C  1.000040e+10
# 5             0.0  0.0     11.4     -2.0   33.6            CCC  9.253099e+09
# 6             0.0  0.0      6.4     -1.0   19.3              C  1.033663e+10
# 7             0.0  0.0      1.3     -2.0   -2.5              D  3.788324e+10
# 8             0.0  0.0     13.8     -1.0   45.8              B  3.757450e+11
# 9             0.0  0.0     12.8     -1.0   42.0              B  3.075647e+10
# 10            0.0  0.0     10.9     -2.0   31.8            CCC  1.317631e+10
# 11            0.0  0.0      8.5     -1.0   26.8             CC  6.303292e+09
# 12            0.0  0.0      5.3      0.0   18.9              C  1.346842e+09
# 13            0.0  0.0      8.9      0.0   31.7            CCC  3.285455e+09
# 14            0.0  0.0      9.3     -1.0   29.5             CC  1.221240e+11
# 15            0.0  0.0      9.9      0.0   35.3            CCC  2.751461e+09
# 16            0.0  0.0     11.2     -1.0   36.5            CCC  7.896500e+10
# 17            0.0  0.0      8.1     -1.0   25.4             CC  3.500926e+10
# 18            0.0  0.0      6.6      0.0   23.6             CC  4.819950e+09
# 19            0.0  0.0      8.3     -1.0   25.9             CC  1.116606e+10
# 20            0.0  0.0      6.3     -1.0   19.0              C  2.204090e+10
# 21            0.0  0.0      3.4     -1.0    8.6              D  1.220091e+10
# 22            0.0  0.0     11.2     -1.0   36.3            CCC  8.177079e+10
# 23            0.0  0.0      8.9      0.0   31.8            CCC  2.586814e+10
# 24            0.0  0.0     10.6      0.0   37.7            CCC  1.270166e+10
# 25            0.0  0.0     12.4     -1.0   40.7              B  1.321908e+10
# 26            0.0  0.0     13.5      0.0   46.2              B  3.739578e+09
# 27            0.2  8.3      8.7     -1.0   27.6             CC  5.899813e+10
# 28            0.0  0.0      6.8      0.0   24.2             CC  1.492949e+10
# 29            0.0  0.0     10.0      0.0   35.7            CCC  1.416991e+10
# 30            0.0  0.0     10.7      0.0   38.3            CCC  2.405289e+09
# 31            0.0  0.0      9.6     -1.0   30.8            CCC  1.537561e+10
# 32            0.0  0.0     10.3     -1.0   33.2            CCC  1.740554e+10
# 33            0.0  0.0      9.3      0.0   33.3            CCC  1.274175e+10
# 34            0.0  0.0     13.2      0.0   47.1              B  2.099656e+10
# 35            0.0  0.0     14.3     -1.0   47.4              B  3.495540e+11
# 36            0.0  0.0     10.2      0.0   36.3            CCC  1.673890e+11
# 37            0.0  0.0     10.2      0.0   36.5            CCC  1.097140e+11
# 38            0.0  0.0     12.4      0.0   44.3              B  3.980243e+10
# 39            0.0  0.0      9.8      0.0   34.9            CCC  1.325935e+10
# 40            NaN  NaN      NaN      NaN    NaN            NaN  1.524487e+09
#
# [41 rows x 28 columns]
