# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Education Dataset

# %%
#df = pd.read_csv("The Global Dataset 14 Apr 2020.csv",sep=';')
#df = pd.read_excel("education.xlsx")
education = pd.read_csv("..//data/Education_index.csv",sep=';')#, dtype={"2013": float})
education.dtypes
# Out:
# HDI Rank    float64
# Country      object
# 1980         object
# 1985         object
# 1990         object
# 1995         object
# 2000         object
# 2005         object
# 2006         object
# 2007         object
# 2008         object
# 2009         object
# 2010         object
# 2011         object
# 2012         object
# 2013         object
# dtype: object

# %%
education.head()
# Out:
#    HDI Rank      Country         1980         1985         1990         1995  \
# 0     169.0  Afghanistan       0,0761  0,103083333  0,121388889  0,175288889
# 1      95.0      Albania  0,540588889  0,527776677  0,537186688  0,528693858
# 2      93.0      Algeria  0,321377778  0,347177778  0,382388889  0,424366667
# 3      37.0      Andorra           ..           ..           ..           ..
# 4     149.0       Angola           ..           ..           ..           ..
#
#           2000         2005         2006         2007         2008  \
# 0  0,225522222       0,2974  0,308986667  0,320573333      0,33216
# 1  0,565465051   0,59467023  0,596323054  0,597975879  0,599628703
# 2  0,493488889  0,562566667  0,570237778  0,580686667      0,59808
# 3           ..           ..           ..           ..           ..
# 4  0,298712356  0,364684578  0,379923409   0,39516224  0,410401071
#
#           2009         2010         2011         2012         2013
# 0  0,343746667        0,357  0,365333333  0,365333333  0,365333333
# 1  0,600651723  0,601674743  0,608519363  0,608519363  0,608519363
# 2  0,615473333  0,631477778  0,642588889  0,642588889  0,642588889
# 3           ..  0,670286667  0,670286667  0,670286667  0,670286667
# 4  0,425639902  0,440878733  0,474212067  0,474212067  0,474212067

# %%
education=education.replace("..", np.nan)
education
# Out:
#      HDI Rank                             Country         1980         1985  \
# 0       169.0                         Afghanistan       0,0761  0,103083333
# 1        95.0                             Albania  0,540588889  0,527776677
# 2        93.0                             Algeria  0,321377778  0,347177778
# 3        37.0                             Andorra          NaN          NaN
# 4       149.0                              Angola          NaN          NaN
# ..        ...                                 ...          ...          ...
# 190      67.0  Venezuela (Bolivarian Republic of)  0,440501111      0,46065
# 191     121.0                             Vietnam  0,381288889  0,375522222
# 192     154.0                               Yemen          NaN          NaN
# 193     141.0                              Zambia  0,318833333  0,361711111
# 194     156.0                            Zimbabwe  0,288388889  0,449666667
#
#             1990         1995         2000         2005         2006  \
# 0    0,121388889  0,175288889  0,225522222       0,2974  0,308986667
# 1    0,537186688  0,528693858  0,565465051   0,59467023  0,596323054
# 2    0,382388889  0,424366667  0,493488889  0,562566667  0,570237778
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN  0,298712356  0,364684578  0,379923409
# ..           ...          ...          ...          ...          ...
# 190  0,452946667  0,474984444  0,513254544  0,594450532  0,617965815
# 191  0,349122222  0,387388889  0,434455556  0,470388889  0,478175556
# 192  0,218431389  0,229298056  0,257438889  0,304011111  0,306979259
# 193  0,375477778  0,457097917  0,487518056  0,537804861  0,545682222
# 194  0,423122222  0,456855556  0,471333333  0,483266667       0,4866
#
#             2007         2008         2009         2010         2011  \
# 0    0,320573333      0,33216  0,343746667        0,357  0,365333333
# 1    0,597975879  0,599628703  0,600651723  0,601674743  0,608519363
# 2    0,580686667      0,59808  0,615473333  0,631477778  0,642588889
# 3            NaN          NaN          NaN  0,670286667  0,670286667
# 4     0,39516224  0,410401071  0,425639902  0,440878733  0,474212067
# ..           ...          ...          ...          ...          ...
# 190  0,649559434  0,670028665   0,67421609  0,682482617  0,682482617
# 191  0,485962222  0,493748889  0,501535556  0,509322222  0,513488889
# 192  0,309947407  0,312915556  0,320513333  0,328111111  0,339222222
# 193  0,553559583  0,561436944  0,569314306  0,577191667  0,584262361
# 194  0,489933333  0,493266667       0,4966  0,499933333  0,499933333
#
#             2012         2013
# 0    0,365333333  0,365333333
# 1    0,608519363  0,608519363
# 2    0,642588889  0,642588889
# 3    0,670286667  0,670286667
# 4    0,474212067  0,474212067
# ..           ...          ...
# 190  0,682482617  0,682482617
# 191  0,513488889  0,513488889
# 192  0,339222222  0,339222222
# 193  0,591333333  0,591333333
# 194  0,499933333  0,499933333
#
# [195 rows x 16 columns]

# %% [markdown]
# # New Data Frame with selected columns

# %%
newdf= education[["Country","2013"]].copy()
newdf= newdf.replace("..", np.nan)
newdf.dropna(inplace=True)

newdf= newdf.stack().str.replace(',','.').unstack()
print(newdf, newdf.dtypes)
# Out:
#                                 Country         2013
# 0                           Afghanistan  0.365333333
# 1                               Albania  0.608519363
# 2                               Algeria  0.642588889
# 3                               Andorra  0.670286667
# 4                                Angola  0.474212067
# ..                                  ...          ...
# 190  Venezuela (Bolivarian Republic of)  0.682482617
# 191                             Vietnam  0.513488889
# 192                               Yemen  0.339222222
# 193                              Zambia  0.591333333
# 194                            Zimbabwe  0.499933333
#
# [187 rows x 2 columns] Country    object
# 2013       object
# dtype: object

# %%
#newdf["2013"].astype(float)
newdf=newdf.astype({"2013" :float})
newdf.dtypes
# Out:
# Country     object
# 2013       float64
# dtype: object

# %%
newdf.count()
# Out:
# Country    187
# 2013       187
# dtype: int64

# %%
#Reanmae Column
newdf.rename(columns={"2013": "Education_Access_Score"}, inplace=True)

# %%
newdf["Education_Access_Score"] = pd.to_numeric(newdf["Education_Access_Score"])

# %%
newdf.dtypes
# Out:
# Country                    object
# Education_Access_Score    float64
# dtype: object

# %% [markdown]
# # Slavery Index Dataset

# %%
slavery_index = pd.read_csv("..//Data/clean_slavery_index.csv", header=1)

slavery_index
#print(slavery_index.isnull().sum())
# Out:
#                                    Country   \
# 0    Korea, Democratic People's Republic of
# 1                                   Eritrea
# 2                                   Burundi
# 3                  Central African Republic
# 4                               Afghanistan
# ..                                      ...
# 181                                   Malta
# 182                                  Tuvalu
# 183        Saint Vincent and the Grenadines
# 184                                 Vanuatu
# 185                              Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                           25,244,000
# 1                                            4,847,000
# 2                                           10,199,000
# 3                                            4,546,000
# 4                                           33,736,000
# ..                                                 ...
# 181                                            428,000
# 182                                                NaN
# 183                                            109,000
# 184                                            265,000
# 185                                             94,000
#
#                       Region  \
# 0       Asia and the Pacific
# 1                     Africa
# 2                     Africa
# 3                     Africa
# 4       Asia and the Pacific
# ..                       ...
# 181  Europe and Central Asia
# 182     Asia and the Pacific
# 183                 Americas
# 184     Asia and the Pacific
# 185                   Africa
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                104.6
# 1                                                 93.0
# 2                                                 40.0
# 3                                                 22.3
# 4                                                 22.2
# ..                                                 ...
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues   \
# 0                                 2,640,000                           87.6
# 1                                   451,000                           71.0
# 2                                   408,000                           72.4
# 3                                   101,000                           85.4
# 4                                   749,000                           81.0
# ..                                      ...                            ...
# 181                                     NaN                            NaN
# 182                                     NaN                            NaN
# 183                                     NaN                            NaN
# 184                                     NaN                            NaN
# 185                                     NaN                            NaN
#
#      Factor Two Nourishment and Access   Factor Three Inequality  \
# 0                                  52.0                     30.3
# 1                                  50.6                     33.7
# 2                                  42.6                     42.1
# 3                                  50.2                     62.7
# 4                                  41.3                     64.7
# ..                                  ...                      ...
# 181                                 NaN                      NaN
# 182                                 NaN                      NaN
# 183                                 NaN                      NaN
# 184                                 NaN                      NaN
# 185                                 NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  32.4                             12.3  ...
# 1                                  48.1                             25.9  ...
# 2                                  48.1                             41.7  ...
# 3                                  58.0                             81.6  ...
# 4                                  46.0                             92.6  ...
# ..                                  ...                              ...  ...
# 181                                 NaN                              NaN  ...
# 182                                 NaN                              NaN  ...
# 183                                 NaN                              NaN  ...
# 184                                 NaN                              NaN  ...
# 185                                 NaN                              NaN  ...
#
#      NEG Government  complicity (1.4.3)  \
# 0                                  -1.0
# 1                                  -1.0
# 2                                  -1.0
# 3                                  -1.0
# 4                                   NaN
# ..                                  ...
# 181                                 NaN
# 182                                 NaN
# 183                                 NaN
# 184                                 NaN
# 185                                 NaN
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           0.3   4.8
# 1                                       -1.0           1.5  21.4
# 2                                       -1.0           1.8  26.2
# 3                                        0.0           1.5  21.4
# 4                                        NaN           NaN   NaN
# ..                                       ...           ...   ...
# 181                                      NaN           NaN   NaN
# 182                                      NaN           NaN   NaN
# 183                                      NaN           NaN   NaN
# 184                                      NaN           NaN   NaN
# 185                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0              0.0  0.0      0.4     -2.0   -5.6              D
# 1              0.0  0.0      1.4     -2.0   -2.0              D
# 2              0.0  0.0      5.0     -2.0   10.7              C
# 3              0.0  0.0      1.7     -1.0    2.5              D
# 4              NaN  NaN      NaN      NaN    NaN            NaN
# ..             ...  ...      ...      ...    ...            ...
# 181            NaN  NaN      NaN      NaN    NaN            NaN
# 182            NaN  NaN      NaN      NaN    NaN            NaN
# 183            NaN  NaN      NaN      NaN    NaN            NaN
# 184            NaN  NaN      NaN      NaN    NaN            NaN
# 185            NaN  NaN      NaN      NaN    NaN            NaN
#
# [186 rows x 27 columns]

# %% [markdown]
# # Remove white space at the end of string

# %%
slavery_index.columns = slavery_index.columns.str.strip()
slavery_index.columns
# Out:
# Index(['Country',
#        'Population \n(from United Nations Population Division, World Population Prospects)',
#        'Region',
#        'Est. prevalence of population in modern slavery (victims per 1,000 population)',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %%
slavery_index.dtypes
# Out:
# Country                                                                                object
# Population \n(from United Nations Population Division, World Population Prospects)     object
# Region                                                                                 object
# Est. prevalence of population in modern slavery (victims per 1,000 population)        float64
# Est. number of people in modern slavery                                                object
# Factor One Governance Issues                                                          float64
# Factor Two Nourishment and Access                                                     float64
# Factor Three Inequality                                                               float64
# Factor Four Disenfranchised Groups                                                    float64
# Factor Five Effects of Conflict                                                       float64
# Final overall (normalised, weighted) vulnerability score                              float64
# Support survivors                                                                     float64
# %                                                                                     float64
# Criminal justice                                                                      float64
# %.1                                                                                   float64
# Coordination                                                                          float64
# %.2                                                                                   float64
# NEG Government  complicity (1.4.3)                                                    float64
# NEG State-imposed forced labour (1.8.1)                                               float64
# Address risk                                                                          float64
# %.3                                                                                   float64
# Supply chains                                                                         float64
# %.4                                                                                   float64
# SUM/104                                                                               float64
# SUM Neg                                                                               float64
# TOTAL                                                                                 float64
# Credit rating                                                                          object
# dtype: object

# %% [markdown]
# # Rename column

# %%
slavery_index.rename(columns={"Est. prevalence of population in modern slavery (victims per 1,000 population)": "Victims_per_1000_population"}, inplace=True)

# %%
slavery_index
# Out:
#                                     Country  \
# 0    Korea, Democratic People's Republic of
# 1                                   Eritrea
# 2                                   Burundi
# 3                  Central African Republic
# 4                               Afghanistan
# ..                                      ...
# 181                                   Malta
# 182                                  Tuvalu
# 183        Saint Vincent and the Grenadines
# 184                                 Vanuatu
# 185                              Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                           25,244,000
# 1                                            4,847,000
# 2                                           10,199,000
# 3                                            4,546,000
# 4                                           33,736,000
# ..                                                 ...
# 181                                            428,000
# 182                                                NaN
# 183                                            109,000
# 184                                            265,000
# 185                                             94,000
#
#                       Region  Victims_per_1000_population  \
# 0       Asia and the Pacific                        104.6
# 1                     Africa                         93.0
# 2                     Africa                         40.0
# 3                     Africa                         22.3
# 4       Asia and the Pacific                         22.2
# ..                       ...                          ...
# 181  Europe and Central Asia                          NaN
# 182     Asia and the Pacific                          NaN
# 183                 Americas                          NaN
# 184     Asia and the Pacific                          NaN
# 185                   Africa                          NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                 2,640,000                          87.6
# 1                                   451,000                          71.0
# 2                                   408,000                          72.4
# 3                                   101,000                          85.4
# 4                                   749,000                          81.0
# ..                                      ...                           ...
# 181                                     NaN                           NaN
# 182                                     NaN                           NaN
# 183                                     NaN                           NaN
# 184                                     NaN                           NaN
# 185                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 52.0                     30.3
# 1                                 50.6                     33.7
# 2                                 42.6                     42.1
# 3                                 50.2                     62.7
# 4                                 41.3                     64.7
# ..                                 ...                      ...
# 181                                NaN                      NaN
# 182                                NaN                      NaN
# 183                                NaN                      NaN
# 184                                NaN                      NaN
# 185                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  32.4                             12.3  ...
# 1                                  48.1                             25.9  ...
# 2                                  48.1                             41.7  ...
# 3                                  58.0                             81.6  ...
# 4                                  46.0                             92.6  ...
# ..                                  ...                              ...  ...
# 181                                 NaN                              NaN  ...
# 182                                 NaN                              NaN  ...
# 183                                 NaN                              NaN  ...
# 184                                 NaN                              NaN  ...
# 185                                 NaN                              NaN  ...
#
#      NEG Government  complicity (1.4.3)  \
# 0                                  -1.0
# 1                                  -1.0
# 2                                  -1.0
# 3                                  -1.0
# 4                                   NaN
# ..                                  ...
# 181                                 NaN
# 182                                 NaN
# 183                                 NaN
# 184                                 NaN
# 185                                 NaN
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           0.3   4.8
# 1                                       -1.0           1.5  21.4
# 2                                       -1.0           1.8  26.2
# 3                                        0.0           1.5  21.4
# 4                                        NaN           NaN   NaN
# ..                                       ...           ...   ...
# 181                                      NaN           NaN   NaN
# 182                                      NaN           NaN   NaN
# 183                                      NaN           NaN   NaN
# 184                                      NaN           NaN   NaN
# 185                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0              0.0  0.0      0.4     -2.0   -5.6              D
# 1              0.0  0.0      1.4     -2.0   -2.0              D
# 2              0.0  0.0      5.0     -2.0   10.7              C
# 3              0.0  0.0      1.7     -1.0    2.5              D
# 4              NaN  NaN      NaN      NaN    NaN            NaN
# ..             ...  ...      ...      ...    ...            ...
# 181            NaN  NaN      NaN      NaN    NaN            NaN
# 182            NaN  NaN      NaN      NaN    NaN            NaN
# 183            NaN  NaN      NaN      NaN    NaN            NaN
# 184            NaN  NaN      NaN      NaN    NaN            NaN
# 185            NaN  NaN      NaN      NaN    NaN            NaN
#
# [186 rows x 27 columns]

# %%
#slavery_index["Est. number of people in modern slavery"] = pd.to_numeric(slavery_index["Est. number of people in modern slavery"])

# %%
#slavery_index.loc[pd.to_numeric(slavery_index["Est. number of people in modern slavery"], errors='coerce').isnull()]

# %% [markdown]
# # Merge `Slavery Index` with `Education` table

# %%
merged= pd.merge(slavery_index, newdf, on="Country" )
merged
# Out:
#                               Country  \
# 0                             Eritrea
# 1                             Burundi
# 2            Central African Republic
# 3                         Afghanistan
# 4                          Mauritania
# ..                                ...
# 163                       Saint Lucia
# 164                             Malta
# 165  Saint Vincent and the Grenadines
# 166                           Vanuatu
# 167                        Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                            4,847,000
# 1                                           10,199,000
# 2                                            4,546,000
# 3                                           33,736,000
# 4                                            4,182,000
# ..                                                 ...
# 163                                            177,000
# 164                                            428,000
# 165                                            109,000
# 166                                            265,000
# 167                                             94,000
#
#                       Region  Victims_per_1000_population  \
# 0                     Africa                         93.0
# 1                     Africa                         40.0
# 2                     Africa                         22.3
# 3       Asia and the Pacific                         22.2
# 4                     Africa                         21.4
# ..                       ...                          ...
# 163                 Americas                          NaN
# 164  Europe and Central Asia                          NaN
# 165                 Americas                          NaN
# 166     Asia and the Pacific                          NaN
# 167                   Africa                          NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   451,000                          71.0
# 1                                   408,000                          72.4
# 2                                   101,000                          85.4
# 3                                   749,000                          81.0
# 4                                    90,000                          67.3
# ..                                      ...                           ...
# 163                                     NaN                           NaN
# 164                                     NaN                           NaN
# 165                                     NaN                           NaN
# 166                                     NaN                           NaN
# 167                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 50.6                     33.7
# 1                                 42.6                     42.1
# 2                                 50.2                     62.7
# 3                                 41.3                     64.7
# 4                                 33.7                     39.3
# ..                                 ...                      ...
# 163                                NaN                      NaN
# 164                                NaN                      NaN
# 165                                NaN                      NaN
# 166                                NaN                      NaN
# 167                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             25.9  ...
# 1                                  48.1                             41.7  ...
# 2                                  58.0                             81.6  ...
# 3                                  46.0                             92.6  ...
# 4                                  50.5                             22.3  ...
# ..                                  ...                              ...  ...
# 163                                 NaN                              NaN  ...
# 164                                 NaN                              NaN  ...
# 165                                 NaN                              NaN  ...
# 166                                 NaN                              NaN  ...
# 167                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.5  21.4
# 1                                       -1.0           1.8  26.2
# 2                                        0.0           1.5  21.4
# 3                                        NaN           NaN   NaN
# 4                                        0.0           2.5  35.7
# ..                                       ...           ...   ...
# 163                                      NaN           NaN   NaN
# 164                                      NaN           NaN   NaN
# 165                                      NaN           NaN   NaN
# 166                                      NaN           NaN   NaN
# 167                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating  \
# 0              0.0  0.0      1.4     -2.0   -2.0              D
# 1              0.0  0.0      5.0     -2.0   10.7              C
# 2              0.0  0.0      1.7     -1.0    2.5              D
# 3              NaN  NaN      NaN      NaN    NaN            NaN
# 4              0.0  0.0      5.3     -1.0   15.5              C
# ..             ...  ...      ...      ...    ...            ...
# 163            NaN  NaN      NaN      NaN    NaN            NaN
# 164            NaN  NaN      NaN      NaN    NaN            NaN
# 165            NaN  NaN      NaN      NaN    NaN            NaN
# 166            NaN  NaN      NaN      NaN    NaN            NaN
# 167            NaN  NaN      NaN      NaN    NaN            NaN
#
#      Education_Access_Score
# 0                  0.227514
# 1                  0.370089
# 2                  0.317867
# 3                  0.365333
# 4                  0.352278
# ..                      ...
# 163                0.631431
# 164                0.732538
# 165                0.656834
# 166                0.595511
# 167                0.635929
#
# [168 rows x 28 columns]

# %%
merged.head(25
           )
# Out:
#                              Country  \
# 0                            Eritrea
# 1                            Burundi
# 2           Central African Republic
# 3                        Afghanistan
# 4                         Mauritania
# 5                           Pakistan
# 6                           Cambodia
# 7                           Mongolia
# 8                              Sudan
# 9                               Chad
# 10                            Rwanda
# 11                      Turkmenistan
# 12                           Myanmar
# 13                 Brunei Darussalam
# 14                           Belarus
# 15                  Papua New Guinea
# 16  Lao People's Democratic Republic
# 17                          Thailand
# 18                         Swaziland
# 19                             Congo
# 20                            Greece
# 21                            Guinea
# 22                             Libya
# 23                       Philippines
# 24                       Timor-Leste
#
#    Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                           4,847,000
# 1                                          10,199,000
# 2                                           4,546,000
# 3                                          33,736,000
# 4                                           4,182,000
# 5                                         189,381,000
# 6                                          15,518,000
# 7                                           2,977,000
# 8                                          38,648,000
# 9                                          14,009,000
# 10                                         11,630,000
# 11                                          5,565,000
# 12                                         52,404,000
# 13                                            418,000
# 14                                          9,486,000
# 15                                          7,920,000
# 16                                          6,664,000
# 17                                         68,658,000
# 18                                          1,319,000
# 19                                          4,996,000
# 20                                         11,218,000
# 21                                         12,092,000
# 22                                          6,235,000
# 23                                        101,716,000
# 24                                          1,241,000
#
#                      Region  Victims_per_1000_population  \
# 0                    Africa                         93.0
# 1                    Africa                         40.0
# 2                    Africa                         22.3
# 3      Asia and the Pacific                         22.2
# 4                    Africa                         21.4
# 5      Asia and the Pacific                         16.8
# 6      Asia and the Pacific                         16.8
# 7      Asia and the Pacific                         12.3
# 8                    Africa                         12.0
# 9                    Africa                         12.0
# 10                   Africa                         11.6
# 11  Europe and Central Asia                         11.2
# 12     Asia and the Pacific                         11.0
# 13     Asia and the Pacific                         10.9
# 14  Europe and Central Asia                         10.9
# 15     Asia and the Pacific                         10.3
# 16     Asia and the Pacific                          9.4
# 17     Asia and the Pacific                          8.9
# 18                   Africa                          8.8
# 19                   Africa                          8.0
# 20  Europe and Central Asia                          7.9
# 21                   Africa                          7.8
# 22                   Africa                          7.7
# 23     Asia and the Pacific                          7.7
# 24     Asia and the Pacific                          7.7
#
#    Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                  451,000                          71.0
# 1                                  408,000                          72.4
# 2                                  101,000                          85.4
# 3                                  749,000                          81.0
# 4                                   90,000                          67.3
# 5                                3,186,000                          56.8
# 6                                  261,000                          66.3
# 7                                   37,000                          40.9
# 8                                  465,000                          80.7
# 9                                  168,000                          71.8
# 10                                 134,000                          56.6
# 11                                  62,000                          80.2
# 12                                 575,000                          58.1
# 13                                   5,000                          53.5
# 14                                 103,000                          64.9
# 15                                  81,000                          64.8
# 16                                  62,000                          70.7
# 17                                 610,000                          50.9
# 18                                  12,000                          69.9
# 19                                  40,000                          75.1
# 20                                  89,000                          38.5
# 21                                  94,000                          68.3
# 22                                  48,000                          81.4
# 23                                 784,000                          50.5
# 24                                  10,000                          58.4
#
#     Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                50.6                     33.7
# 1                                42.6                     42.1
# 2                                50.2                     62.7
# 3                                41.3                     64.7
# 4                                33.7                     39.3
# 5                                36.2                     45.9
# 6                                38.5                     41.6
# 7                                36.8                     35.1
# 8                                46.6                     42.4
# 9                                43.2                     48.5
# 10                               40.8                     40.0
# 11                               21.5                     31.4
# 12                               43.8                     26.1
# 13                               30.9                     31.7
# 14                               16.7                     23.9
# 15                               63.3                     46.2
# 16                               35.1                     26.4
# 17                               21.8                     35.3
# 18                               50.0                     39.4
# 19                               37.6                     48.5
# 20                               14.4                     36.4
# 21                               32.4                     54.7
# 22                               23.0                     49.6
# 23                               35.3                     45.7
# 24                               41.9                     37.2
#
#     Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                 48.1                             25.9  ...
# 1                                 48.1                             41.7  ...
# 2                                 58.0                             81.6  ...
# 3                                 46.0                             92.6  ...
# 4                                 50.5                             22.3  ...
# 5                                 55.3                             92.8  ...
# 6                                 56.7                             14.8  ...
# 7                                 47.1                             18.1  ...
# 8                                 37.0                             87.4  ...
# 9                                 46.5                             46.1  ...
# 10                                55.7                             34.0  ...
# 11                                32.6                             15.9  ...
# 12                                46.0                             70.2  ...
# 13                                41.2                             18.2  ...
# 14                                39.4                             20.8  ...
# 15                                 9.5                             13.3  ...
# 16                                41.2                             13.9  ...
# 17                                45.1                             51.9  ...
# 18                                38.8                             11.7  ...
# 19                                46.1                             19.6  ...
# 20                                56.0                             23.6  ...
# 21                                46.4                             28.6  ...
# 22                                28.1                             63.1  ...
# 23                                36.4                             69.3  ...
# 24                                41.2                              3.9  ...
#
#     NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                      -1.0           1.5  21.4
# 1                                      -1.0           1.8  26.2
# 2                                       0.0           1.5  21.4
# 3                                       NaN           NaN   NaN
# 4                                       0.0           2.5  35.7
# 5                                       0.0           2.8  40.5
# 6                                       0.0           2.3  33.3
# 7                                      -1.0           3.8  54.8
# 8                                       0.0           2.3  33.3
# 9                                       0.0           2.8  40.5
# 10                                     -1.0           3.8  54.8
# 11                                     -1.0           4.3  61.9
# 12                                     -1.0           3.0  42.9
# 13                                      0.0           3.0  42.9
# 14                                     -1.0           4.7  66.7
# 15                                      0.0           1.8  26.2
# 16                                      0.0           2.8  40.5
# 17                                      0.0           5.2  73.8
# 18                                     -1.0           3.3  47.6
# 19                                      0.0           3.0  42.9
# 20                                      0.0           3.2  45.2
# 21                                      0.0           3.5  50.0
# 22                                     -1.0           0.0   0.0
# 23                                      0.0           4.8  69.0
# 24                                      0.0           3.0  42.9
#
#     Supply chains   %.4  SUM/104  SUM Neg  TOTAL  Credit rating  \
# 0             0.0   0.0      1.4     -2.0   -2.0              D
# 1             0.0   0.0      5.0     -2.0   10.7              C
# 2             0.0   0.0      1.7     -1.0    2.5              D
# 3             NaN   NaN      NaN      NaN    NaN            NaN
# 4             0.0   0.0      5.3     -1.0   15.5              C
# 5             0.0   0.0      6.2     -1.0   18.6              C
# 6             0.0   0.0     10.5      0.0   37.6            CCC
# 7             0.0   0.0      9.6     -1.0   30.7            CCC
# 8             0.0   0.0      5.2     -1.0   14.9              C
# 9             0.0   0.0      5.7     -1.0   16.7              C
# 10            0.0   0.0     11.4     -2.0   33.6            CCC
# 11            0.0   0.0      9.6     -2.0   27.1             CC
# 12            0.0   0.0     11.1     -2.0   32.4            CCC
# 13            0.0   0.0      5.8      0.0   20.6             CC
# 14            0.0   0.0     12.2     -1.0   40.1              B
# 15            0.0   0.0      6.3     -1.0   18.9              C
# 16            0.0   0.0     10.5     -1.0   34.0            CCC
# 17            0.0   0.0     14.7     -1.0   48.9              B
# 18            0.0   0.0      9.2     -1.0   29.3             CC
# 19            0.0   0.0      5.2     -1.0   14.8              C
# 20            0.4  18.3     15.4      0.0   55.1             BB
# 21            0.0   0.0      6.4     -1.0   19.3              C
# 22            0.0   0.0      1.3     -2.0   -2.5              D
# 23            0.0   0.0     15.6      0.0   55.8             BB
# 24            0.0   0.0      8.0      0.0   28.5             CC
#
#     Education_Access_Score
# 0                 0.227514
# 1                 0.370089
# 2                 0.317867
# 3                 0.365333
# 4                 0.352278
# 5                 0.371667
# 6                 0.495178
# 7                 0.693667
# 8                 0.305956
# 9                 0.255852
# 10                0.478167
# 11                0.678713
# 12                0.370556
# 13                0.692111
# 14                0.819984
# 15                0.376311
# 16                0.435867
# 17                0.607965
# 18                0.551289
# 19                0.511333
# 20                0.796989
# 21                0.294445
# 22                0.697889
# 23                0.609984
# 24                0.472407
#
# [25 rows x 28 columns]

# %%
merged.corr()
# Out:
#                                                     Victims_per_1000_population  \
# Victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.379444
# Factor Two Nourishment and Access                                      0.423225
# Factor Three Inequality                                                0.111686
# Factor Four Disenfranchised Groups                                     0.294802
# Factor Five Effects of Conflict                                        0.197003
# Final overall (normalised, weighted) vulnerabil...                     0.406846
# Support survivors                                                     -0.377257
# %                                                                     -0.376439
# Criminal justice                                                      -0.392226
# %.1                                                                   -0.391494
# Coordination                                                          -0.365449
# %.2                                                                   -0.364524
# NEG Government  complicity (1.4.3)                                    -0.234737
# NEG State-imposed forced labour (1.8.1)                               -0.355021
# Address risk                                                          -0.370284
# %.3                                                                   -0.369202
# Supply chains                                                         -0.159504
# %.4                                                                   -0.157498
# SUM/104                                                               -0.441590
# SUM Neg                                                               -0.363597
# TOTAL                                                                 -0.465029
# Education_Access_Score                                                -0.416617
#
#                                                     Factor One Governance Issues  \
# Victims_per_1000_population                                             0.379444
# Factor One Governance Issues                                            1.000000
# Factor Two Nourishment and Access                                       0.595208
# Factor Three Inequality                                                 0.502648
# Factor Four Disenfranchised Groups                                      0.468657
# Factor Five Effects of Conflict                                         0.460542
# Final overall (normalised, weighted) vulnerabil...                      0.929781
# Support survivors                                                      -0.718463
# %                                                                      -0.719307
# Criminal justice                                                       -0.643288
# %.1                                                                    -0.644600
# Coordination                                                           -0.593959
# %.2                                                                    -0.594188
# NEG Government  complicity (1.4.3)                                     -0.444631
# NEG State-imposed forced labour (1.8.1)                                -0.267512
# Address risk                                                           -0.658122
# %.3                                                                    -0.656610
# Supply chains                                                          -0.573796
# %.4                                                                    -0.561784
# SUM/104                                                                -0.794816
# SUM Neg                                                                -0.483502
# TOTAL                                                                  -0.814466
# Education_Access_Score                                                 -0.733245
#
#                                                     Factor Two Nourishment and Access  \
# Victims_per_1000_population                                                  0.423225
# Factor One Governance Issues                                                 0.595208
# Factor Two Nourishment and Access                                            1.000000
# Factor Three Inequality                                                      0.374382
# Factor Four Disenfranchised Groups                                           0.416182
# Factor Five Effects of Conflict                                              0.327446
# Final overall (normalised, weighted) vulnerabil...                           0.736855
# Support survivors                                                           -0.481210
# %                                                                           -0.480159
# Criminal justice                                                            -0.439673
# %.1                                                                         -0.439634
# Coordination                                                                -0.440369
# %.2                                                                         -0.442043
# NEG Government  complicity (1.4.3)                                          -0.345587
# NEG State-imposed forced labour (1.8.1)                                     -0.106736
# Address risk                                                                -0.523452
# %.3                                                                         -0.518601
# Supply chains                                                               -0.395159
# %.4                                                                         -0.385736
# SUM/104                                                                     -0.563055
# SUM Neg                                                                     -0.324523
# TOTAL                                                                       -0.575496
# Education_Access_Score                                                      -0.779522
#
#                                                     Factor Three Inequality  \
# Victims_per_1000_population                                        0.111686
# Factor One Governance Issues                                       0.502648
# Factor Two Nourishment and Access                                  0.374382
# Factor Three Inequality                                            1.000000
# Factor Four Disenfranchised Groups                                 0.436054
# Factor Five Effects of Conflict                                    0.372882
# Final overall (normalised, weighted) vulnerabil...                 0.649680
# Support survivors                                                 -0.278501
# %                                                                 -0.280180
# Criminal justice                                                  -0.251601
# %.1                                                               -0.250351
# Coordination                                                      -0.271686
# %.2                                                               -0.268109
# NEG Government  complicity (1.4.3)                                -0.284602
# NEG State-imposed forced labour (1.8.1)                            0.001839
# Address risk                                                      -0.182037
# %.3                                                               -0.179726
# Supply chains                                                     -0.318625
# %.4                                                               -0.303547
# SUM/104                                                           -0.298557
# SUM Neg                                                           -0.221779
# TOTAL                                                             -0.312195
# Education_Access_Score                                            -0.485061
#
#                                                     Factor Four Disenfranchised Groups  \
# Victims_per_1000_population                                                   0.294802
# Factor One Governance Issues                                                  0.468657
# Factor Two Nourishment and Access                                             0.416182
# Factor Three Inequality                                                       0.436054
# Factor Four Disenfranchised Groups                                            1.000000
# Factor Five Effects of Conflict                                               0.232622
# Final overall (normalised, weighted) vulnerabil...                            0.613947
# Support survivors                                                            -0.289656
# %                                                                            -0.289535
# Criminal justice                                                             -0.312353
# %.1                                                                          -0.314049
# Coordination                                                                 -0.274764
# %.2                                                                          -0.278307
# NEG Government  complicity (1.4.3)                                           -0.151045
# NEG State-imposed forced labour (1.8.1)                                      -0.041067
# Address risk                                                                 -0.301425
# %.3                                                                          -0.297696
# Supply chains                                                                -0.269741
# %.4                                                                          -0.279464
# SUM/104                                                                      -0.352921
# SUM Neg                                                                      -0.139008
# TOTAL                                                                        -0.351394
# Education_Access_Score                                                       -0.449591
#
#                                                     Factor Five Effects of Conflict  \
# Victims_per_1000_population                                                0.197003
# Factor One Governance Issues                                               0.460542
# Factor Two Nourishment and Access                                          0.327446
# Factor Three Inequality                                                    0.372882
# Factor Four Disenfranchised Groups                                         0.232622
# Factor Five Effects of Conflict                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                         0.630298
# Support survivors                                                         -0.211623
# %                                                                         -0.211027
# Criminal justice                                                          -0.147979
# %.1                                                                       -0.145110
# Coordination                                                              -0.111431
# %.2                                                                       -0.106631
# NEG Government  complicity (1.4.3)                                        -0.360252
# NEG State-imposed forced labour (1.8.1)                                   -0.213621
# Address risk                                                              -0.254158
# %.3                                                                       -0.253146
# Supply chains                                                             -0.217195
# %.4                                                                       -0.206653
# SUM/104                                                                   -0.228068
# SUM Neg                                                                   -0.390164
# TOTAL                                                                     -0.268848
# Education_Access_Score                                                    -0.410084
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# Victims_per_1000_population                                                                  0.406846
# Factor One Governance Issues                                                                 0.929781
# Factor Two Nourishment and Access                                                            0.736855
# Factor Three Inequality                                                                      0.649680
# Factor Four Disenfranchised Groups                                                           0.613947
# Factor Five Effects of Conflict                                                              0.630298
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# Support survivors                                                                           -0.651196
# %                                                                                           -0.651541
# Criminal justice                                                                            -0.585350
# %.1                                                                                         -0.585601
# Coordination                                                                                -0.546765
# %.2                                                                                         -0.546344
# NEG Government  complicity (1.4.3)                                                          -0.471877
# NEG State-imposed forced labour (1.8.1)                                                     -0.227035
# Address risk                                                                                -0.622873
# %.3                                                                                         -0.619768
# Supply chains                                                                               -0.551788
# %.4                                                                                         -0.539987
# SUM/104                                                                                     -0.729949
# SUM Neg                                                                                     -0.484311
# TOTAL                                                                                       -0.754005
# Education_Access_Score                                                                      -0.804421
#
#                                                     Support survivors  \
# Victims_per_1000_population                                 -0.377257
# Factor One Governance Issues                                -0.718463
# Factor Two Nourishment and Access                           -0.481210
# Factor Three Inequality                                     -0.278501
# Factor Four Disenfranchised Groups                          -0.289656
# Factor Five Effects of Conflict                             -0.211623
# Final overall (normalised, weighted) vulnerabil...          -0.651196
# Support survivors                                            1.000000
# %                                                            0.999876
# Criminal justice                                             0.710247
# %.1                                                          0.712385
# Coordination                                                 0.577469
# %.2                                                          0.576801
# NEG Government  complicity (1.4.3)                           0.315491
# NEG State-imposed forced labour (1.8.1)                      0.185547
# Address risk                                                 0.571494
# %.3                                                          0.570977
# Supply chains                                                0.423228
# %.4                                                          0.422001
# SUM/104                                                      0.897757
# SUM Neg                                                      0.340910
# TOTAL                                                        0.890594
# Education_Access_Score                                       0.595888
#
#                                                            %  \
# Victims_per_1000_population                        -0.376439
# Factor One Governance Issues                       -0.719307
# Factor Two Nourishment and Access                  -0.480159
# Factor Three Inequality                            -0.280180
# Factor Four Disenfranchised Groups                 -0.289535
# Factor Five Effects of Conflict                    -0.211027
# Final overall (normalised, weighted) vulnerabil... -0.651541
# Support survivors                                   0.999876
# %                                                   1.000000
# Criminal justice                                    0.710026
# %.1                                                 0.712154
# Coordination                                        0.577449
# %.2                                                 0.576822
# NEG Government  complicity (1.4.3)                  0.315203
# NEG State-imposed forced labour (1.8.1)             0.183192
# Address risk                                        0.572400
# %.3                                                 0.571926
# Supply chains                                       0.424052
# %.4                                                 0.422626
# SUM/104                                             0.898056
# SUM Neg                                             0.339491
# TOTAL                                               0.890667
# Education_Access_Score                              0.596111
#
#                                                     Criminal justice  ...  \
# Victims_per_1000_population                                -0.392226  ...
# Factor One Governance Issues                               -0.643288  ...
# Factor Two Nourishment and Access                          -0.439673  ...
# Factor Three Inequality                                    -0.251601  ...
# Factor Four Disenfranchised Groups                         -0.312353  ...
# Factor Five Effects of Conflict                            -0.147979  ...
# Final overall (normalised, weighted) vulnerabil...         -0.585350  ...
# Support survivors                                           0.710247  ...
# %                                                           0.710026  ...
# Criminal justice                                            1.000000  ...
# %.1                                                         0.999653  ...
# Coordination                                                0.586818  ...
# %.2                                                         0.586714  ...
# NEG Government  complicity (1.4.3)                          0.221510  ...
# NEG State-imposed forced labour (1.8.1)                     0.231919  ...
# Address risk                                                0.612633  ...
# %.3                                                         0.612278  ...
# Supply chains                                               0.392304  ...
# %.4                                                         0.390696  ...
# SUM/104                                                     0.863833  ...
# SUM Neg                                                     0.290865  ...
# TOTAL                                                       0.852355  ...
# Education_Access_Score                                      0.544045  ...
#
#                                                     NEG Government  complicity (1.4.3)  \
# Victims_per_1000_population                                                  -0.234737
# Factor One Governance Issues                                                 -0.444631
# Factor Two Nourishment and Access                                            -0.345587
# Factor Three Inequality                                                      -0.284602
# Factor Four Disenfranchised Groups                                           -0.151045
# Factor Five Effects of Conflict                                              -0.360252
# Final overall (normalised, weighted) vulnerabil...                           -0.471877
# Support survivors                                                             0.315491
# %                                                                             0.315203
# Criminal justice                                                              0.221510
# %.1                                                                           0.218370
# Coordination                                                                  0.333867
# %.2                                                                           0.331330
# NEG Government  complicity (1.4.3)                                            1.000000
# NEG State-imposed forced labour (1.8.1)                                       0.164971
# Address risk                                                                  0.278687
# %.3                                                                           0.277820
# Supply chains                                                                 0.285842
# %.4                                                                           0.277685
# SUM/104                                                                       0.343359
# SUM Neg                                                                       0.866136
# TOTAL                                                                         0.444153
# Education_Access_Score                                                        0.339317
#
#                                                     NEG State-imposed forced labour (1.8.1)  \
# Victims_per_1000_population                                                       -0.355021
# Factor One Governance Issues                                                      -0.267512
# Factor Two Nourishment and Access                                                 -0.106736
# Factor Three Inequality                                                            0.001839
# Factor Four Disenfranchised Groups                                                -0.041067
# Factor Five Effects of Conflict                                                   -0.213621
# Final overall (normalised, weighted) vulnerabil...                                -0.227035
# Support survivors                                                                  0.185547
# %                                                                                  0.183192
# Criminal justice                                                                   0.231919
# %.1                                                                                0.230707
# Coordination                                                                       0.164576
# %.2                                                                                0.164407
# NEG Government  complicity (1.4.3)                                                 0.164971
# NEG State-imposed forced labour (1.8.1)                                            1.000000
# Address risk                                                                       0.146865
# %.3                                                                                0.146013
# Supply chains                                                                     -0.007212
# %.4                                                                               -0.011222
# SUM/104                                                                            0.210349
# SUM Neg                                                                            0.635848
# TOTAL                                                                              0.286018
# Education_Access_Score                                                             0.096140
#
#                                                     Address risk       %.3  \
# Victims_per_1000_population                            -0.370284 -0.369202
# Factor One Governance Issues                           -0.658122 -0.656610
# Factor Two Nourishment and Access                      -0.523452 -0.518601
# Factor Three Inequality                                -0.182037 -0.179726
# Factor Four Disenfranchised Groups                     -0.301425 -0.297696
# Factor Five Effects of Conflict                        -0.254158 -0.253146
# Final overall (normalised, weighted) vulnerabil...     -0.622873 -0.619768
# Support survivors                                       0.571494  0.570977
# %                                                       0.572400  0.571926
# Criminal justice                                        0.612633  0.612278
# %.1                                                     0.613075  0.612731
# Coordination                                            0.561575  0.561523
# %.2                                                     0.562687  0.562642
# NEG Government  complicity (1.4.3)                      0.278687  0.277820
# NEG State-imposed forced labour (1.8.1)                 0.146865  0.146013
# Address risk                                            1.000000  0.999745
# %.3                                                     0.999745  1.000000
# Supply chains                                           0.372106  0.369387
# %.4                                                     0.371305  0.368495
# SUM/104                                                 0.805265  0.804930
# SUM Neg                                                 0.292507  0.291397
# TOTAL                                                   0.796952  0.796452
# Education_Access_Score                                  0.559672  0.556106
#
#                                                     Supply chains       %.4  \
# Victims_per_1000_population                             -0.159504 -0.157498
# Factor One Governance Issues                            -0.573796 -0.561784
# Factor Two Nourishment and Access                       -0.395159 -0.385736
# Factor Three Inequality                                 -0.318625 -0.303547
# Factor Four Disenfranchised Groups                      -0.269741 -0.279464
# Factor Five Effects of Conflict                         -0.217195 -0.206653
# Final overall (normalised, weighted) vulnerabil...      -0.551788 -0.539987
# Support survivors                                        0.423228  0.422001
# %                                                        0.424052  0.422626
# Criminal justice                                         0.392304  0.390696
# %.1                                                      0.393951  0.392812
# Coordination                                             0.464809  0.456012
# %.2                                                      0.464161  0.455811
# NEG Government  complicity (1.4.3)                       0.285842  0.277685
# NEG State-imposed forced labour (1.8.1)                 -0.007212 -0.011222
# Address risk                                             0.372106  0.371305
# %.3                                                      0.369387  0.368495
# Supply chains                                            1.000000  0.997488
# %.4                                                      0.997488  1.000000
# SUM/104                                                  0.520516  0.518007
# SUM Neg                                                  0.220027  0.211612
# TOTAL                                                    0.519543  0.515909
# Education_Access_Score                                   0.506888  0.496392
#
#                                                      SUM/104   SUM Neg  \
# Victims_per_1000_population                        -0.441590 -0.363597
# Factor One Governance Issues                       -0.794816 -0.483502
# Factor Two Nourishment and Access                  -0.563055 -0.324523
# Factor Three Inequality                            -0.298557 -0.221779
# Factor Four Disenfranchised Groups                 -0.352921 -0.139008
# Factor Five Effects of Conflict                    -0.228068 -0.390164
# Final overall (normalised, weighted) vulnerabil... -0.729949 -0.484311
# Support survivors                                   0.897757  0.340910
# %                                                   0.898056  0.339491
# Criminal justice                                    0.863833  0.290865
# %.1                                                 0.865420  0.287794
# Coordination                                        0.763327  0.344662
# %.2                                                 0.763514  0.342592
# NEG Government  complicity (1.4.3)                  0.343359  0.866136
# NEG State-imposed forced labour (1.8.1)             0.210349  0.635848
# Address risk                                        0.805265  0.292507
# %.3                                                 0.804930  0.291397
# Supply chains                                       0.520516  0.220027
# %.4                                                 0.518007  0.211612
# SUM/104                                             1.000000  0.375285
# SUM Neg                                             0.375285  1.000000
# TOTAL                                               0.991451  0.492506
# Education_Access_Score                              0.657073  0.314247
#
#                                                        TOTAL  \
# Victims_per_1000_population                        -0.465029
# Factor One Governance Issues                       -0.814466
# Factor Two Nourishment and Access                  -0.575496
# Factor Three Inequality                            -0.312195
# Factor Four Disenfranchised Groups                 -0.351394
# Factor Five Effects of Conflict                    -0.268848
# Final overall (normalised, weighted) vulnerabil... -0.754005
# Support survivors                                   0.890594
# %                                                   0.890667
# Criminal justice                                    0.852355
# %.1                                                 0.853403
# Coordination                                        0.765316
# %.2                                                 0.765159
# NEG Government  complicity (1.4.3)                  0.444153
# NEG State-imposed forced labour (1.8.1)             0.286018
# Address risk                                        0.796952
# %.3                                                 0.796452
# Supply chains                                       0.519543
# %.4                                                 0.515909
# SUM/104                                             0.991451
# SUM Neg                                             0.492506
# TOTAL                                               1.000000
# Education_Access_Score                              0.662586
#
#                                                     Education_Access_Score
# Victims_per_1000_population                                      -0.416617
# Factor One Governance Issues                                     -0.733245
# Factor Two Nourishment and Access                                -0.779522
# Factor Three Inequality                                          -0.485061
# Factor Four Disenfranchised Groups                               -0.449591
# Factor Five Effects of Conflict                                  -0.410084
# Final overall (normalised, weighted) vulnerabil...               -0.804421
# Support survivors                                                 0.595888
# %                                                                 0.596111
# Criminal justice                                                  0.544045
# %.1                                                               0.543130
# Coordination                                                      0.452691
# %.2                                                               0.452608
# NEG Government  complicity (1.4.3)                                0.339317
# NEG State-imposed forced labour (1.8.1)                           0.096140
# Address risk                                                      0.559672
# %.3                                                               0.556106
# Supply chains                                                     0.506888
# %.4                                                               0.496392
# SUM/104                                                           0.657073
# SUM Neg                                                           0.314247
# TOTAL                                                             0.662586
# Education_Access_Score                                            1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# # Plots

# %% [markdown]
# ## Scatter plot

# %%
ax = sns.scatterplot(data=merged,
                x="Education_Access_Score",
                y="Victims_per_1000_population");

# %% [markdown]
# ## Regplot

# %%
ax= sns.regplot(data=merged,
                x="Education_Access_Score",
                y="Victims_per_1000_population");

# %%
#x= merged["Education_Access_Score"]
#y= merged["Victims_per_1,000_population"]

#print("x mean:",x.mean().round(2),"y mean:", y.mean().round(2))

# %% [markdown]
# # Drop `null` values

# %%
merged_new= merged[["Education_Access_Score", "Victims_per_1000_population"]].copy()
merged_new.dropna(inplace=True)
merged_new.head()
# Out:
#    Education_Access_Score  Victims_per_1000_population
# 0                0.227514                         93.0
# 1                0.370089                         40.0
# 2                0.317867                         22.3
# 3                0.365333                         22.2
# 4                0.352278                         21.4

# %%
merged_new.corr()
# Out:
#                              Education_Access_Score  \
# Education_Access_Score                     1.000000
# Victims_per_1000_population               -0.416617
#
#                              Victims_per_1000_population
# Education_Access_Score                         -0.416617
# Victims_per_1000_population                     1.000000

# %% [markdown]
# #  OLS Regression Results

# %%
x = sm.add_constant(merged_new.Education_Access_Score)
model = sm.OLS(merged_new.Victims_per_1000_population,x)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.174
# Model:                                     OLS   Adj. R-squared:                  0.168
# Method:                          Least Squares   F-statistic:                     31.29
# Date:                         Thu, 09 Jul 2020   Prob (F-statistic):           1.03e-07
# Time:                                 15:40:53   Log-Likelihood:                -524.90
# No. Observations:                          151   AIC:                             1054.
# Df Residuals:                              149   BIC:                             1060.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     18.0953      2.291      7.900      0.000      13.569      22.621
# Education_Access_Score   -19.9532      3.567     -5.594      0.000     -27.001     -12.905
# ==============================================================================
# Omnibus:                      249.117   Durbin-Watson:                   0.601
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31182.481
# Skew:                           7.292   Prob(JB):                         0.00
# Kurtosis:                      71.873   Cond. No.                         7.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 2nd Model

# %% [markdown]
# ## Education dataset
# ### New Data Frame with `Country` and `HDI Rank` in the columns

# %%
hdidf= education[["Country","HDI Rank"]].copy()
hdidf= hdidf.replace("..", np.nan)
hdidf.dropna(inplace=True)

print(hdidf, hdidf.dtypes)
# Out:
#                                 Country  HDI Rank
# 0                           Afghanistan     169.0
# 1                               Albania      95.0
# 2                               Algeria      93.0
# 3                               Andorra      37.0
# 4                                Angola     149.0
# ..                                  ...       ...
# 190  Venezuela (Bolivarian Republic of)      67.0
# 191                             Vietnam     121.0
# 192                               Yemen     154.0
# 193                              Zambia     141.0
# 194                            Zimbabwe     156.0
#
# [187 rows x 2 columns] Country      object
# HDI Rank    float64
# dtype: object

# %%
hdidf.rename(columns={"HDI Rank": "HDI_Rank"}, inplace=True)

# %% [markdown]
# # Merging Tables

# %% [markdown]
# ## `slavery_index` table with `hdidf` table

# %%
merge_2= pd.merge(slavery_index, hdidf, on="Country" )
merge_2
# Out:
#                               Country  \
# 0                             Eritrea
# 1                             Burundi
# 2            Central African Republic
# 3                         Afghanistan
# 4                          Mauritania
# ..                                ...
# 163                       Saint Lucia
# 164                             Malta
# 165  Saint Vincent and the Grenadines
# 166                           Vanuatu
# 167                        Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                            4,847,000
# 1                                           10,199,000
# 2                                            4,546,000
# 3                                           33,736,000
# 4                                            4,182,000
# ..                                                 ...
# 163                                            177,000
# 164                                            428,000
# 165                                            109,000
# 166                                            265,000
# 167                                             94,000
#
#                       Region  Victims_per_1000_population  \
# 0                     Africa                         93.0
# 1                     Africa                         40.0
# 2                     Africa                         22.3
# 3       Asia and the Pacific                         22.2
# 4                     Africa                         21.4
# ..                       ...                          ...
# 163                 Americas                          NaN
# 164  Europe and Central Asia                          NaN
# 165                 Americas                          NaN
# 166     Asia and the Pacific                          NaN
# 167                   Africa                          NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   451,000                          71.0
# 1                                   408,000                          72.4
# 2                                   101,000                          85.4
# 3                                   749,000                          81.0
# 4                                    90,000                          67.3
# ..                                      ...                           ...
# 163                                     NaN                           NaN
# 164                                     NaN                           NaN
# 165                                     NaN                           NaN
# 166                                     NaN                           NaN
# 167                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 50.6                     33.7
# 1                                 42.6                     42.1
# 2                                 50.2                     62.7
# 3                                 41.3                     64.7
# 4                                 33.7                     39.3
# ..                                 ...                      ...
# 163                                NaN                      NaN
# 164                                NaN                      NaN
# 165                                NaN                      NaN
# 166                                NaN                      NaN
# 167                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             25.9  ...
# 1                                  48.1                             41.7  ...
# 2                                  58.0                             81.6  ...
# 3                                  46.0                             92.6  ...
# 4                                  50.5                             22.3  ...
# ..                                  ...                              ...  ...
# 163                                 NaN                              NaN  ...
# 164                                 NaN                              NaN  ...
# 165                                 NaN                              NaN  ...
# 166                                 NaN                              NaN  ...
# 167                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.5  21.4
# 1                                       -1.0           1.8  26.2
# 2                                        0.0           1.5  21.4
# 3                                        NaN           NaN   NaN
# 4                                        0.0           2.5  35.7
# ..                                       ...           ...   ...
# 163                                      NaN           NaN   NaN
# 164                                      NaN           NaN   NaN
# 165                                      NaN           NaN   NaN
# 166                                      NaN           NaN   NaN
# 167                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating  HDI_Rank
# 0              0.0  0.0      1.4     -2.0   -2.0              D     182.0
# 1              0.0  0.0      5.0     -2.0   10.7              C     180.0
# 2              0.0  0.0      1.7     -1.0    2.5              D     185.0
# 3              NaN  NaN      NaN      NaN    NaN            NaN     169.0
# 4              0.0  0.0      5.3     -1.0   15.5              C     161.0
# ..             ...  ...      ...      ...    ...            ...       ...
# 163            NaN  NaN      NaN      NaN    NaN            NaN      97.0
# 164            NaN  NaN      NaN      NaN    NaN            NaN      39.0
# 165            NaN  NaN      NaN      NaN    NaN            NaN      91.0
# 166            NaN  NaN      NaN      NaN    NaN            NaN     131.0
# 167            NaN  NaN      NaN      NaN    NaN            NaN      71.0
#
# [168 rows x 28 columns]

# %% [markdown]
# # Correlations between `merge_2` table

# %%
merge_2.corr()
# Out:
#                                                     Victims_per_1000_population  \
# Victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.379444
# Factor Two Nourishment and Access                                      0.423225
# Factor Three Inequality                                                0.111686
# Factor Four Disenfranchised Groups                                     0.294802
# Factor Five Effects of Conflict                                        0.197003
# Final overall (normalised, weighted) vulnerabil...                     0.406846
# Support survivors                                                     -0.377257
# %                                                                     -0.376439
# Criminal justice                                                      -0.392226
# %.1                                                                   -0.391494
# Coordination                                                          -0.365449
# %.2                                                                   -0.364524
# NEG Government  complicity (1.4.3)                                    -0.234737
# NEG State-imposed forced labour (1.8.1)                               -0.355021
# Address risk                                                          -0.370284
# %.3                                                                   -0.369202
# Supply chains                                                         -0.159504
# %.4                                                                   -0.157498
# SUM/104                                                               -0.441590
# SUM Neg                                                               -0.363597
# TOTAL                                                                 -0.465029
# HDI_Rank                                                               0.393452
#
#                                                     Factor One Governance Issues  \
# Victims_per_1000_population                                             0.379444
# Factor One Governance Issues                                            1.000000
# Factor Two Nourishment and Access                                       0.595208
# Factor Three Inequality                                                 0.502648
# Factor Four Disenfranchised Groups                                      0.468657
# Factor Five Effects of Conflict                                         0.460542
# Final overall (normalised, weighted) vulnerabil...                      0.929781
# Support survivors                                                      -0.718463
# %                                                                      -0.719307
# Criminal justice                                                       -0.643288
# %.1                                                                    -0.644600
# Coordination                                                           -0.593959
# %.2                                                                    -0.594188
# NEG Government  complicity (1.4.3)                                     -0.444631
# NEG State-imposed forced labour (1.8.1)                                -0.267512
# Address risk                                                           -0.658122
# %.3                                                                    -0.656610
# Supply chains                                                          -0.573796
# %.4                                                                    -0.561784
# SUM/104                                                                -0.794816
# SUM Neg                                                                -0.483502
# TOTAL                                                                  -0.814466
# HDI_Rank                                                                0.748468
#
#                                                     Factor Two Nourishment and Access  \
# Victims_per_1000_population                                                  0.423225
# Factor One Governance Issues                                                 0.595208
# Factor Two Nourishment and Access                                            1.000000
# Factor Three Inequality                                                      0.374382
# Factor Four Disenfranchised Groups                                           0.416182
# Factor Five Effects of Conflict                                              0.327446
# Final overall (normalised, weighted) vulnerabil...                           0.736855
# Support survivors                                                           -0.481210
# %                                                                           -0.480159
# Criminal justice                                                            -0.439673
# %.1                                                                         -0.439634
# Coordination                                                                -0.440369
# %.2                                                                         -0.442043
# NEG Government  complicity (1.4.3)                                          -0.345587
# NEG State-imposed forced labour (1.8.1)                                     -0.106736
# Address risk                                                                -0.523452
# %.3                                                                         -0.518601
# Supply chains                                                               -0.395159
# %.4                                                                         -0.385736
# SUM/104                                                                     -0.563055
# SUM Neg                                                                     -0.324523
# TOTAL                                                                       -0.575496
# HDI_Rank                                                                     0.816940
#
#                                                     Factor Three Inequality  \
# Victims_per_1000_population                                        0.111686
# Factor One Governance Issues                                       0.502648
# Factor Two Nourishment and Access                                  0.374382
# Factor Three Inequality                                            1.000000
# Factor Four Disenfranchised Groups                                 0.436054
# Factor Five Effects of Conflict                                    0.372882
# Final overall (normalised, weighted) vulnerabil...                 0.649680
# Support survivors                                                 -0.278501
# %                                                                 -0.280180
# Criminal justice                                                  -0.251601
# %.1                                                               -0.250351
# Coordination                                                      -0.271686
# %.2                                                               -0.268109
# NEG Government  complicity (1.4.3)                                -0.284602
# NEG State-imposed forced labour (1.8.1)                            0.001839
# Address risk                                                      -0.182037
# %.3                                                               -0.179726
# Supply chains                                                     -0.318625
# %.4                                                               -0.303547
# SUM/104                                                           -0.298557
# SUM Neg                                                           -0.221779
# TOTAL                                                             -0.312195
# HDI_Rank                                                           0.534871
#
#                                                     Factor Four Disenfranchised Groups  \
# Victims_per_1000_population                                                   0.294802
# Factor One Governance Issues                                                  0.468657
# Factor Two Nourishment and Access                                             0.416182
# Factor Three Inequality                                                       0.436054
# Factor Four Disenfranchised Groups                                            1.000000
# Factor Five Effects of Conflict                                               0.232622
# Final overall (normalised, weighted) vulnerabil...                            0.613947
# Support survivors                                                            -0.289656
# %                                                                            -0.289535
# Criminal justice                                                             -0.312353
# %.1                                                                          -0.314049
# Coordination                                                                 -0.274764
# %.2                                                                          -0.278307
# NEG Government  complicity (1.4.3)                                           -0.151045
# NEG State-imposed forced labour (1.8.1)                                      -0.041067
# Address risk                                                                 -0.301425
# %.3                                                                          -0.297696
# Supply chains                                                                -0.269741
# %.4                                                                          -0.279464
# SUM/104                                                                      -0.352921
# SUM Neg                                                                      -0.139008
# TOTAL                                                                        -0.351394
# HDI_Rank                                                                      0.526088
#
#                                                     Factor Five Effects of Conflict  \
# Victims_per_1000_population                                                0.197003
# Factor One Governance Issues                                               0.460542
# Factor Two Nourishment and Access                                          0.327446
# Factor Three Inequality                                                    0.372882
# Factor Four Disenfranchised Groups                                         0.232622
# Factor Five Effects of Conflict                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                         0.630298
# Support survivors                                                         -0.211623
# %                                                                         -0.211027
# Criminal justice                                                          -0.147979
# %.1                                                                       -0.145110
# Coordination                                                              -0.111431
# %.2                                                                       -0.106631
# NEG Government  complicity (1.4.3)                                        -0.360252
# NEG State-imposed forced labour (1.8.1)                                   -0.213621
# Address risk                                                              -0.254158
# %.3                                                                       -0.253146
# Supply chains                                                             -0.217195
# %.4                                                                       -0.206653
# SUM/104                                                                   -0.228068
# SUM Neg                                                                   -0.390164
# TOTAL                                                                     -0.268848
# HDI_Rank                                                                   0.384580
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# Victims_per_1000_population                                                                  0.406846
# Factor One Governance Issues                                                                 0.929781
# Factor Two Nourishment and Access                                                            0.736855
# Factor Three Inequality                                                                      0.649680
# Factor Four Disenfranchised Groups                                                           0.613947
# Factor Five Effects of Conflict                                                              0.630298
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# Support survivors                                                                           -0.651196
# %                                                                                           -0.651541
# Criminal justice                                                                            -0.585350
# %.1                                                                                         -0.585601
# Coordination                                                                                -0.546765
# %.2                                                                                         -0.546344
# NEG Government  complicity (1.4.3)                                                          -0.471877
# NEG State-imposed forced labour (1.8.1)                                                     -0.227035
# Address risk                                                                                -0.622873
# %.3                                                                                         -0.619768
# Supply chains                                                                               -0.551788
# %.4                                                                                         -0.539987
# SUM/104                                                                                     -0.729949
# SUM Neg                                                                                     -0.484311
# TOTAL                                                                                       -0.754005
# HDI_Rank                                                                                     0.834111
#
#                                                     Support survivors  \
# Victims_per_1000_population                                 -0.377257
# Factor One Governance Issues                                -0.718463
# Factor Two Nourishment and Access                           -0.481210
# Factor Three Inequality                                     -0.278501
# Factor Four Disenfranchised Groups                          -0.289656
# Factor Five Effects of Conflict                             -0.211623
# Final overall (normalised, weighted) vulnerabil...          -0.651196
# Support survivors                                            1.000000
# %                                                            0.999876
# Criminal justice                                             0.710247
# %.1                                                          0.712385
# Coordination                                                 0.577469
# %.2                                                          0.576801
# NEG Government  complicity (1.4.3)                           0.315491
# NEG State-imposed forced labour (1.8.1)                      0.185547
# Address risk                                                 0.571494
# %.3                                                          0.570977
# Supply chains                                                0.423228
# %.4                                                          0.422001
# SUM/104                                                      0.897757
# SUM Neg                                                      0.340910
# TOTAL                                                        0.890594
# HDI_Rank                                                    -0.582376
#
#                                                            %  \
# Victims_per_1000_population                        -0.376439
# Factor One Governance Issues                       -0.719307
# Factor Two Nourishment and Access                  -0.480159
# Factor Three Inequality                            -0.280180
# Factor Four Disenfranchised Groups                 -0.289535
# Factor Five Effects of Conflict                    -0.211027
# Final overall (normalised, weighted) vulnerabil... -0.651541
# Support survivors                                   0.999876
# %                                                   1.000000
# Criminal justice                                    0.710026
# %.1                                                 0.712154
# Coordination                                        0.577449
# %.2                                                 0.576822
# NEG Government  complicity (1.4.3)                  0.315203
# NEG State-imposed forced labour (1.8.1)             0.183192
# Address risk                                        0.572400
# %.3                                                 0.571926
# Supply chains                                       0.424052
# %.4                                                 0.422626
# SUM/104                                             0.898056
# SUM Neg                                             0.339491
# TOTAL                                               0.890667
# HDI_Rank                                           -0.582441
#
#                                                     Criminal justice  ...  \
# Victims_per_1000_population                                -0.392226  ...
# Factor One Governance Issues                               -0.643288  ...
# Factor Two Nourishment and Access                          -0.439673  ...
# Factor Three Inequality                                    -0.251601  ...
# Factor Four Disenfranchised Groups                         -0.312353  ...
# Factor Five Effects of Conflict                            -0.147979  ...
# Final overall (normalised, weighted) vulnerabil...         -0.585350  ...
# Support survivors                                           0.710247  ...
# %                                                           0.710026  ...
# Criminal justice                                            1.000000  ...
# %.1                                                         0.999653  ...
# Coordination                                                0.586818  ...
# %.2                                                         0.586714  ...
# NEG Government  complicity (1.4.3)                          0.221510  ...
# NEG State-imposed forced labour (1.8.1)                     0.231919  ...
# Address risk                                                0.612633  ...
# %.3                                                         0.612278  ...
# Supply chains                                               0.392304  ...
# %.4                                                         0.390696  ...
# SUM/104                                                     0.863833  ...
# SUM Neg                                                     0.290865  ...
# TOTAL                                                       0.852355  ...
# HDI_Rank                                                   -0.509307  ...
#
#                                                     NEG Government  complicity (1.4.3)  \
# Victims_per_1000_population                                                  -0.234737
# Factor One Governance Issues                                                 -0.444631
# Factor Two Nourishment and Access                                            -0.345587
# Factor Three Inequality                                                      -0.284602
# Factor Four Disenfranchised Groups                                           -0.151045
# Factor Five Effects of Conflict                                              -0.360252
# Final overall (normalised, weighted) vulnerabil...                           -0.471877
# Support survivors                                                             0.315491
# %                                                                             0.315203
# Criminal justice                                                              0.221510
# %.1                                                                           0.218370
# Coordination                                                                  0.333867
# %.2                                                                           0.331330
# NEG Government  complicity (1.4.3)                                            1.000000
# NEG State-imposed forced labour (1.8.1)                                       0.164971
# Address risk                                                                  0.278687
# %.3                                                                           0.277820
# Supply chains                                                                 0.285842
# %.4                                                                           0.277685
# SUM/104                                                                       0.343359
# SUM Neg                                                                       0.866136
# TOTAL                                                                         0.444153
# HDI_Rank                                                                     -0.358483
#
#                                                     NEG State-imposed forced labour (1.8.1)  \
# Victims_per_1000_population                                                       -0.355021
# Factor One Governance Issues                                                      -0.267512
# Factor Two Nourishment and Access                                                 -0.106736
# Factor Three Inequality                                                            0.001839
# Factor Four Disenfranchised Groups                                                -0.041067
# Factor Five Effects of Conflict                                                   -0.213621
# Final overall (normalised, weighted) vulnerabil...                                -0.227035
# Support survivors                                                                  0.185547
# %                                                                                  0.183192
# Criminal justice                                                                   0.231919
# %.1                                                                                0.230707
# Coordination                                                                       0.164576
# %.2                                                                                0.164407
# NEG Government  complicity (1.4.3)                                                 0.164971
# NEG State-imposed forced labour (1.8.1)                                            1.000000
# Address risk                                                                       0.146865
# %.3                                                                                0.146013
# Supply chains                                                                     -0.007212
# %.4                                                                               -0.011222
# SUM/104                                                                            0.210349
# SUM Neg                                                                            0.635848
# TOTAL                                                                              0.286018
# HDI_Rank                                                                          -0.139441
#
#                                                     Address risk       %.3  \
# Victims_per_1000_population                            -0.370284 -0.369202
# Factor One Governance Issues                           -0.658122 -0.656610
# Factor Two Nourishment and Access                      -0.523452 -0.518601
# Factor Three Inequality                                -0.182037 -0.179726
# Factor Four Disenfranchised Groups                     -0.301425 -0.297696
# Factor Five Effects of Conflict                        -0.254158 -0.253146
# Final overall (normalised, weighted) vulnerabil...     -0.622873 -0.619768
# Support survivors                                       0.571494  0.570977
# %                                                       0.572400  0.571926
# Criminal justice                                        0.612633  0.612278
# %.1                                                     0.613075  0.612731
# Coordination                                            0.561575  0.561523
# %.2                                                     0.562687  0.562642
# NEG Government  complicity (1.4.3)                      0.278687  0.277820
# NEG State-imposed forced labour (1.8.1)                 0.146865  0.146013
# Address risk                                            1.000000  0.999745
# %.3                                                     0.999745  1.000000
# Supply chains                                           0.372106  0.369387
# %.4                                                     0.371305  0.368495
# SUM/104                                                 0.805265  0.804930
# SUM Neg                                                 0.292507  0.291397
# TOTAL                                                   0.796952  0.796452
# HDI_Rank                                               -0.512684 -0.508240
#
#                                                     Supply chains       %.4  \
# Victims_per_1000_population                             -0.159504 -0.157498
# Factor One Governance Issues                            -0.573796 -0.561784
# Factor Two Nourishment and Access                       -0.395159 -0.385736
# Factor Three Inequality                                 -0.318625 -0.303547
# Factor Four Disenfranchised Groups                      -0.269741 -0.279464
# Factor Five Effects of Conflict                         -0.217195 -0.206653
# Final overall (normalised, weighted) vulnerabil...      -0.551788 -0.539987
# Support survivors                                        0.423228  0.422001
# %                                                        0.424052  0.422626
# Criminal justice                                         0.392304  0.390696
# %.1                                                      0.393951  0.392812
# Coordination                                             0.464809  0.456012
# %.2                                                      0.464161  0.455811
# NEG Government  complicity (1.4.3)                       0.285842  0.277685
# NEG State-imposed forced labour (1.8.1)                 -0.007212 -0.011222
# Address risk                                             0.372106  0.371305
# %.3                                                      0.369387  0.368495
# Supply chains                                            1.000000  0.997488
# %.4                                                      0.997488  1.000000
# SUM/104                                                  0.520516  0.518007
# SUM Neg                                                  0.220027  0.211612
# TOTAL                                                    0.519543  0.515909
# HDI_Rank                                                -0.514157 -0.504536
#
#                                                      SUM/104   SUM Neg  \
# Victims_per_1000_population                        -0.441590 -0.363597
# Factor One Governance Issues                       -0.794816 -0.483502
# Factor Two Nourishment and Access                  -0.563055 -0.324523
# Factor Three Inequality                            -0.298557 -0.221779
# Factor Four Disenfranchised Groups                 -0.352921 -0.139008
# Factor Five Effects of Conflict                    -0.228068 -0.390164
# Final overall (normalised, weighted) vulnerabil... -0.729949 -0.484311
# Support survivors                                   0.897757  0.340910
# %                                                   0.898056  0.339491
# Criminal justice                                    0.863833  0.290865
# %.1                                                 0.865420  0.287794
# Coordination                                        0.763327  0.344662
# %.2                                                 0.763514  0.342592
# NEG Government  complicity (1.4.3)                  0.343359  0.866136
# NEG State-imposed forced labour (1.8.1)             0.210349  0.635848
# Address risk                                        0.805265  0.292507
# %.3                                                 0.804930  0.291397
# Supply chains                                       0.520516  0.220027
# %.4                                                 0.518007  0.211612
# SUM/104                                             1.000000  0.375285
# SUM Neg                                             0.375285  1.000000
# TOTAL                                               0.991451  0.492506
# HDI_Rank                                           -0.620846 -0.351188
#
#                                                        TOTAL  HDI_Rank
# Victims_per_1000_population                        -0.465029  0.393452
# Factor One Governance Issues                       -0.814466  0.748468
# Factor Two Nourishment and Access                  -0.575496  0.816940
# Factor Three Inequality                            -0.312195  0.534871
# Factor Four Disenfranchised Groups                 -0.351394  0.526088
# Factor Five Effects of Conflict                    -0.268848  0.384580
# Final overall (normalised, weighted) vulnerabil... -0.754005  0.834111
# Support survivors                                   0.890594 -0.582376
# %                                                   0.890667 -0.582441
# Criminal justice                                    0.852355 -0.509307
# %.1                                                 0.853403 -0.509229
# Coordination                                        0.765316 -0.405059
# %.2                                                 0.765159 -0.405771
# NEG Government  complicity (1.4.3)                  0.444153 -0.358483
# NEG State-imposed forced labour (1.8.1)             0.286018 -0.139441
# Address risk                                        0.796952 -0.512684
# %.3                                                 0.796452 -0.508240
# Supply chains                                       0.519543 -0.514157
# %.4                                                 0.515909 -0.504536
# SUM/104                                             0.991451 -0.620846
# SUM Neg                                             0.492506 -0.351188
# TOTAL                                               1.000000 -0.633602
# HDI_Rank                                           -0.633602  1.000000
#
# [23 rows x 23 columns]

# %%
ax = sns.scatterplot(data=merge_2,
                x="HDI_Rank",
                y="Victims_per_1000_population");

# %%
ax= sns.regplot(data=merge_2,
                x="HDI_Rank",
                y="Victims_per_1000_population");

# %%
merged_n= merge_2[["HDI_Rank", "Victims_per_1000_population"]].copy()
merged_n.dropna(inplace=True)
merged_n.head()
# Out:
#    HDI_Rank  Victims_per_1000_population
# 0     182.0                         93.0
# 1     180.0                         40.0
# 2     185.0                         22.3
# 3     169.0                         22.2
# 4     161.0                         21.4

# %%
merged_n.corr()
# Out:
#                              HDI_Rank  Victims_per_1000_population
# HDI_Rank                     1.000000                     0.393452
# Victims_per_1000_population  0.393452                     1.000000

# %%
x = sm.add_constant(merged_n.HDI_Rank)
model = sm.OLS(merged_n.Victims_per_1000_population,x)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.155
# Model:                                     OLS   Adj. R-squared:                  0.149
# Method:                          Least Squares   F-statistic:                     27.29
# Date:                         Thu, 09 Jul 2020   Prob (F-statistic):           5.80e-07
# Time:                                 15:40:55   Log-Likelihood:                -526.60
# No. Observations:                          151   AIC:                             1057.
# Df Residuals:                              149   BIC:                             1063.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1769      1.256      0.141      0.888      -2.304       2.658
# HDI_Rank       0.0602      0.012      5.224      0.000       0.037       0.083
# ==============================================================================
# Omnibus:                      257.061   Durbin-Watson:                   0.527
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36155.445
# Skew:                           7.698   Prob(JB):                         0.00
# Kurtosis:                      77.226   Cond. No.                         211.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 3rd Model

# %%
education_df= education[["HDI Rank","Country","2013"]].copy()
education_df= education_df.replace("..", np.nan)
education_df.dropna(inplace=True)

education_df["2013"]= education_df["2013"].str.replace(',','.')
education_df=education_df.astype({"HDI Rank":float, "2013" :float})
education_df.rename(columns={"HDI Rank": "HDI_Rank","2013": "Education_Access_Score"}, inplace=True)

education_df, education_df.dtypes
# Out:
# (     HDI_Rank                             Country  Education_Access_Score
#  0       169.0                         Afghanistan                0.365333
#  1        95.0                             Albania                0.608519
#  2        93.0                             Algeria                0.642589
#  3        37.0                             Andorra                0.670287
#  4       149.0                              Angola                0.474212
#  ..        ...                                 ...                     ...
#  190      67.0  Venezuela (Bolivarian Republic of)                0.682483
#  191     121.0                             Vietnam                0.513489
#  192     154.0                               Yemen                0.339222
#  193     141.0                              Zambia                0.591333
#  194     156.0                            Zimbabwe                0.499933
#
#  [187 rows x 3 columns],
#  HDI_Rank                  float64
#  Country                    object
#  Education_Access_Score    float64
#  dtype: object)

# %%
slavery_index.rename(columns={"Population \n(from United Nations Population Division, World Population Prospects)": "Population"}, inplace=True)
slavery_index['Population'] = slavery_index['Population'].astype('str') 
slavery_index['Population']=slavery_index['Population'].str.replace(',','')
slavery_index=slavery_index.astype({"Population" :float})

# %%
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].astype('str')
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace(",","")
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace("<","")
slavery_index=slavery_index.astype({"Est. number of people in modern slavery" :float})
slavery_index.head(25)
# Out:
#                                        Country   Population  \
# 0       Korea, Democratic People's Republic of   25244000.0
# 1                                      Eritrea    4847000.0
# 2                                      Burundi   10199000.0
# 3                     Central African Republic    4546000.0
# 4                                  Afghanistan   33736000.0
# 5                                   Mauritania    4182000.0
# 6                                  South Sudan   11882000.0
# 7                                     Pakistan  189381000.0
# 8                                     Cambodia   15518000.0
# 9                    Iran, Islamic Republic of   79360000.0
# 10                                     Somalia   13908000.0
# 11           Congo, Democratic Republic of the   76197000.0
# 12                                    Mongolia    2977000.0
# 13                                       Sudan   38648000.0
# 14                                        Chad   14009000.0
# 15                                      Rwanda   11630000.0
# 16                                Turkmenistan    5565000.0
# 17                                     Myanmar   52404000.0
# 18                           Brunei Darussalam     418000.0
# 19                                     Belarus    9486000.0
# 20                            Papua New Guinea    7920000.0
# 21            Lao People's Democratic Republic    6664000.0
# 22                                    Thailand   68658000.0
# 23                                   Swaziland    1319000.0
# 24  Macedonia, the former Yugoslav Republic of    2079000.0
#
#                      Region  Victims_per_1000_population  \
# 0      Asia and the Pacific                        104.6
# 1                    Africa                         93.0
# 2                    Africa                         40.0
# 3                    Africa                         22.3
# 4      Asia and the Pacific                         22.2
# 5                    Africa                         21.4
# 6                    Africa                         20.5
# 7      Asia and the Pacific                         16.8
# 8      Asia and the Pacific                         16.8
# 9      Asia and the Pacific                         16.2
# 10                   Africa                         15.5
# 11                   Africa                         13.7
# 12     Asia and the Pacific                         12.3
# 13                   Africa                         12.0
# 14                   Africa                         12.0
# 15                   Africa                         11.6
# 16  Europe and Central Asia                         11.2
# 17     Asia and the Pacific                         11.0
# 18     Asia and the Pacific                         10.9
# 19  Europe and Central Asia                         10.9
# 20     Asia and the Pacific                         10.3
# 21     Asia and the Pacific                          9.4
# 22     Asia and the Pacific                          8.9
# 23                   Africa                          8.8
# 24  Europe and Central Asia                          8.7
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                 2640000.0                          87.6
# 1                                  451000.0                          71.0
# 2                                  408000.0                          72.4
# 3                                  101000.0                          85.4
# 4                                  749000.0                          81.0
# 5                                   90000.0                          67.3
# 6                                  243000.0                          75.7
# 7                                 3186000.0                          56.8
# 8                                  261000.0                          66.3
# 9                                 1289000.0                          74.6
# 10                                 216000.0                          80.6
# 11                                1045000.0                          77.2
# 12                                  37000.0                          40.9
# 13                                 465000.0                          80.7
# 14                                 168000.0                          71.8
# 15                                 134000.0                          56.6
# 16                                  62000.0                          80.2
# 17                                 575000.0                          58.1
# 18                                   5000.0                          53.5
# 19                                 103000.0                          64.9
# 20                                  81000.0                          64.8
# 21                                  62000.0                          70.7
# 22                                 610000.0                          50.9
# 23                                  12000.0                          69.9
# 24                                  18000.0                          48.4
#
#     Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                52.0                     30.3
# 1                                50.6                     33.7
# 2                                42.6                     42.1
# 3                                50.2                     62.7
# 4                                41.3                     64.7
# 5                                33.7                     39.3
# 6                                51.1                     62.9
# 7                                36.2                     45.9
# 8                                38.5                     41.6
# 9                                25.5                     35.8
# 10                               56.8                     49.6
# 11                               50.8                     55.6
# 12                               36.8                     35.1
# 13                               46.6                     42.4
# 14                               43.2                     48.5
# 15                               40.8                     40.0
# 16                               21.5                     31.4
# 17                               43.8                     26.1
# 18                               30.9                     31.7
# 19                               16.7                     23.9
# 20                               63.3                     46.2
# 21                               35.1                     26.4
# 22                               21.8                     35.3
# 23                               50.0                     39.4
# 24                               17.4                     42.5
#
#     Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                 32.4                             12.3  ...
# 1                                 48.1                             25.9  ...
# 2                                 48.1                             41.7  ...
# 3                                 58.0                             81.6  ...
# 4                                 46.0                             92.6  ...
# 5                                 50.5                             22.3  ...
# 6                                 56.1                             85.7  ...
# 7                                 55.3                             92.8  ...
# 8                                 56.7                             14.8  ...
# 9                                 37.3                             39.5  ...
# 10                                22.7                             88.4  ...
# 11                                46.5                             86.7  ...
# 12                                47.1                             18.1  ...
# 13                                37.0                             87.4  ...
# 14                                46.5                             46.1  ...
# 15                                55.7                             34.0  ...
# 16                                32.6                             15.9  ...
# 17                                46.0                             70.2  ...
# 18                                41.2                             18.2  ...
# 19                                39.4                             20.8  ...
# 20                                 9.5                             13.3  ...
# 21                                41.2                             13.9  ...
# 22                                45.1                             51.9  ...
# 23                                38.8                             11.7  ...
# 24                                50.6                             27.3  ...
#
#     NEG Government  complicity (1.4.3)  \
# 0                                 -1.0
# 1                                 -1.0
# 2                                 -1.0
# 3                                 -1.0
# 4                                  NaN
# 5                                 -1.0
# 6                                  NaN
# 7                                 -1.0
# 8                                  0.0
# 9                                 -1.0
# 10                                -1.0
# 11                                -1.0
# 12                                 0.0
# 13                                -1.0
# 14                                -1.0
# 15                                -1.0
# 16                                -1.0
# 17                                -1.0
# 18                                 0.0
# 19                                 0.0
# 20                                -1.0
# 21                                -1.0
# 22                                -1.0
# 23                                 0.0
# 24                                 0.0
#
#     NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                      -1.0           0.3   4.8
# 1                                      -1.0           1.5  21.4
# 2                                      -1.0           1.8  26.2
# 3                                       0.0           1.5  21.4
# 4                                       NaN           NaN   NaN
# 5                                       0.0           2.5  35.7
# 6                                       NaN           NaN   NaN
# 7                                       0.0           2.8  40.5
# 8                                       0.0           2.3  33.3
# 9                                       0.0           1.7  23.8
# 10                                      0.0           2.5  35.7
# 11                                      0.0           1.0  14.3
# 12                                     -1.0           3.8  54.8
# 13                                      0.0           2.3  33.3
# 14                                      0.0           2.8  40.5
# 15                                     -1.0           3.8  54.8
# 16                                     -1.0           4.3  61.9
# 17                                     -1.0           3.0  42.9
# 18                                      0.0           3.0  42.9
# 19                                     -1.0           4.7  66.7
# 20                                      0.0           1.8  26.2
# 21                                      0.0           2.8  40.5
# 22                                      0.0           5.2  73.8
# 23                                     -1.0           3.3  47.6
# 24                                      0.0           4.3  61.9
#
#     Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0             0.0  0.0      0.4     -2.0   -5.6              D
# 1             0.0  0.0      1.4     -2.0   -2.0              D
# 2             0.0  0.0      5.0     -2.0   10.7              C
# 3             0.0  0.0      1.7     -1.0    2.5              D
# 4             NaN  NaN      NaN      NaN    NaN            NaN
# 5             0.0  0.0      5.3     -1.0   15.5              C
# 6             NaN  NaN      NaN      NaN    NaN            NaN
# 7             0.0  0.0      6.2     -1.0   18.6              C
# 8             0.0  0.0     10.5      0.0   37.6            CCC
# 9             0.0  0.0      2.9     -1.0    6.8              D
# 10            0.0  0.0      5.5     -1.0   16.0              C
# 11            0.0  0.0      6.3     -1.0   18.9              C
# 12            0.0  0.0      9.6     -1.0   30.7            CCC
# 13            0.0  0.0      5.2     -1.0   14.9              C
# 14            0.0  0.0      5.7     -1.0   16.7              C
# 15            0.0  0.0     11.4     -2.0   33.6            CCC
# 16            0.0  0.0      9.6     -2.0   27.1             CC
# 17            0.0  0.0     11.1     -2.0   32.4            CCC
# 18            0.0  0.0      5.8      0.0   20.6             CC
# 19            0.0  0.0     12.2     -1.0   40.1              B
# 20            0.0  0.0      6.3     -1.0   18.9              C
# 21            0.0  0.0     10.5     -1.0   34.0            CCC
# 22            0.0  0.0     14.7     -1.0   48.9              B
# 23            0.0  0.0      9.2     -1.0   29.3             CC
# 24            0.0  0.0     17.7      0.0   63.2            BBB
#
# [25 rows x 27 columns]

# %%
# merging both tables
merge_3= pd.merge(slavery_index, education_df, on="Country" )
merge_3
# Out:
#                               Country  Population                   Region  \
# 0                             Eritrea   4847000.0                   Africa
# 1                             Burundi  10199000.0                   Africa
# 2            Central African Republic   4546000.0                   Africa
# 3                         Afghanistan  33736000.0     Asia and the Pacific
# 4                          Mauritania   4182000.0                   Africa
# ..                                ...         ...                      ...
# 163                       Saint Lucia    177000.0                 Americas
# 164                             Malta    428000.0  Europe and Central Asia
# 165  Saint Vincent and the Grenadines    109000.0                 Americas
# 166                           Vanuatu    265000.0     Asia and the Pacific
# 167                        Seychelles     94000.0                   Africa
#
#      Victims_per_1000_population  Est. number of people in modern slavery  \
# 0                           93.0                                 451000.0
# 1                           40.0                                 408000.0
# 2                           22.3                                 101000.0
# 3                           22.2                                 749000.0
# 4                           21.4                                  90000.0
# ..                           ...                                      ...
# 163                          NaN                                      NaN
# 164                          NaN                                      NaN
# 165                          NaN                                      NaN
# 166                          NaN                                      NaN
# 167                          NaN                                      NaN
#
#      Factor One Governance Issues  Factor Two Nourishment and Access  \
# 0                            71.0                               50.6
# 1                            72.4                               42.6
# 2                            85.4                               50.2
# 3                            81.0                               41.3
# 4                            67.3                               33.7
# ..                            ...                                ...
# 163                           NaN                                NaN
# 164                           NaN                                NaN
# 165                           NaN                                NaN
# 166                           NaN                                NaN
# 167                           NaN                                NaN
#
#      Factor Three Inequality  Factor Four Disenfranchised Groups  \
# 0                       33.7                                48.1
# 1                       42.1                                48.1
# 2                       62.7                                58.0
# 3                       64.7                                46.0
# 4                       39.3                                50.5
# ..                       ...                                 ...
# 163                      NaN                                 NaN
# 164                      NaN                                 NaN
# 165                      NaN                                 NaN
# 166                      NaN                                 NaN
# 167                      NaN                                 NaN
#
#      Factor Five Effects of Conflict  ...  Address risk   %.3  Supply chains  \
# 0                               25.9  ...           1.5  21.4            0.0
# 1                               41.7  ...           1.8  26.2            0.0
# 2                               81.6  ...           1.5  21.4            0.0
# 3                               92.6  ...           NaN   NaN            NaN
# 4                               22.3  ...           2.5  35.7            0.0
# ..                               ...  ...           ...   ...            ...
# 163                              NaN  ...           NaN   NaN            NaN
# 164                              NaN  ...           NaN   NaN            NaN
# 165                              NaN  ...           NaN   NaN            NaN
# 166                              NaN  ...           NaN   NaN            NaN
# 167                              NaN  ...           NaN   NaN            NaN
#
#      %.4  SUM/104  SUM Neg  TOTAL  Credit rating  HDI_Rank  \
# 0    0.0      1.4     -2.0   -2.0              D     182.0
# 1    0.0      5.0     -2.0   10.7              C     180.0
# 2    0.0      1.7     -1.0    2.5              D     185.0
# 3    NaN      NaN      NaN    NaN            NaN     169.0
# 4    0.0      5.3     -1.0   15.5              C     161.0
# ..   ...      ...      ...    ...            ...       ...
# 163  NaN      NaN      NaN    NaN            NaN      97.0
# 164  NaN      NaN      NaN    NaN            NaN      39.0
# 165  NaN      NaN      NaN    NaN            NaN      91.0
# 166  NaN      NaN      NaN    NaN            NaN     131.0
# 167  NaN      NaN      NaN    NaN            NaN      71.0
#
#      Education_Access_Score
# 0                  0.227514
# 1                  0.370089
# 2                  0.317867
# 3                  0.365333
# 4                  0.352278
# ..                      ...
# 163                0.631431
# 164                0.732538
# 165                0.656834
# 166                0.595511
# 167                0.635929
#
# [168 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
#plt.style.use('ggplot')

# histogram of the height
#education_df.Victims_per_1000_population.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
#plt.title('Distribution of Height', size=24)
#plt.xlabel('Victims_per_1000_population")', size=18)
#plt.ylabel('HDI_Rank', size=18)

# %%
merge_3.dropna(inplace=True)
merge_3
# Out:
#                       Country   Population                Region  \
# 0                     Eritrea    4847000.0                Africa
# 1                     Burundi   10199000.0                Africa
# 2    Central African Republic    4546000.0                Africa
# 4                  Mauritania    4182000.0                Africa
# 5                    Pakistan  189381000.0  Asia and the Pacific
# ..                        ...          ...                   ...
# 146                     Chile   17763000.0              Americas
# 147                 Australia   23800000.0  Asia and the Pacific
# 148               New Zealand    4615000.0  Asia and the Pacific
# 149                    Canada   35950000.0              Americas
# 150                     Japan  127975000.0  Asia and the Pacific
#
#      Victims_per_1000_population  Est. number of people in modern slavery  \
# 0                           93.0                                 451000.0
# 1                           40.0                                 408000.0
# 2                           22.3                                 101000.0
# 4                           21.4                                  90000.0
# 5                           16.8                                3186000.0
# ..                           ...                                      ...
# 146                          0.8                                  14000.0
# 147                          0.6                                  15000.0
# 148                          0.6                                   3000.0
# 149                          0.5                                  17000.0
# 150                          0.3                                  37000.0
#
#      Factor One Governance Issues  Factor Two Nourishment and Access  \
# 0                            71.0                               50.6
# 1                            72.4                               42.6
# 2                            85.4                               50.2
# 4                            67.3                               33.7
# 5                            56.8                               36.2
# ..                            ...                                ...
# 146                          28.5                               13.8
# 147                          11.9                               15.7
# 148                          12.2                               18.4
# 149                          16.6                               20.7
# 150                          21.5                               13.1
#
#      Factor Three Inequality  Factor Four Disenfranchised Groups  \
# 0                       33.7                                48.1
# 1                       42.1                                48.1
# 2                       62.7                                58.0
# 4                       39.3                                50.5
# 5                       45.9                                55.3
# ..                       ...                                 ...
# 146                     50.0                                23.5
# 147                     20.7                                12.0
# 148                     16.2                                 7.0
# 149                     20.1                                 9.2
# 150                     15.5                                31.9
#
#      Factor Five Effects of Conflict  ...  Address risk   %.3  Supply chains  \
# 0                               25.9  ...           1.5  21.4            0.0
# 1                               41.7  ...           1.8  26.2            0.0
# 2                               81.6  ...           1.5  21.4            0.0
# 4                               22.3  ...           2.5  35.7            0.0
# 5                               92.8  ...           2.8  40.5            0.0
# ..                               ...  ...           ...   ...            ...
# 146                             20.3  ...           5.3  76.2            0.0
# 147                             13.0  ...           4.8  69.0            0.0
# 148                              7.0  ...           6.7  95.2            0.0
# 149                             21.5  ...           4.3  61.9            0.0
# 150                             17.8  ...           3.2  45.2            0.0
#
#      %.4  SUM/104  SUM Neg  TOTAL  Credit rating  HDI_Rank  \
# 0    0.0      1.4     -2.0   -2.0              D     182.0
# 1    0.0      5.0     -2.0   10.7              C     180.0
# 2    0.0      1.7     -1.0    2.5              D     185.0
# 4    0.0      5.3     -1.0   15.5              C     161.0
# 5    0.0      6.2     -1.0   18.6              C     146.0
# ..   ...      ...      ...    ...            ...       ...
# 146  0.0     17.5      0.0   62.3            BBB      41.0
# 147  0.0     17.9      0.0   63.8            BBB       2.0
# 148  0.0     16.1      0.0   57.6             BB       7.0
# 149  0.0     16.4      0.0   58.6             BB       8.0
# 150  0.0     11.3     -1.0   36.6            CCC      17.0
#
#      Education_Access_Score
# 0                  0.227514
# 1                  0.370089
# 2                  0.317867
# 4                  0.352278
# 5                  0.371667
# ..                      ...
# 146                0.745675
# 147                0.926536
# 148                0.916767
# 149                0.850300
# 150                0.808000
#
# [147 rows x 29 columns]

# %%
#reg = LinearRegression()
#reg.fit(merge_3[["Education_Access_Score","HDI_Rank" ]], merge_3.Victims_per_1000_population)
#reg.coef_
#reg.intercept_
#reg.predict(["value for column 1", "value of column 2"])

# %%
# best fit polynomials
merge_3_fit = np.polyfit(merge_3.Height, merge_3.Weight, 1)
# Out:
# array([-2.15245507e+01, -5.28373433e-03])

# %%
# Out:
# 19.561860277333604

# %%
merge_3_fit = np.polyfit(merge_3.Height, merge_3.Weight, 1)
