# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# # 1. Load GDP Data into a new Data Frame

# %%
df_gdp = pd.read_csv("../data/gdp_data.csv")
df_gdp.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016          2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10  1.910135e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  9.463542e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527808e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 64 columns]

# %%
df_gdp.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Length: 64, dtype: object

# %% [markdown]
# # 2. Rename columns names

# %%
df_gdp= df_gdp.rename({'Country Name' : 'Country',
               '2017' : 'gdp_2017'},axis=1)

# %%
df_gdp.head()
# Out:
#        Country Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016      gdp_2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10  1.910135e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  9.463542e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527808e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 64 columns]

# %% [markdown]
# # 3. Drop the NaN values

# %%
df_gdp_new = df_gdp[['Country', 'gdp_2017']].copy()
df_gdp_new.dropna(inplace=True)
df_gdp_new.head()
# Out:
#        Country      gdp_2017
# 0        Aruba  3.056425e+09
# 1  Afghanistan  2.019176e+10
# 2       Angola  1.221240e+11
# 3      Albania  1.301969e+10
# 4      Andorra  3.000181e+09

# %% [markdown]
# # 4. Sort values by gdp_2017
# * the values are represented in scientific notation, make sure to pay attention to the power of e

# %%
df_gdp_new.sort_values(by=['gdp_2017'])
# Out:
#                        Country      gdp_2017
# 243                     Tuvalu  4.061925e+07
# 177                      Nauru  1.095859e+08
# 122                   Kiribati  1.872762e+08
# 153           Marshall Islands  2.128810e+08
# 186                      Palau  2.863218e+08
# ..                         ...           ...
# 101           IDA & IBRD total  3.094160e+13
# 196  Post-demographic dividend  4.741500e+13
# 179               OECD members  5.025760e+13
# 93                 High income  5.141610e+13
# 257                      World  8.122920e+13
#
# [249 rows x 2 columns]

# %% [markdown]
# # 5. Load Slavery Index Data into a new Data Frame

# %%
df_slavery = pd.read_csv("../data/clean_slavery_index.csv", header=1)
df_slavery
# Out:
#                                    Country   \
# 0    Korea, Democratic People's Republic of
# 1                                   Eritrea
# 2                                   Burundi
# 3                  Central African Republic
# 4                               Afghanistan
# ..                                      ...
# 181                                   Malta
# 182                                  Tuvalu
# 183        Saint Vincent and the Grenadines
# 184                                 Vanuatu
# 185                              Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                           25,244,000
# 1                                            4,847,000
# 2                                           10,199,000
# 3                                            4,546,000
# 4                                           33,736,000
# ..                                                 ...
# 181                                            428,000
# 182                                                NaN
# 183                                            109,000
# 184                                            265,000
# 185                                             94,000
#
#                       Region  \
# 0       Asia and the Pacific
# 1                     Africa
# 2                     Africa
# 3                     Africa
# 4       Asia and the Pacific
# ..                       ...
# 181  Europe and Central Asia
# 182     Asia and the Pacific
# 183                 Americas
# 184     Asia and the Pacific
# 185                   Africa
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                104.6
# 1                                                 93.0
# 2                                                 40.0
# 3                                                 22.3
# 4                                                 22.2
# ..                                                 ...
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues   \
# 0                                 2,640,000                           87.6
# 1                                   451,000                           71.0
# 2                                   408,000                           72.4
# 3                                   101,000                           85.4
# 4                                   749,000                           81.0
# ..                                      ...                            ...
# 181                                     NaN                            NaN
# 182                                     NaN                            NaN
# 183                                     NaN                            NaN
# 184                                     NaN                            NaN
# 185                                     NaN                            NaN
#
#      Factor Two Nourishment and Access   Factor Three Inequality  \
# 0                                  52.0                     30.3
# 1                                  50.6                     33.7
# 2                                  42.6                     42.1
# 3                                  50.2                     62.7
# 4                                  41.3                     64.7
# ..                                  ...                      ...
# 181                                 NaN                      NaN
# 182                                 NaN                      NaN
# 183                                 NaN                      NaN
# 184                                 NaN                      NaN
# 185                                 NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  32.4                             12.3  ...
# 1                                  48.1                             25.9  ...
# 2                                  48.1                             41.7  ...
# 3                                  58.0                             81.6  ...
# 4                                  46.0                             92.6  ...
# ..                                  ...                              ...  ...
# 181                                 NaN                              NaN  ...
# 182                                 NaN                              NaN  ...
# 183                                 NaN                              NaN  ...
# 184                                 NaN                              NaN  ...
# 185                                 NaN                              NaN  ...
#
#      NEG Government  complicity (1.4.3)  \
# 0                                  -1.0
# 1                                  -1.0
# 2                                  -1.0
# 3                                  -1.0
# 4                                   NaN
# ..                                  ...
# 181                                 NaN
# 182                                 NaN
# 183                                 NaN
# 184                                 NaN
# 185                                 NaN
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           0.3   4.8
# 1                                       -1.0           1.5  21.4
# 2                                       -1.0           1.8  26.2
# 3                                        0.0           1.5  21.4
# 4                                        NaN           NaN   NaN
# ..                                       ...           ...   ...
# 181                                      NaN           NaN   NaN
# 182                                      NaN           NaN   NaN
# 183                                      NaN           NaN   NaN
# 184                                      NaN           NaN   NaN
# 185                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0              0.0  0.0      0.4     -2.0   -5.6              D
# 1              0.0  0.0      1.4     -2.0   -2.0              D
# 2              0.0  0.0      5.0     -2.0   10.7              C
# 3              0.0  0.0      1.7     -1.0    2.5              D
# 4              NaN  NaN      NaN      NaN    NaN            NaN
# ..             ...  ...      ...      ...    ...            ...
# 181            NaN  NaN      NaN      NaN    NaN            NaN
# 182            NaN  NaN      NaN      NaN    NaN            NaN
# 183            NaN  NaN      NaN      NaN    NaN            NaN
# 184            NaN  NaN      NaN      NaN    NaN            NaN
# 185            NaN  NaN      NaN      NaN    NaN            NaN
#
# [186 rows x 27 columns]

# %%
df_slavery.columns = df_slavery.columns.str.strip()
df_slavery.columns
# Out:
# Index(['Country',
#        'Population \n(from United Nations Population Division, World Population Prospects)',
#        'Region',
#        'Est. prevalence of population in modern slavery (victims per 1,000 population)',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %% [markdown]
# # 5. Merge Table with the Slavery Index Data

# %%
reunion = pd.merge(df_slavery, df_gdp_new, on="Country" )
reunion
# Out:
#                       Country  \
# 0                     Burundi
# 1    Central African Republic
# 2                 Afghanistan
# 3                  Mauritania
# 4                    Pakistan
# ..                        ...
# 151                     Tonga
# 152                     Malta
# 153                    Tuvalu
# 154                   Vanuatu
# 155                Seychelles
#
#     Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                           10,199,000
# 1                                            4,546,000
# 2                                           33,736,000
# 3                                            4,182,000
# 4                                          189,381,000
# ..                                                 ...
# 151                                            106,000
# 152                                            428,000
# 153                                                NaN
# 154                                            265,000
# 155                                             94,000
#
#                       Region  \
# 0                     Africa
# 1                     Africa
# 2       Asia and the Pacific
# 3                     Africa
# 4       Asia and the Pacific
# ..                       ...
# 151     Asia and the Pacific
# 152  Europe and Central Asia
# 153     Asia and the Pacific
# 154     Asia and the Pacific
# 155                   Africa
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                 40.0
# 1                                                 22.3
# 2                                                 22.2
# 3                                                 21.4
# 4                                                 16.8
# ..                                                 ...
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   408,000                          72.4
# 1                                   101,000                          85.4
# 2                                   749,000                          81.0
# 3                                    90,000                          67.3
# 4                                 3,186,000                          56.8
# ..                                      ...                           ...
# 151                                     NaN                           NaN
# 152                                     NaN                           NaN
# 153                                     NaN                           NaN
# 154                                     NaN                           NaN
# 155                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 42.6                     42.1
# 1                                 50.2                     62.7
# 2                                 41.3                     64.7
# 3                                 33.7                     39.3
# 4                                 36.2                     45.9
# ..                                 ...                      ...
# 151                                NaN                      NaN
# 152                                NaN                      NaN
# 153                                NaN                      NaN
# 154                                NaN                      NaN
# 155                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             41.7  ...
# 1                                  58.0                             81.6  ...
# 2                                  46.0                             92.6  ...
# 3                                  50.5                             22.3  ...
# 4                                  55.3                             92.8  ...
# ..                                  ...                              ...  ...
# 151                                 NaN                              NaN  ...
# 152                                 NaN                              NaN  ...
# 153                                 NaN                              NaN  ...
# 154                                 NaN                              NaN  ...
# 155                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.8  26.2
# 1                                        0.0           1.5  21.4
# 2                                        NaN           NaN   NaN
# 3                                        0.0           2.5  35.7
# 4                                        0.0           2.8  40.5
# ..                                       ...           ...   ...
# 151                                      NaN           NaN   NaN
# 152                                      NaN           NaN   NaN
# 153                                      NaN           NaN   NaN
# 154                                      NaN           NaN   NaN
# 155                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating      gdp_2017
# 0              0.0  0.0      5.0     -2.0   10.7              C  3.172292e+09
# 1              0.0  0.0      1.7     -1.0    2.5              D  2.072350e+09
# 2              NaN  NaN      NaN      NaN    NaN            NaN  2.019176e+10
# 3              0.0  0.0      5.3     -1.0   15.5              C  6.758391e+09
# 4              0.0  0.0      6.2     -1.0   18.6              C  3.045670e+11
# ..             ...  ...      ...      ...    ...            ...           ...
# 151            NaN  NaN      NaN      NaN    NaN            NaN  4.301742e+08
# 152            NaN  NaN      NaN      NaN    NaN            NaN  1.274786e+10
# 153            NaN  NaN      NaN      NaN    NaN            NaN  4.061925e+07
# 154            NaN  NaN      NaN      NaN    NaN            NaN  8.800436e+08
# 155            NaN  NaN      NaN      NaN    NaN            NaN  1.524487e+09
#
# [156 rows x 28 columns]

# %%
reunion.rename(columns={"Population \n(from United Nations Population Division, World Population Prospects)": "total_population"}, inplace=True)
reunion
# Out:
#                       Country total_population                   Region  \
# 0                     Burundi       10,199,000                   Africa
# 1    Central African Republic        4,546,000                   Africa
# 2                 Afghanistan       33,736,000     Asia and the Pacific
# 3                  Mauritania        4,182,000                   Africa
# 4                    Pakistan      189,381,000     Asia and the Pacific
# ..                        ...              ...                      ...
# 151                     Tonga          106,000     Asia and the Pacific
# 152                     Malta          428,000  Europe and Central Asia
# 153                    Tuvalu              NaN     Asia and the Pacific
# 154                   Vanuatu          265,000     Asia and the Pacific
# 155                Seychelles           94,000                   Africa
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                 40.0
# 1                                                 22.3
# 2                                                 22.2
# 3                                                 21.4
# 4                                                 16.8
# ..                                                 ...
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   408,000                          72.4
# 1                                   101,000                          85.4
# 2                                   749,000                          81.0
# 3                                    90,000                          67.3
# 4                                 3,186,000                          56.8
# ..                                      ...                           ...
# 151                                     NaN                           NaN
# 152                                     NaN                           NaN
# 153                                     NaN                           NaN
# 154                                     NaN                           NaN
# 155                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 42.6                     42.1
# 1                                 50.2                     62.7
# 2                                 41.3                     64.7
# 3                                 33.7                     39.3
# 4                                 36.2                     45.9
# ..                                 ...                      ...
# 151                                NaN                      NaN
# 152                                NaN                      NaN
# 153                                NaN                      NaN
# 154                                NaN                      NaN
# 155                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             41.7  ...
# 1                                  58.0                             81.6  ...
# 2                                  46.0                             92.6  ...
# 3                                  50.5                             22.3  ...
# 4                                  55.3                             92.8  ...
# ..                                  ...                              ...  ...
# 151                                 NaN                              NaN  ...
# 152                                 NaN                              NaN  ...
# 153                                 NaN                              NaN  ...
# 154                                 NaN                              NaN  ...
# 155                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.8  26.2
# 1                                        0.0           1.5  21.4
# 2                                        NaN           NaN   NaN
# 3                                        0.0           2.5  35.7
# 4                                        0.0           2.8  40.5
# ..                                       ...           ...   ...
# 151                                      NaN           NaN   NaN
# 152                                      NaN           NaN   NaN
# 153                                      NaN           NaN   NaN
# 154                                      NaN           NaN   NaN
# 155                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating      gdp_2017
# 0              0.0  0.0      5.0     -2.0   10.7              C  3.172292e+09
# 1              0.0  0.0      1.7     -1.0    2.5              D  2.072350e+09
# 2              NaN  NaN      NaN      NaN    NaN            NaN  2.019176e+10
# 3              0.0  0.0      5.3     -1.0   15.5              C  6.758391e+09
# 4              0.0  0.0      6.2     -1.0   18.6              C  3.045670e+11
# ..             ...  ...      ...      ...    ...            ...           ...
# 151            NaN  NaN      NaN      NaN    NaN            NaN  4.301742e+08
# 152            NaN  NaN      NaN      NaN    NaN            NaN  1.274786e+10
# 153            NaN  NaN      NaN      NaN    NaN            NaN  4.061925e+07
# 154            NaN  NaN      NaN      NaN    NaN            NaN  8.800436e+08
# 155            NaN  NaN      NaN      NaN    NaN            NaN  1.524487e+09
#
# [156 rows x 28 columns]

# %%
reunion.dropna(inplace=True)
reunion
# Out:
#                       Country total_population                Region  \
# 0                     Burundi       10,199,000                Africa
# 1    Central African Republic        4,546,000                Africa
# 3                  Mauritania        4,182,000                Africa
# 4                    Pakistan      189,381,000  Asia and the Pacific
# 5                    Cambodia       15,518,000  Asia and the Pacific
# ..                        ...              ...                   ...
# 136                     Chile       17,763,000              Americas
# 137                 Australia       23,800,000  Asia and the Pacific
# 138               New Zealand        4,615,000  Asia and the Pacific
# 139                    Canada       35,950,000              Americas
# 140                     Japan      127,975,000  Asia and the Pacific
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                 40.0
# 1                                                 22.3
# 3                                                 21.4
# 4                                                 16.8
# 5                                                 16.8
# ..                                                 ...
# 136                                                0.8
# 137                                                0.6
# 138                                                0.6
# 139                                                0.5
# 140                                                0.3
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   408,000                          72.4
# 1                                   101,000                          85.4
# 3                                    90,000                          67.3
# 4                                 3,186,000                          56.8
# 5                                   261,000                          66.3
# ..                                      ...                           ...
# 136                                  14,000                          28.5
# 137                                  15,000                          11.9
# 138                                   3,000                          12.2
# 139                                  17,000                          16.6
# 140                                  37,000                          21.5
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 42.6                     42.1
# 1                                 50.2                     62.7
# 3                                 33.7                     39.3
# 4                                 36.2                     45.9
# 5                                 38.5                     41.6
# ..                                 ...                      ...
# 136                               13.8                     50.0
# 137                               15.7                     20.7
# 138                               18.4                     16.2
# 139                               20.7                     20.1
# 140                               13.1                     15.5
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             41.7  ...
# 1                                  58.0                             81.6  ...
# 3                                  50.5                             22.3  ...
# 4                                  55.3                             92.8  ...
# 5                                  56.7                             14.8  ...
# ..                                  ...                              ...  ...
# 136                                23.5                             20.3  ...
# 137                                12.0                             13.0  ...
# 138                                 7.0                              7.0  ...
# 139                                 9.2                             21.5  ...
# 140                                31.9                             17.8  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.8  26.2
# 1                                        0.0           1.5  21.4
# 3                                        0.0           2.5  35.7
# 4                                        0.0           2.8  40.5
# 5                                        0.0           2.3  33.3
# ..                                       ...           ...   ...
# 136                                      0.0           5.3  76.2
# 137                                      0.0           4.8  69.0
# 138                                      0.0           6.7  95.2
# 139                                      0.0           4.3  61.9
# 140                                      0.0           3.2  45.2
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating      gdp_2017
# 0              0.0  0.0      5.0     -2.0   10.7              C  3.172292e+09
# 1              0.0  0.0      1.7     -1.0    2.5              D  2.072350e+09
# 3              0.0  0.0      5.3     -1.0   15.5              C  6.758391e+09
# 4              0.0  0.0      6.2     -1.0   18.6              C  3.045670e+11
# 5              0.0  0.0     10.5      0.0   37.6            CCC  2.217720e+10
# ..             ...  ...      ...      ...    ...            ...           ...
# 136            0.0  0.0     17.5      0.0   62.3            BBB  2.770450e+11
# 137            0.0  0.0     17.9      0.0   63.8            BBB  1.330140e+12
# 138            0.0  0.0     16.1      0.0   57.6             BB  2.054160e+11
# 139            0.0  0.0     16.4      0.0   58.6             BB  1.649880e+12
# 140            0.0  0.0     11.3     -1.0   36.6            CCC  4.866860e+12
#
# [139 rows x 28 columns]

# %%
reunion['total_population'] = reunion['total_population'].astype('str') 
reunion['total_population'] = reunion['total_population'].str.replace(",", "")
reunion = reunion.astype({"total_population" :float})
reunion.dtypes
# Out:
# Country                                                                            object
# total_population                                                                  float64
# Region                                                                             object
# Est. prevalence of population in modern slavery (victims per 1,000 population)    float64
# Est. number of people in modern slavery                                            object
# Factor One Governance Issues                                                      float64
# Factor Two Nourishment and Access                                                 float64
# Factor Three Inequality                                                           float64
# Factor Four Disenfranchised Groups                                                float64
# Factor Five Effects of Conflict                                                   float64
# Final overall (normalised, weighted) vulnerability score                          float64
# Support survivors                                                                 float64
# %                                                                                 float64
# Criminal justice                                                                  float64
# %.1                                                                               float64
# Coordination                                                                      float64
# %.2                                                                               float64
# NEG Government  complicity (1.4.3)                                                float64
# NEG State-imposed forced labour (1.8.1)                                           float64
# Address risk                                                                      float64
# %.3                                                                               float64
# Supply chains                                                                     float64
# %.4                                                                               float64
# SUM/104                                                                           float64
# SUM Neg                                                                           float64
# TOTAL                                                                             float64
# Credit rating                                                                      object
# gdp_2017                                                                          float64
# dtype: object

# %%
reunion['gdp_per_capita'] = reunion.apply(lambda row: row.gdp_2017 / row.total_population, axis=1)
reunion.gdp_per_capita = reunion.gdp_per_capita.round()
reunion
# Out:
#                       Country  total_population                Region  \
# 0                     Burundi        10199000.0                Africa
# 1    Central African Republic         4546000.0                Africa
# 3                  Mauritania         4182000.0                Africa
# 4                    Pakistan       189381000.0  Asia and the Pacific
# 5                    Cambodia        15518000.0  Asia and the Pacific
# ..                        ...               ...                   ...
# 136                     Chile        17763000.0              Americas
# 137                 Australia        23800000.0  Asia and the Pacific
# 138               New Zealand         4615000.0  Asia and the Pacific
# 139                    Canada        35950000.0              Americas
# 140                     Japan       127975000.0  Asia and the Pacific
#
#      Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                                 40.0
# 1                                                 22.3
# 3                                                 21.4
# 4                                                 16.8
# 5                                                 16.8
# ..                                                 ...
# 136                                                0.8
# 137                                                0.6
# 138                                                0.6
# 139                                                0.5
# 140                                                0.3
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   408,000                          72.4
# 1                                   101,000                          85.4
# 3                                    90,000                          67.3
# 4                                 3,186,000                          56.8
# 5                                   261,000                          66.3
# ..                                      ...                           ...
# 136                                  14,000                          28.5
# 137                                  15,000                          11.9
# 138                                   3,000                          12.2
# 139                                  17,000                          16.6
# 140                                  37,000                          21.5
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 42.6                     42.1
# 1                                 50.2                     62.7
# 3                                 33.7                     39.3
# 4                                 36.2                     45.9
# 5                                 38.5                     41.6
# ..                                 ...                      ...
# 136                               13.8                     50.0
# 137                               15.7                     20.7
# 138                               18.4                     16.2
# 139                               20.7                     20.1
# 140                               13.1                     15.5
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             41.7  ...
# 1                                  58.0                             81.6  ...
# 3                                  50.5                             22.3  ...
# 4                                  55.3                             92.8  ...
# 5                                  56.7                             14.8  ...
# ..                                  ...                              ...  ...
# 136                                23.5                             20.3  ...
# 137                                12.0                             13.0  ...
# 138                                 7.0                              7.0  ...
# 139                                 9.2                             21.5  ...
# 140                                31.9                             17.8  ...
#
#      Address risk   %.3  Supply chains  %.4  SUM/104  SUM Neg  TOTAL  \
# 0             1.8  26.2            0.0  0.0      5.0     -2.0   10.7
# 1             1.5  21.4            0.0  0.0      1.7     -1.0    2.5
# 3             2.5  35.7            0.0  0.0      5.3     -1.0   15.5
# 4             2.8  40.5            0.0  0.0      6.2     -1.0   18.6
# 5             2.3  33.3            0.0  0.0     10.5      0.0   37.6
# ..            ...   ...            ...  ...      ...      ...    ...
# 136           5.3  76.2            0.0  0.0     17.5      0.0   62.3
# 137           4.8  69.0            0.0  0.0     17.9      0.0   63.8
# 138           6.7  95.2            0.0  0.0     16.1      0.0   57.6
# 139           4.3  61.9            0.0  0.0     16.4      0.0   58.6
# 140           3.2  45.2            0.0  0.0     11.3     -1.0   36.6
#
#      Credit rating      gdp_2017  gdp_per_capita
# 0                C  3.172292e+09           311.0
# 1                D  2.072350e+09           456.0
# 3                C  6.758391e+09          1616.0
# 4                C  3.045670e+11          1608.0
# 5              CCC  2.217720e+10          1429.0
# ..             ...           ...             ...
# 136            BBB  2.770450e+11         15597.0
# 137            BBB  1.330140e+12         55888.0
# 138             BB  2.054160e+11         44511.0
# 139             BB  1.649880e+12         45894.0
# 140            CCC  4.866860e+12         38030.0
#
# [139 rows x 29 columns]

# %% [markdown]
# # Rename column

# %%
reunion.rename(columns={"Est. prevalence of population in modern slavery (victims per 1,000 population)": "victims_per_1000_population"}, inplace=True)
reunion.head()
# Out:
#                     Country  total_population                Region  \
# 0                   Burundi        10199000.0                Africa
# 1  Central African Republic         4546000.0                Africa
# 3                Mauritania         4182000.0                Africa
# 4                  Pakistan       189381000.0  Asia and the Pacific
# 5                  Cambodia        15518000.0  Asia and the Pacific
#
#    victims_per_1000_population Est. number of people in modern slavery  \
# 0                         40.0                                 408,000
# 1                         22.3                                 101,000
# 3                         21.4                                  90,000
# 4                         16.8                               3,186,000
# 5                         16.8                                 261,000
#
#    Factor One Governance Issues  Factor Two Nourishment and Access  \
# 0                          72.4                               42.6
# 1                          85.4                               50.2
# 3                          67.3                               33.7
# 4                          56.8                               36.2
# 5                          66.3                               38.5
#
#    Factor Three Inequality  Factor Four Disenfranchised Groups  \
# 0                     42.1                                48.1
# 1                     62.7                                58.0
# 3                     39.3                                50.5
# 4                     45.9                                55.3
# 5                     41.6                                56.7
#
#    Factor Five Effects of Conflict  ...  Address risk   %.3  Supply chains  \
# 0                             41.7  ...           1.8  26.2            0.0
# 1                             81.6  ...           1.5  21.4            0.0
# 3                             22.3  ...           2.5  35.7            0.0
# 4                             92.8  ...           2.8  40.5            0.0
# 5                             14.8  ...           2.3  33.3            0.0
#
#    %.4  SUM/104  SUM Neg  TOTAL  Credit rating      gdp_2017  gdp_per_capita
# 0  0.0      5.0     -2.0   10.7              C  3.172292e+09           311.0
# 1  0.0      1.7     -1.0    2.5              D  2.072350e+09           456.0
# 3  0.0      5.3     -1.0   15.5              C  6.758391e+09          1616.0
# 4  0.0      6.2     -1.0   18.6              C  3.045670e+11          1608.0
# 5  0.0     10.5      0.0   37.6            CCC  2.217720e+10          1429.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Plotting

# %%
ax = sns.scatterplot(data = reunion,
                x="gdp_per_capita",
                y="victims_per_1000_population");

# %%
ax= sns.regplot(data = reunion,
                x="gdp_per_capita",
                y="victims_per_1000_population");

# %%
reunion.corr()
# Out:
#                                                     total_population  \
# total_population                                            1.000000
# victims_per_1000_population                                -0.017584
# Factor One Governance Issues                                0.034661
# Factor Two Nourishment and Access                           0.008178
# Factor Three Inequality                                    -0.065670
# Factor Four Disenfranchised Groups                         -0.018368
# Factor Five Effects of Conflict                             0.334817
# Final overall (normalised, weighted) vulnerabil...          0.077283
# Support survivors                                          -0.024617
# %                                                          -0.024246
# Criminal justice                                            0.032601
# %.1                                                         0.030237
# Coordination                                                0.084696
# %.2                                                         0.082992
# NEG Government  complicity (1.4.3)                         -0.062386
# NEG State-imposed forced labour (1.8.1)                    -0.204369
# Address risk                                               -0.024486
# %.3                                                        -0.027878
# Supply chains                                               0.136807
# %.4                                                         0.136065
# SUM/104                                                     0.012674
# SUM Neg                                                    -0.147079
# TOTAL                                                      -0.009310
# gdp_2017                                                    0.566135
# gdp_per_capita                                             -0.055574
#
#                                                     victims_per_1000_population  \
# total_population                                                      -0.017584
# victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.521355
# Factor Two Nourishment and Access                                      0.520234
# Factor Three Inequality                                                0.210290
# Factor Four Disenfranchised Groups                                     0.443543
# Factor Five Effects of Conflict                                        0.355926
# Final overall (normalised, weighted) vulnerabil...                     0.587430
# Support survivors                                                     -0.419260
# %                                                                     -0.418470
# Criminal justice                                                      -0.418765
# %.1                                                                   -0.420017
# Coordination                                                          -0.387256
# %.2                                                                   -0.388477
# NEG Government  complicity (1.4.3)                                    -0.284919
# NEG State-imposed forced labour (1.8.1)                               -0.313733
# Address risk                                                          -0.433439
# %.3                                                                   -0.429783
# Supply chains                                                         -0.225352
# %.4                                                                   -0.223516
# SUM/104                                                               -0.495304
# SUM Neg                                                               -0.374461
# TOTAL                                                                 -0.518656
# gdp_2017                                                              -0.146913
# gdp_per_capita                                                        -0.378734
#
#                                                     Factor One Governance Issues  \
# total_population                                                        0.034661
# victims_per_1000_population                                             0.521355
# Factor One Governance Issues                                            1.000000
# Factor Two Nourishment and Access                                       0.562720
# Factor Three Inequality                                                 0.471258
# Factor Four Disenfranchised Groups                                      0.467857
# Factor Five Effects of Conflict                                         0.415296
# Final overall (normalised, weighted) vulnerabil...                      0.922364
# Support survivors                                                      -0.706053
# %                                                                      -0.706679
# Criminal justice                                                       -0.630621
# %.1                                                                    -0.628597
# Coordination                                                           -0.599385
# %.2                                                                    -0.600692
# NEG Government  complicity (1.4.3)                                     -0.450224
# NEG State-imposed forced labour (1.8.1)                                -0.236204
# Address risk                                                           -0.654304
# %.3                                                                    -0.653175
# Supply chains                                                          -0.568315
# %.4                                                                    -0.556321
# SUM/104                                                                -0.793348
# SUM Neg                                                                -0.467201
# TOTAL                                                                  -0.811843
# gdp_2017                                                               -0.202034
# gdp_per_capita                                                         -0.689694
#
#                                                     Factor Two Nourishment and Access  \
# total_population                                                             0.008178
# victims_per_1000_population                                                  0.520234
# Factor One Governance Issues                                                 0.562720
# Factor Two Nourishment and Access                                            1.000000
# Factor Three Inequality                                                      0.365497
# Factor Four Disenfranchised Groups                                           0.417396
# Factor Five Effects of Conflict                                              0.326050
# Final overall (normalised, weighted) vulnerabil...                           0.732119
# Support survivors                                                           -0.475986
# %                                                                           -0.474813
# Criminal justice                                                            -0.416498
# %.1                                                                         -0.418834
# Coordination                                                                -0.416419
# %.2                                                                         -0.418972
# NEG Government  complicity (1.4.3)                                          -0.347724
# NEG State-imposed forced labour (1.8.1)                                     -0.050948
# Address risk                                                                -0.512497
# %.3                                                                         -0.507123
# Supply chains                                                               -0.388911
# %.4                                                                         -0.379675
# SUM/104                                                                     -0.551958
# SUM Neg                                                                     -0.297761
# TOTAL                                                                       -0.563115
# gdp_2017                                                                    -0.156296
# gdp_per_capita                                                              -0.514765
#
#                                                     Factor Three Inequality  \
# total_population                                                  -0.065670
# victims_per_1000_population                                        0.210290
# Factor One Governance Issues                                       0.471258
# Factor Two Nourishment and Access                                  0.365497
# Factor Three Inequality                                            1.000000
# Factor Four Disenfranchised Groups                                 0.445508
# Factor Five Effects of Conflict                                    0.268431
# Final overall (normalised, weighted) vulnerabil...                 0.621531
# Support survivors                                                 -0.275942
# %                                                                 -0.277604
# Criminal justice                                                  -0.250503
# %.1                                                               -0.247548
# Coordination                                                      -0.274386
# %.2                                                               -0.270653
# NEG Government  complicity (1.4.3)                                -0.305739
# NEG State-imposed forced labour (1.8.1)                            0.010756
# Address risk                                                      -0.186228
# %.3                                                               -0.183793
# Supply chains                                                     -0.316282
# %.4                                                               -0.301033
# SUM/104                                                           -0.301413
# SUM Neg                                                           -0.235158
# TOTAL                                                             -0.317171
# gdp_2017                                                          -0.164316
# gdp_per_capita                                                    -0.606840
#
#                                                     Factor Four Disenfranchised Groups  \
# total_population                                                             -0.018368
# victims_per_1000_population                                                   0.443543
# Factor One Governance Issues                                                  0.467857
# Factor Two Nourishment and Access                                             0.417396
# Factor Three Inequality                                                       0.445508
# Factor Four Disenfranchised Groups                                            1.000000
# Factor Five Effects of Conflict                                               0.223660
# Final overall (normalised, weighted) vulnerabil...                            0.629960
# Support survivors                                                            -0.262267
# %                                                                            -0.261920
# Criminal justice                                                             -0.295595
# %.1                                                                          -0.292868
# Coordination                                                                 -0.282852
# %.2                                                                          -0.287361
# NEG Government  complicity (1.4.3)                                           -0.153705
# NEG State-imposed forced labour (1.8.1)                                      -0.006594
# Address risk                                                                 -0.296502
# %.3                                                                          -0.293005
# Supply chains                                                                -0.275253
# %.4                                                                          -0.284219
# SUM/104                                                                      -0.340489
# SUM Neg                                                                      -0.123979
# TOTAL                                                                        -0.337296
# gdp_2017                                                                     -0.220592
# gdp_per_capita                                                               -0.633496
#
#                                                     Factor Five Effects of Conflict  \
# total_population                                                           0.334817
# victims_per_1000_population                                                0.355926
# Factor One Governance Issues                                               0.415296
# Factor Two Nourishment and Access                                          0.326050
# Factor Three Inequality                                                    0.268431
# Factor Four Disenfranchised Groups                                         0.223660
# Factor Five Effects of Conflict                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                         0.588517
# Support survivors                                                         -0.236591
# %                                                                         -0.236245
# Criminal justice                                                          -0.168899
# %.1                                                                       -0.168931
# Coordination                                                              -0.124385
# %.2                                                                       -0.119168
# NEG Government  complicity (1.4.3)                                        -0.385745
# NEG State-imposed forced labour (1.8.1)                                   -0.221974
# Address risk                                                              -0.281717
# %.3                                                                       -0.280085
# Supply chains                                                             -0.217287
# %.4                                                                       -0.206706
# SUM/104                                                                   -0.256779
# SUM Neg                                                                   -0.409693
# TOTAL                                                                     -0.300173
# gdp_2017                                                                   0.070621
# gdp_per_capita                                                            -0.359601
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# total_population                                                                             0.077283
# victims_per_1000_population                                                                  0.587430
# Factor One Governance Issues                                                                 0.922364
# Factor Two Nourishment and Access                                                            0.732119
# Factor Three Inequality                                                                      0.621531
# Factor Four Disenfranchised Groups                                                           0.629960
# Factor Five Effects of Conflict                                                              0.588517
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# Support survivors                                                                           -0.638467
# %                                                                                           -0.638670
# Criminal justice                                                                            -0.569986
# %.1                                                                                         -0.568508
# Coordination                                                                                -0.544551
# %.2                                                                                         -0.544966
# NEG Government  complicity (1.4.3)                                                          -0.481966
# NEG State-imposed forced labour (1.8.1)                                                     -0.190137
# Address risk                                                                                -0.619119
# %.3                                                                                         -0.616015
# Supply chains                                                                               -0.544367
# %.4                                                                                         -0.532535
# SUM/104                                                                                     -0.725469
# SUM Neg                                                                                     -0.470051
# TOTAL                                                                                       -0.749134
# gdp_2017                                                                                    -0.194626
# gdp_per_capita                                                                              -0.770620
#
#                                                     Support survivors  \
# total_population                                            -0.024617
# victims_per_1000_population                                 -0.419260
# Factor One Governance Issues                                -0.706053
# Factor Two Nourishment and Access                           -0.475986
# Factor Three Inequality                                     -0.275942
# Factor Four Disenfranchised Groups                          -0.262267
# Factor Five Effects of Conflict                             -0.236591
# Final overall (normalised, weighted) vulnerabil...          -0.638467
# Support survivors                                            1.000000
# %                                                            0.999875
# Criminal justice                                             0.694590
# %.1                                                          0.699884
# Coordination                                                 0.555791
# %.2                                                          0.556289
# NEG Government  complicity (1.4.3)                           0.316901
# NEG State-imposed forced labour (1.8.1)                      0.161343
# Address risk                                                 0.553307
# %.3                                                          0.552650
# Supply chains                                                0.411375
# %.4                                                          0.410467
# SUM/104                                                      0.892121
# SUM Neg                                                      0.326493
# TOTAL                                                        0.885453
# gdp_2017                                                     0.193718
# gdp_per_capita                                               0.426024
#
#                                                            %  ...  \
# total_population                                   -0.024246  ...
# victims_per_1000_population                        -0.418470  ...
# Factor One Governance Issues                       -0.706679  ...
# Factor Two Nourishment and Access                  -0.474813  ...
# Factor Three Inequality                            -0.277604  ...
# Factor Four Disenfranchised Groups                 -0.261920  ...
# Factor Five Effects of Conflict                    -0.236245  ...
# Final overall (normalised, weighted) vulnerabil... -0.638670  ...
# Support survivors                                   0.999875  ...
# %                                                   1.000000  ...
# Criminal justice                                    0.694377  ...
# %.1                                                 0.699672  ...
# Coordination                                        0.556038  ...
# %.2                                                 0.556594  ...
# NEG Government  complicity (1.4.3)                  0.316740  ...
# NEG State-imposed forced labour (1.8.1)             0.158524  ...
# Address risk                                        0.554474  ...
# %.3                                                 0.553869  ...
# Supply chains                                       0.412262  ...
# %.4                                                 0.411145  ...
# SUM/104                                             0.892567  ...
# SUM Neg                                             0.325014  ...
# TOTAL                                               0.885650  ...
# gdp_2017                                            0.195107  ...
# gdp_per_capita                                      0.425282  ...
#
#                                                     NEG State-imposed forced labour (1.8.1)  \
# total_population                                                                  -0.204369
# victims_per_1000_population                                                       -0.313733
# Factor One Governance Issues                                                      -0.236204
# Factor Two Nourishment and Access                                                 -0.050948
# Factor Three Inequality                                                            0.010756
# Factor Four Disenfranchised Groups                                                -0.006594
# Factor Five Effects of Conflict                                                   -0.221974
# Final overall (normalised, weighted) vulnerabil...                                -0.190137
# Support survivors                                                                  0.161343
# %                                                                                  0.158524
# Criminal justice                                                                   0.175972
# %.1                                                                                0.176560
# Coordination                                                                       0.148522
# %.2                                                                                0.149911
# NEG Government  complicity (1.4.3)                                                 0.201582
# NEG State-imposed forced labour (1.8.1)                                            1.000000
# Address risk                                                                       0.133523
# %.3                                                                                0.132446
# Supply chains                                                                     -0.036836
# %.4                                                                               -0.040235
# SUM/104                                                                            0.178412
# SUM Neg                                                                            0.638180
# TOTAL                                                                              0.258217
# gdp_2017                                                                          -0.309849
# gdp_per_capita                                                                     0.117426
#
#                                                     Address risk       %.3  \
# total_population                                       -0.024486 -0.027878
# victims_per_1000_population                            -0.433439 -0.429783
# Factor One Governance Issues                           -0.654304 -0.653175
# Factor Two Nourishment and Access                      -0.512497 -0.507123
# Factor Three Inequality                                -0.186228 -0.183793
# Factor Four Disenfranchised Groups                     -0.296502 -0.293005
# Factor Five Effects of Conflict                        -0.281717 -0.280085
# Final overall (normalised, weighted) vulnerabil...     -0.619119 -0.616015
# Support survivors                                       0.553307  0.552650
# %                                                       0.554474  0.553869
# Criminal justice                                        0.601376  0.600943
# %.1                                                     0.601132  0.600583
# Coordination                                            0.538540  0.538331
# %.2                                                     0.540566  0.540345
# NEG Government  complicity (1.4.3)                      0.279984  0.278712
# NEG State-imposed forced labour (1.8.1)                 0.133523  0.132446
# Address risk                                            1.000000  0.999736
# %.3                                                     0.999736  1.000000
# Supply chains                                           0.363790  0.361322
# %.4                                                     0.363402  0.360830
# SUM/104                                                 0.797723  0.797290
# SUM Neg                                                 0.284129  0.282613
# TOTAL                                                   0.790079  0.789397
# gdp_2017                                                0.099782  0.096007
# gdp_per_capita                                          0.313803  0.310906
#
#                                                     Supply chains       %.4  \
# total_population                                         0.136807  0.136065
# victims_per_1000_population                             -0.225352 -0.223516
# Factor One Governance Issues                            -0.568315 -0.556321
# Factor Two Nourishment and Access                       -0.388911 -0.379675
# Factor Three Inequality                                 -0.316282 -0.301033
# Factor Four Disenfranchised Groups                      -0.275253 -0.284219
# Factor Five Effects of Conflict                         -0.217287 -0.206706
# Final overall (normalised, weighted) vulnerabil...      -0.544367 -0.532535
# Support survivors                                        0.411375  0.410467
# %                                                        0.412262  0.411145
# Criminal justice                                         0.385983  0.384803
# %.1                                                      0.384284  0.383687
# Coordination                                             0.467712  0.458853
# %.2                                                      0.466977  0.458610
# NEG Government  complicity (1.4.3)                       0.282058  0.274070
# NEG State-imposed forced labour (1.8.1)                 -0.036836 -0.040235
# Address risk                                             0.363790  0.363402
# %.3                                                      0.361322  0.360830
# Supply chains                                            1.000000  0.997484
# %.4                                                      0.997484  1.000000
# SUM/104                                                  0.517562  0.515405
# SUM Neg                                                  0.204033  0.196124
# TOTAL                                                    0.514775  0.511535
# gdp_2017                                                 0.548036  0.557853
# gdp_per_capita                                           0.459658  0.452631
#
#                                                      SUM/104   SUM Neg  \
# total_population                                    0.012674 -0.147079
# victims_per_1000_population                        -0.495304 -0.374461
# Factor One Governance Issues                       -0.793348 -0.467201
# Factor Two Nourishment and Access                  -0.551958 -0.297761
# Factor Three Inequality                            -0.301413 -0.235158
# Factor Four Disenfranchised Groups                 -0.340489 -0.123979
# Factor Five Effects of Conflict                    -0.256779 -0.409693
# Final overall (normalised, weighted) vulnerabil... -0.725469 -0.470051
# Support survivors                                   0.892121  0.326493
# %                                                   0.892567  0.325014
# Criminal justice                                    0.856755  0.258687
# %.1                                                 0.858384  0.258716
# Coordination                                        0.750396  0.332715
# %.2                                                 0.751740  0.330895
# NEG Government  complicity (1.4.3)                  0.347391  0.882729
# NEG State-imposed forced labour (1.8.1)             0.178412  0.638180
# Address risk                                        0.797723  0.284129
# %.3                                                 0.797290  0.282613
# Supply chains                                       0.517562  0.204033
# %.4                                                 0.515405  0.196124
# SUM/104                                             1.000000  0.358647
# SUM Neg                                             0.358647  1.000000
# TOTAL                                               0.990964  0.479666
# gdp_2017                                            0.212494 -0.126451
# gdp_per_capita                                      0.429266  0.300353
#
#                                                        TOTAL  gdp_2017  \
# total_population                                   -0.009310  0.566135
# victims_per_1000_population                        -0.518656 -0.146913
# Factor One Governance Issues                       -0.811843 -0.202034
# Factor Two Nourishment and Access                  -0.563115 -0.156296
# Factor Three Inequality                            -0.317171 -0.164316
# Factor Four Disenfranchised Groups                 -0.337296 -0.220592
# Factor Five Effects of Conflict                    -0.300173  0.070621
# Final overall (normalised, weighted) vulnerabil... -0.749134 -0.194626
# Support survivors                                   0.885453  0.193718
# %                                                   0.885650  0.195107
# Criminal justice                                    0.842685  0.178455
# %.1                                                 0.844751  0.178787
# Coordination                                        0.752256  0.142218
# %.2                                                 0.753237  0.140856
# NEG Government  complicity (1.4.3)                  0.452647  0.028235
# NEG State-imposed forced labour (1.8.1)             0.258217 -0.309849
# Address risk                                        0.790079  0.099782
# %.3                                                 0.789397  0.096007
# Supply chains                                       0.514775  0.548036
# %.4                                                 0.511535  0.557853
# SUM/104                                             0.990964  0.212494
# SUM Neg                                             0.479666 -0.126451
# TOTAL                                               1.000000  0.180930
# gdp_2017                                            0.180930  1.000000
# gdp_per_capita                                      0.446366  0.241985
#
#                                                     gdp_per_capita
# total_population                                         -0.055574
# victims_per_1000_population                              -0.378734
# Factor One Governance Issues                             -0.689694
# Factor Two Nourishment and Access                        -0.514765
# Factor Three Inequality                                  -0.606840
# Factor Four Disenfranchised Groups                       -0.633496
# Factor Five Effects of Conflict                          -0.359601
# Final overall (normalised, weighted) vulnerabil...       -0.770620
# Support survivors                                         0.426024
# %                                                         0.425282
# Criminal justice                                          0.306456
# %.1                                                       0.304527
# Coordination                                              0.304098
# %.2                                                       0.304289
# NEG Government  complicity (1.4.3)                        0.310449
# NEG State-imposed forced labour (1.8.1)                   0.117426
# Address risk                                              0.313803
# %.3                                                       0.310906
# Supply chains                                             0.459658
# %.4                                                       0.452631
# SUM/104                                                   0.429266
# SUM Neg                                                   0.300353
# TOTAL                                                     0.446366
# gdp_2017                                                  0.241985
# gdp_per_capita                                            1.000000
#
# [25 rows x 25 columns]

# %%
reunion_new = reunion[["Country", "gdp_per_capita", "victims_per_1000_population"]].copy()
reunion_new
# Out:
#                       Country  gdp_per_capita  victims_per_1000_population
# 0                     Burundi           311.0                         40.0
# 1    Central African Republic           456.0                         22.3
# 3                  Mauritania          1616.0                         21.4
# 4                    Pakistan          1608.0                         16.8
# 5                    Cambodia          1429.0                         16.8
# ..                        ...             ...                          ...
# 136                     Chile         15597.0                          0.8
# 137                 Australia         55888.0                          0.6
# 138               New Zealand         44511.0                          0.6
# 139                    Canada         45894.0                          0.5
# 140                     Japan         38030.0                          0.3
#
# [139 rows x 3 columns]

# %%
reunion_new.corr()
# Out:
#                              gdp_per_capita  victims_per_1000_population
# gdp_per_capita                     1.000000                    -0.378734
# victims_per_1000_population       -0.378734                     1.000000

# %%
# histogram of the GDP per capita
import matplotlib.pyplot as plt
plt.style.use('ggplot')
reunion_new.gdp_per_capita.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of GDP per capita', size=24)
plt.xlabel('GDP per Capita', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# histogram of victims per 1000 people
import matplotlib.pyplot as plt
plt.style.use('ggplot')
reunion_new.victims_per_1000_population.plot(kind='hist', color='purple', edgecolor='black', figsize=(10,7))
plt.title('Distribution of Victims per 1000 people', size=24)
plt.xlabel('Victims per 1000 people', size=18)
plt.ylabel('Frequency', size=18)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = sm.add_constant(reunion_new.gdp_per_capita)
model = sm.OLS(reunion_new.victims_per_1000_population,x)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     victims_per_1000_population   R-squared:                       0.143
# Model:                                     OLS   Adj. R-squared:                  0.137
# Method:                          Least Squares   F-statistic:                     22.94
# Date:                         Fri, 10 Jul 2020   Prob (F-statistic):           4.28e-06
# Time:                                 18:59:28   Log-Likelihood:                -404.09
# No. Observations:                          139   AIC:                             812.2
# Df Residuals:                              137   BIC:                             818.0
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              6.3889      0.472     13.528      0.000       5.455       7.323
# gdp_per_capita -8.709e-05   1.82e-05     -4.790      0.000      -0.000   -5.11e-05
# ==============================================================================
# Omnibus:                      152.765   Durbin-Watson:                   0.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3673.761
# Skew:                           3.987   Prob(JB):                         0.00
# Kurtosis:                      26.890   Cond. No.                     3.24e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.24e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
reunion_new = reunion_new.assign(gdp_per_capita2=reunion_new["gdp_per_capita"] ** 2)

# %%
x_q = sm.add_constant(reunion_new[["gdp_per_capita", "gdp_per_capita2"]])
model_q = sm.OLS(reunion_new["victims_per_1000_population"],x_q)
results_q = model_q.fit()
print(results_q.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     victims_per_1000_population   R-squared:                       0.195
# Model:                                     OLS   Adj. R-squared:                  0.183
# Method:                          Least Squares   F-statistic:                     16.46
# Date:                         Fri, 10 Jul 2020   Prob (F-statistic):           3.96e-07
# Time:                                 18:59:28   Log-Likelihood:                -399.78
# No. Observations:                          139   AIC:                             805.6
# Df Residuals:                              136   BIC:                             814.4
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               7.1971      0.535     13.450      0.000       6.139       8.255
# gdp_per_capita     -0.0002   4.73e-05     -4.574      0.000      -0.000      -0.000
# gdp_per_capita2  1.785e-09   6.05e-10      2.948      0.004    5.88e-10    2.98e-09
# ==============================================================================
# Omnibus:                      153.794   Durbin-Watson:                   0.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3860.866
# Skew:                           4.008   Prob(JB):                         0.00
# Kurtosis:                      27.543   Cond. No.                     2.56e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#reunion_new.to_csv(r'C:\Ironhack\visualizing_real_world_data\visualizing_real_world_data\Data\gdp_per_capita.csv')
