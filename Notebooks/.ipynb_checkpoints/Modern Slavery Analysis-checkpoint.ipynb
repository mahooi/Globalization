# %% [markdown]
# # Merge csv files on Country key (clean_slavery_index, gdp_per_capita, access_to_education)

# %% [markdown]
# Load final csv file to df and clean columns/rows/datatypes (check just in case)
# #final_df.to_csv(r'C:\Users\user\data_analysis_project\visualizing_real_world_data\Data\final_dataset.csv')

# %% [markdown]
# Do the correlations for victims_in_1000 based on: gdp_per_capita, access_to_education, violence_index, HDI_rank

# %% [markdown]
# 1. Do the scatter plots; => 2. Run correlations; => 3. Run the 4 Regressions; => 4. Run OLS1; => 5. Observe low R squared value
#
# # Reduce the sample to the first approx. 30% of the countries by slavery_index
#
# 1. Do the scatter plots - part 2; => 2. Run correlations - part 2; 3. Run the 4 Regressions - part 2; 4. Run OLS - part 2
#
# => !!5. Hope to GOD R squared si closer to 1 :D!!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# # 1. Load Access to education Dataset

# %%
education = pd.read_csv("..//data/access_to_education_index.csv",sep=';')

# %%
education.columns
# Out:
# Index(['HDI Rank', 'Country', '1980', '1985', '1990', '1995', '2000', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
# 1.2 New Data Frame with selected columns

# %%
education_newdf = education[["Country","2013", "HDI Rank"]].copy()
education_newdf.rename(columns={"Country": "country", "2013": "education_access_score", "HDI Rank" : "hdi_rank"}, inplace=True)
education_newdf = education_newdf.replace("..", np.nan)
education_newdf.dropna(inplace=True)
education_newdf["education_access_score"] = education_newdf["education_access_score"].astype("str")
education_newdf["education_access_score"] = education_newdf["education_access_score"].str.replace("," , ".")
education_newdf = education_newdf.astype({"education_access_score" :float})
print(education_newdf, education_newdf.dtypes)
# Out:
#                                 country  education_access_score  hdi_rank
# 0                           Afghanistan                0.365333     169.0
# 1                               Albania                0.608519      95.0
# 2                               Algeria                0.642589      93.0
# 3                               Andorra                0.670287      37.0
# 4                                Angola                0.474212     149.0
# ..                                  ...                     ...       ...
# 190  Venezuela (Bolivarian Republic of)                0.682483      67.0
# 191                             Vietnam                0.513489     121.0
# 192                               Yemen                0.339222     154.0
# 193                              Zambia                0.591333     141.0
# 194                            Zimbabwe                0.499933     156.0
#
# [187 rows x 3 columns] country                    object
# education_access_score    float64
# hdi_rank                  float64
# dtype: object

# %% [markdown]
# # 2. Load Slavery Index Dataset

# %%
slavery_index = pd.read_csv("..//Data/clean_slavery_index.csv", header=1)

slavery_index.head()
# Out:
#                                  Country   \
# 0  Korea, Democratic People's Republic of
# 1                                 Eritrea
# 2                                 Burundi
# 3                Central African Republic
# 4                             Afghanistan
#
#   Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                         25,244,000
# 1                                          4,847,000
# 2                                         10,199,000
# 3                                          4,546,000
# 4                                         33,736,000
#
#                  Region  \
# 0  Asia and the Pacific
# 1                Africa
# 2                Africa
# 3                Africa
# 4  Asia and the Pacific
#
#    Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                              104.6
# 1                                               93.0
# 2                                               40.0
# 3                                               22.3
# 4                                               22.2
#
#   Est. number of people in modern slavery  Factor One Governance Issues   \
# 0                               2,640,000                           87.6
# 1                                 451,000                           71.0
# 2                                 408,000                           72.4
# 3                                 101,000                           85.4
# 4                                 749,000                           81.0
#
#    Factor Two Nourishment and Access   Factor Three Inequality  \
# 0                                52.0                     30.3
# 1                                50.6                     33.7
# 2                                42.6                     42.1
# 3                                50.2                     62.7
# 4                                41.3                     64.7
#
#    Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                32.4                             12.3  ...
# 1                                48.1                             25.9  ...
# 2                                48.1                             41.7  ...
# 3                                58.0                             81.6  ...
# 4                                46.0                             92.6  ...
#
#    NEG Government  complicity (1.4.3)  \
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
# 3                                -1.0
# 4                                 NaN
#
#    NEG State-imposed forced labour (1.8.1)  Address risk   %.3  Supply chains  \
# 0                                     -1.0           0.3   4.8            0.0
# 1                                     -1.0           1.5  21.4            0.0
# 2                                     -1.0           1.8  26.2            0.0
# 3                                      0.0           1.5  21.4            0.0
# 4                                      NaN           NaN   NaN            NaN
#
#    %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0  0.0      0.4     -2.0   -5.6              D
# 1  0.0      1.4     -2.0   -2.0              D
# 2  0.0      5.0     -2.0   10.7              C
# 3  0.0      1.7     -1.0    2.5              D
# 4  NaN      NaN      NaN    NaN            NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# # Remove white space at the end of string

# %%
slavery_index.columns = slavery_index.columns.str.strip()
slavery_index.columns
# Out:
# Index(['Country',
#        'Population \n(from United Nations Population Division, World Population Prospects)',
#        'Region',
#        'Est. prevalence of population in modern slavery (victims per 1,000 population)',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %% [markdown]
# # Rename columns

# %%
slavery_index.rename(columns={"Est. prevalence of population in modern slavery (victims per 1,000 population)": "victims_per_1000_population"}, inplace=True)
slavery_index = slavery_index.rename({"Country" : "country"},axis=1)

slavery_index.rename(columns={"Population \n(from United Nations Population Division, World Population Prospects)": "total_population"}, inplace=True)

slavery_index.rename(columns={"Factor Five Effects of Conflict": "factor_five_effects_of_conflict"}, inplace=True)

slavery_index.rename(columns={"Criminal justice": "criminal_justice"}, inplace=True)

slavery_index.rename(columns={"Factor One Governance Issues":"factor_one_governance_issues"}, inplace=True)

slavery_index.rename(columns={"Factor Three Inequality":"factor_three_inequality"}, inplace=True)

# %%
slavery_index["total_population"] = slavery_index["total_population"].astype('str') 
slavery_index["total_population"] = slavery_index["total_population"].str.replace(',','')
slavery_index = slavery_index.astype({"total_population" :float})

# %%
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].astype('str')
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace(",","")
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace("<","")
slavery_index = slavery_index.astype({"Est. number of people in modern slavery" :float})
slavery_index.columns
# Out:
# Index(['country', 'total_population', 'Region', 'victims_per_1000_population',
#        'Est. number of people in modern slavery',
#        'factor_one_governance_issues', 'Factor Two Nourishment and Access',
#        'factor_three_inequality', 'Factor Four Disenfranchised Groups',
#        'factor_five_effects_of_conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'criminal_justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %% [markdown]
# # 3. Load GDP Dataset

# %%
gdp_df = pd.read_csv("../data/gdp_per_capita.csv")
gdp_df.head()
# Out:
#    Unnamed: 0                   Country  gdp_per_capita  \
# 0           0                   Burundi           311.0
# 1           1  Central African Republic           456.0
# 2           3                Mauritania          1616.0
# 3           4                  Pakistan          1608.0
# 4           5                  Cambodia          1429.0
#
#    victims_per_1000_population  gdp_per_capita2
# 0                         40.0          96721.0
# 1                         22.3         207936.0
# 2                         21.4        2611456.0
# 3                         16.8        2585664.0
# 4                         16.8        2042041.0

# %% [markdown]
# # Rename columns names

# %%
gdp_df = gdp_df.rename({"Country" : "country"},axis=1)
gdp_df
# Out:
#      Unnamed: 0                   country  gdp_per_capita  \
# 0             0                   Burundi           311.0
# 1             1  Central African Republic           456.0
# 2             3                Mauritania          1616.0
# 3             4                  Pakistan          1608.0
# 4             5                  Cambodia          1429.0
# ..          ...                       ...             ...
# 134         136                     Chile         15597.0
# 135         137                 Australia         55888.0
# 136         138               New Zealand         44511.0
# 137         139                    Canada         45894.0
# 138         140                     Japan         38030.0
#
#      victims_per_1000_population  gdp_per_capita2
# 0                           40.0     9.672100e+04
# 1                           22.3     2.079360e+05
# 2                           21.4     2.611456e+06
# 3                           16.8     2.585664e+06
# 4                           16.8     2.042041e+06
# ..                           ...              ...
# 134                          0.8     2.432664e+08
# 135                          0.6     3.123469e+09
# 136                          0.6     1.981229e+09
# 137                          0.5     2.106259e+09
# 138                          0.3     1.446281e+09
#
# [139 rows x 5 columns]

# %% [markdown]
# # 4. Merge 3 Datasets (Access to education, Slavery Index, GDP)

# %%
merge_2dsets = pd.merge(slavery_index, education_newdf,on="country")

# %%
merge_3dsets = pd.merge(merge_2dsets, gdp_df, on="country")
merge_3dsets
# Out:
#                       country  total_population                Region  \
# 0                     Burundi        10199000.0                Africa
# 1    Central African Republic         4546000.0                Africa
# 2                  Mauritania         4182000.0                Africa
# 3                    Pakistan       189381000.0  Asia and the Pacific
# 4                    Cambodia        15518000.0  Asia and the Pacific
# ..                        ...               ...                   ...
# 133                     Chile        17763000.0              Americas
# 134                 Australia        23800000.0  Asia and the Pacific
# 135               New Zealand         4615000.0  Asia and the Pacific
# 136                    Canada        35950000.0              Americas
# 137                     Japan       127975000.0  Asia and the Pacific
#
#      victims_per_1000_population_x  Est. number of people in modern slavery  \
# 0                             40.0                                 408000.0
# 1                             22.3                                 101000.0
# 2                             21.4                                  90000.0
# 3                             16.8                                3186000.0
# 4                             16.8                                 261000.0
# ..                             ...                                      ...
# 133                            0.8                                  14000.0
# 134                            0.6                                  15000.0
# 135                            0.6                                   3000.0
# 136                            0.5                                  17000.0
# 137                            0.3                                  37000.0
#
#      factor_one_governance_issues  Factor Two Nourishment and Access  \
# 0                            72.4                               42.6
# 1                            85.4                               50.2
# 2                            67.3                               33.7
# 3                            56.8                               36.2
# 4                            66.3                               38.5
# ..                            ...                                ...
# 133                          28.5                               13.8
# 134                          11.9                               15.7
# 135                          12.2                               18.4
# 136                          16.6                               20.7
# 137                          21.5                               13.1
#
#      factor_three_inequality  Factor Four Disenfranchised Groups  \
# 0                       42.1                                48.1
# 1                       62.7                                58.0
# 2                       39.3                                50.5
# 3                       45.9                                55.3
# 4                       41.6                                56.7
# ..                       ...                                 ...
# 133                     50.0                                23.5
# 134                     20.7                                12.0
# 135                     16.2                                 7.0
# 136                     20.1                                 9.2
# 137                     15.5                                31.9
#
#      factor_five_effects_of_conflict  ...  SUM/104  SUM Neg  TOTAL  \
# 0                               41.7  ...      5.0     -2.0   10.7
# 1                               81.6  ...      1.7     -1.0    2.5
# 2                               22.3  ...      5.3     -1.0   15.5
# 3                               92.8  ...      6.2     -1.0   18.6
# 4                               14.8  ...     10.5      0.0   37.6
# ..                               ...  ...      ...      ...    ...
# 133                             20.3  ...     17.5      0.0   62.3
# 134                             13.0  ...     17.9      0.0   63.8
# 135                              7.0  ...     16.1      0.0   57.6
# 136                             21.5  ...     16.4      0.0   58.6
# 137                             17.8  ...     11.3     -1.0   36.6
#
#      Credit rating  education_access_score  hdi_rank  Unnamed: 0  \
# 0                C                0.370089     180.0           0
# 1                D                0.317867     185.0           1
# 2                C                0.352278     161.0           3
# 3                C                0.371667     146.0           4
# 4              CCC                0.495178     136.0           5
# ..             ...                     ...       ...         ...
# 133            BBB                0.745675      41.0         136
# 134            BBB                0.926536       2.0         137
# 135             BB                0.916767       7.0         138
# 136             BB                0.850300       8.0         139
# 137            CCC                0.808000      17.0         140
#
#      gdp_per_capita  victims_per_1000_population_y  gdp_per_capita2
# 0             311.0                           40.0     9.672100e+04
# 1             456.0                           22.3     2.079360e+05
# 2            1616.0                           21.4     2.611456e+06
# 3            1608.0                           16.8     2.585664e+06
# 4            1429.0                           16.8     2.042041e+06
# ..              ...                            ...              ...
# 133         15597.0                            0.8     2.432664e+08
# 134         55888.0                            0.6     3.123469e+09
# 135         44511.0                            0.6     1.981229e+09
# 136         45894.0                            0.5     2.106259e+09
# 137         38030.0                            0.3     1.446281e+09
#
# [138 rows x 33 columns]

# %%
# Drop the NaN values

# %%
merge_3dsets = merge_3dsets.copy()
merge_3dsets.dropna(inplace=True)
merge_3dsets.rename(columns={"victims_per_1000_population_x": "victims_per_1000_population"}, inplace=True)

# %%
merge_3dsets.drop(columns=["victims_per_1000_population_y", "Unnamed: 0"],inplace=True)

# %%
merge_3dsets
# Out:
#                       country  total_population                Region  \
# 0                     Burundi        10199000.0                Africa
# 1    Central African Republic         4546000.0                Africa
# 2                  Mauritania         4182000.0                Africa
# 3                    Pakistan       189381000.0  Asia and the Pacific
# 4                    Cambodia        15518000.0  Asia and the Pacific
# ..                        ...               ...                   ...
# 133                     Chile        17763000.0              Americas
# 134                 Australia        23800000.0  Asia and the Pacific
# 135               New Zealand         4615000.0  Asia and the Pacific
# 136                    Canada        35950000.0              Americas
# 137                     Japan       127975000.0  Asia and the Pacific
#
#      victims_per_1000_population  Est. number of people in modern slavery  \
# 0                           40.0                                 408000.0
# 1                           22.3                                 101000.0
# 2                           21.4                                  90000.0
# 3                           16.8                                3186000.0
# 4                           16.8                                 261000.0
# ..                           ...                                      ...
# 133                          0.8                                  14000.0
# 134                          0.6                                  15000.0
# 135                          0.6                                   3000.0
# 136                          0.5                                  17000.0
# 137                          0.3                                  37000.0
#
#      factor_one_governance_issues  Factor Two Nourishment and Access  \
# 0                            72.4                               42.6
# 1                            85.4                               50.2
# 2                            67.3                               33.7
# 3                            56.8                               36.2
# 4                            66.3                               38.5
# ..                            ...                                ...
# 133                          28.5                               13.8
# 134                          11.9                               15.7
# 135                          12.2                               18.4
# 136                          16.6                               20.7
# 137                          21.5                               13.1
#
#      factor_three_inequality  Factor Four Disenfranchised Groups  \
# 0                       42.1                                48.1
# 1                       62.7                                58.0
# 2                       39.3                                50.5
# 3                       45.9                                55.3
# 4                       41.6                                56.7
# ..                       ...                                 ...
# 133                     50.0                                23.5
# 134                     20.7                                12.0
# 135                     16.2                                 7.0
# 136                     20.1                                 9.2
# 137                     15.5                                31.9
#
#      factor_five_effects_of_conflict  ...  Supply chains  %.4  SUM/104  \
# 0                               41.7  ...            0.0  0.0      5.0
# 1                               81.6  ...            0.0  0.0      1.7
# 2                               22.3  ...            0.0  0.0      5.3
# 3                               92.8  ...            0.0  0.0      6.2
# 4                               14.8  ...            0.0  0.0     10.5
# ..                               ...  ...            ...  ...      ...
# 133                             20.3  ...            0.0  0.0     17.5
# 134                             13.0  ...            0.0  0.0     17.9
# 135                              7.0  ...            0.0  0.0     16.1
# 136                             21.5  ...            0.0  0.0     16.4
# 137                             17.8  ...            0.0  0.0     11.3
#
#      SUM Neg  TOTAL  Credit rating  education_access_score  hdi_rank  \
# 0       -2.0   10.7              C                0.370089     180.0
# 1       -1.0    2.5              D                0.317867     185.0
# 2       -1.0   15.5              C                0.352278     161.0
# 3       -1.0   18.6              C                0.371667     146.0
# 4        0.0   37.6            CCC                0.495178     136.0
# ..       ...    ...            ...                     ...       ...
# 133      0.0   62.3            BBB                0.745675      41.0
# 134      0.0   63.8            BBB                0.926536       2.0
# 135      0.0   57.6             BB                0.916767       7.0
# 136      0.0   58.6             BB                0.850300       8.0
# 137     -1.0   36.6            CCC                0.808000      17.0
#
#      gdp_per_capita  gdp_per_capita2
# 0             311.0     9.672100e+04
# 1             456.0     2.079360e+05
# 2            1616.0     2.611456e+06
# 3            1608.0     2.585664e+06
# 4            1429.0     2.042041e+06
# ..              ...              ...
# 133         15597.0     2.432664e+08
# 134         55888.0     3.123469e+09
# 135         44511.0     1.981229e+09
# 136         45894.0     2.106259e+09
# 137         38030.0     1.446281e+09
#
# [138 rows x 31 columns]

# %%
#merge_3dsets.to_csv(r"C:\Users\user\data_analysis_project\visualizing_real_world_data\Data\merged_dataset.csv")

# %%
merge_3dsets.dtypes
# Out:
# country                                                      object
# total_population                                            float64
# Region                                                       object
# victims_per_1000_population                                 float64
# Est. number of people in modern slavery                     float64
# factor_one_governance_issues                                float64
# Factor Two Nourishment and Access                           float64
# factor_three_inequality                                     float64
# Factor Four Disenfranchised Groups                          float64
# factor_five_effects_of_conflict                             float64
# Final overall (normalised, weighted) vulnerability score    float64
# Support survivors                                           float64
# %                                                           float64
# criminal_justice                                            float64
# %.1                                                         float64
# Coordination                                                float64
# %.2                                                         float64
# NEG Government  complicity (1.4.3)                          float64
# NEG State-imposed forced labour (1.8.1)                     float64
# Address risk                                                float64
# %.3                                                         float64
# Supply chains                                               float64
# %.4                                                         float64
# SUM/104                                                     float64
# SUM Neg                                                     float64
# TOTAL                                                       float64
# Credit rating                                                object
# education_access_score                                      float64
# hdi_rank                                                    float64
# gdp_per_capita                                              float64
# gdp_per_capita2                                             float64
# dtype: object

# %%
merge_3dsets[["victims_per_1000_population",
              "factor_one_governance_issues",
              "factor_three_inequality",
              "factor_five_effects_of_conflict",
              "gdp_per_capita",
              "education_access_score",
              "hdi_rank",
              "criminal_justice"]].corr(method='pearson')
# Out:
#                                  victims_per_1000_population  \
# victims_per_1000_population                         1.000000
# factor_one_governance_issues                        0.522369
# factor_three_inequality                             0.210582
# factor_five_effects_of_conflict                     0.355543
# gdp_per_capita                                     -0.380121
# education_access_score                             -0.486700
# hdi_rank                                            0.510094
# criminal_justice                                   -0.418467
#
#                                  factor_one_governance_issues  \
# victims_per_1000_population                          0.522369
# factor_one_governance_issues                         1.000000
# factor_three_inequality                              0.471129
# factor_five_effects_of_conflict                      0.418644
# gdp_per_capita                                      -0.689256
# education_access_score                              -0.720322
# hdi_rank                                             0.736616
# criminal_justice                                    -0.632332
#
#                                  factor_three_inequality  \
# victims_per_1000_population                     0.210582
# factor_one_governance_issues                    0.471129
# factor_three_inequality                         1.000000
# factor_five_effects_of_conflict                 0.269874
# gdp_per_capita                                 -0.606970
# education_access_score                         -0.486627
# hdi_rank                                        0.541685
# criminal_justice                               -0.251043
#
#                                  factor_five_effects_of_conflict  \
# victims_per_1000_population                             0.355543
# factor_one_governance_issues                            0.418644
# factor_three_inequality                                 0.269874
# factor_five_effects_of_conflict                         1.000000
# gdp_per_capita                                         -0.363931
# education_access_score                                 -0.413569
# hdi_rank                                                0.395833
# criminal_justice                                       -0.167321
#
#                                  gdp_per_capita  education_access_score  \
# victims_per_1000_population           -0.380121               -0.486700
# factor_one_governance_issues          -0.689256               -0.720322
# factor_three_inequality               -0.606970               -0.486627
# factor_five_effects_of_conflict       -0.363931               -0.413569
# gdp_per_capita                         1.000000                0.639031
# education_access_score                 0.639031                1.000000
# hdi_rank                              -0.747347               -0.945600
# criminal_justice                       0.308439                0.527980
#
#                                  hdi_rank  criminal_justice
# victims_per_1000_population      0.510094         -0.418467
# factor_one_governance_issues     0.736616         -0.632332
# factor_three_inequality          0.541685         -0.251043
# factor_five_effects_of_conflict  0.395833         -0.167321
# gdp_per_capita                  -0.747347          0.308439
# education_access_score          -0.945600          0.527980
# hdi_rank                         1.000000         -0.491626
# criminal_justice                -0.491626          1.000000

# %% [markdown]
# # Define Regression Function

# %%
def run_regression(df, y_col, X_cols):
    y = df[y_col]
    X = df[X_cols]
    X = sm.add_constant(X)
    
    l = sm.OLS(y, X)
    return l.fit()
# Dependant Variable
y_col= "victims_per_1000_population"

# Multiple regression function
run_regression(merge_3dsets, y_col, ["factor_five_effects_of_conflict",
                                     "education_access_score",
                                     "criminal_justice"]).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     victims_per_1000_population   R-squared:                       0.306
# Model:                                     OLS   Adj. R-squared:                  0.291
# Method:                          Least Squares   F-statistic:                     19.72
# Date:                         Sat, 11 Jul 2020   Prob (F-statistic):           1.19e-10
# Time:                                 22:39:09   Log-Likelihood:                -387.10
# No. Observations:                          138   AIC:                             782.2
# Df Residuals:                              134   BIC:                             793.9
# Df Model:                                    3
# Covariance Type:                     nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              11.2124      1.678      6.683      0.000       7.894      14.531
# factor_five_effects_of_conflict     0.0500      0.020      2.535      0.012       0.011       0.089
# education_access_score             -7.5084      2.484     -3.023      0.003     -12.421      -2.596
# criminal_justice                   -1.0347      0.369     -2.805      0.006      -1.764      -0.305
# ==============================================================================
# Omnibus:                      143.867   Durbin-Watson:                   0.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3275.418
# Skew:                           3.668   Prob(JB):                         0.00
# Kurtosis:                      25.712   Cond. No.                         272.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Plot 1
# ## Victims /1000 population - Factor Five Effects of Conflict

# %%
ax = sns.scatterplot(data=merge_3dsets,
                x="factor_five_effects_of_conflict",
                y="victims_per_1000_population");

# %%
ax= sns.regplot(data=merge_3dsets,
                x="factor_five_effects_of_conflict",
                y="victims_per_1000_population");

# %% [markdown]
# # Plot 2
# ## Victims /1000 population - Education Access Score

# %%
ax= sns.regplot(data=merge_3dsets,
                x="education_access_score",
                y="victims_per_1000_population");

# %% [markdown]
# # Plot 3
# ## Victims /1000 population - Criminal justice

# %%
ax= sns.regplot(data=merge_3dsets,
                x="criminal_justice",
                y="victims_per_1000_population");

# %% [markdown]
# # Plot 4
# ## GDP per Capita - Victims /1000 population

# %%
ax= sns.regplot(data=merge_3dsets,
                x="gdp_per_capita",
                y="victims_per_1000_population");
