# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# # 2. Access to Education Dataset

# %%
education = pd.read_csv("..//data/access_to_education_index.csv",sep=';')
education.dtypes
# Out:
# HDI Rank    float64
# Country      object
# 1980         object
# 1985         object
# 1990         object
# 1995         object
# 2000         object
# 2005         object
# 2006         object
# 2007         object
# 2008         object
# 2009         object
# 2010         object
# 2011         object
# 2012         object
# 2013         object
# dtype: object

# %%
education.head()
# Out:
#    HDI Rank      Country         1980         1985         1990         1995  \
# 0     169.0  Afghanistan       0,0761  0,103083333  0,121388889  0,175288889
# 1      95.0      Albania  0,540588889  0,527776677  0,537186688  0,528693858
# 2      93.0      Algeria  0,321377778  0,347177778  0,382388889  0,424366667
# 3      37.0      Andorra           ..           ..           ..           ..
# 4     149.0       Angola           ..           ..           ..           ..
#
#           2000         2005         2006         2007         2008  \
# 0  0,225522222       0,2974  0,308986667  0,320573333      0,33216
# 1  0,565465051   0,59467023  0,596323054  0,597975879  0,599628703
# 2  0,493488889  0,562566667  0,570237778  0,580686667      0,59808
# 3           ..           ..           ..           ..           ..
# 4  0,298712356  0,364684578  0,379923409   0,39516224  0,410401071
#
#           2009         2010         2011         2012         2013
# 0  0,343746667        0,357  0,365333333  0,365333333  0,365333333
# 1  0,600651723  0,601674743  0,608519363  0,608519363  0,608519363
# 2  0,615473333  0,631477778  0,642588889  0,642588889  0,642588889
# 3           ..  0,670286667  0,670286667  0,670286667  0,670286667
# 4  0,425639902  0,440878733  0,474212067  0,474212067  0,474212067

# %%
# Remove special character from the DataFrame
education=education.replace("..", np.nan)
education
# Out:
#      HDI Rank                             Country         1980         1985  \
# 0       169.0                         Afghanistan       0,0761  0,103083333
# 1        95.0                             Albania  0,540588889  0,527776677
# 2        93.0                             Algeria  0,321377778  0,347177778
# 3        37.0                             Andorra          NaN          NaN
# 4       149.0                              Angola          NaN          NaN
# ..        ...                                 ...          ...          ...
# 190      67.0  Venezuela (Bolivarian Republic of)  0,440501111      0,46065
# 191     121.0                             Vietnam  0,381288889  0,375522222
# 192     154.0                               Yemen          NaN          NaN
# 193     141.0                              Zambia  0,318833333  0,361711111
# 194     156.0                            Zimbabwe  0,288388889  0,449666667
#
#             1990         1995         2000         2005         2006  \
# 0    0,121388889  0,175288889  0,225522222       0,2974  0,308986667
# 1    0,537186688  0,528693858  0,565465051   0,59467023  0,596323054
# 2    0,382388889  0,424366667  0,493488889  0,562566667  0,570237778
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN  0,298712356  0,364684578  0,379923409
# ..           ...          ...          ...          ...          ...
# 190  0,452946667  0,474984444  0,513254544  0,594450532  0,617965815
# 191  0,349122222  0,387388889  0,434455556  0,470388889  0,478175556
# 192  0,218431389  0,229298056  0,257438889  0,304011111  0,306979259
# 193  0,375477778  0,457097917  0,487518056  0,537804861  0,545682222
# 194  0,423122222  0,456855556  0,471333333  0,483266667       0,4866
#
#             2007         2008         2009         2010         2011  \
# 0    0,320573333      0,33216  0,343746667        0,357  0,365333333
# 1    0,597975879  0,599628703  0,600651723  0,601674743  0,608519363
# 2    0,580686667      0,59808  0,615473333  0,631477778  0,642588889
# 3            NaN          NaN          NaN  0,670286667  0,670286667
# 4     0,39516224  0,410401071  0,425639902  0,440878733  0,474212067
# ..           ...          ...          ...          ...          ...
# 190  0,649559434  0,670028665   0,67421609  0,682482617  0,682482617
# 191  0,485962222  0,493748889  0,501535556  0,509322222  0,513488889
# 192  0,309947407  0,312915556  0,320513333  0,328111111  0,339222222
# 193  0,553559583  0,561436944  0,569314306  0,577191667  0,584262361
# 194  0,489933333  0,493266667       0,4966  0,499933333  0,499933333
#
#             2012         2013
# 0    0,365333333  0,365333333
# 1    0,608519363  0,608519363
# 2    0,642588889  0,642588889
# 3    0,670286667  0,670286667
# 4    0,474212067  0,474212067
# ..           ...          ...
# 190  0,682482617  0,682482617
# 191  0,513488889  0,513488889
# 192  0,339222222  0,339222222
# 193  0,591333333  0,591333333
# 194  0,499933333  0,499933333
#
# [195 rows x 16 columns]

# %% [markdown]
# ## 2.1 New Data Frame with selected columns

# %%
newdf= education[["Country","2013"]].copy()

# Remove special character from the DataFrame
newdf= newdf.replace("..", np.nan)

# Drop missing values
newdf.dropna(inplace=True)

#  Replace the comma into a full stop 
newdf= newdf.stack().str.replace(',','.').unstack()

print(newdf, newdf.dtypes)
# Out:
#                                 Country         2013
# 0                           Afghanistan  0.365333333
# 1                               Albania  0.608519363
# 2                               Algeria  0.642588889
# 3                               Andorra  0.670286667
# 4                                Angola  0.474212067
# ..                                  ...          ...
# 190  Venezuela (Bolivarian Republic of)  0.682482617
# 191                             Vietnam  0.513488889
# 192                               Yemen  0.339222222
# 193                              Zambia  0.591333333
# 194                            Zimbabwe  0.499933333
#
# [187 rows x 2 columns] Country    object
# 2013       object
# dtype: object

# %%
# Convert the series into a float
newdf=newdf.astype({"2013" :float})
newdf.dtypes
# Out:
# Country     object
# 2013       float64
# dtype: object

# %%
#Rename Column
newdf.rename(columns={"2013": "Education_Access_Score"}, inplace=True)

# %% [markdown]
# ## 2.2 Cleaned DataFrame

# %%
newdf.head()
# Out:
#        Country  Education_Access_Score
# 0  Afghanistan                0.365333
# 1      Albania                0.608519
# 2      Algeria                0.642589
# 3      Andorra                0.670287
# 4       Angola                0.474212

# %% [markdown]
# # 3. Slavery Index Dataset

# %%
slavery_index = pd.read_csv("..//Data/clean_slavery_index.csv", header=1)

slavery_index.head(3)
# Out:
#                                  Country   \
# 0  Korea, Democratic People's Republic of
# 1                                 Eritrea
# 2                                 Burundi
#
#   Population \n(from United Nations Population Division, World Population Prospects)  \
# 0                                         25,244,000
# 1                                          4,847,000
# 2                                         10,199,000
#
#                  Region  \
# 0  Asia and the Pacific
# 1                Africa
# 2                Africa
#
#    Est. prevalence of population in modern slavery (victims per 1,000 population)  \
# 0                                              104.6
# 1                                               93.0
# 2                                               40.0
#
#   Est. number of people in modern slavery  Factor One Governance Issues   \
# 0                               2,640,000                           87.6
# 1                                 451,000                           71.0
# 2                                 408,000                           72.4
#
#    Factor Two Nourishment and Access   Factor Three Inequality  \
# 0                                52.0                     30.3
# 1                                50.6                     33.7
# 2                                42.6                     42.1
#
#    Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                32.4                             12.3  ...
# 1                                48.1                             25.9  ...
# 2                                48.1                             41.7  ...
#
#    NEG Government  complicity (1.4.3)  \
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
#
#    NEG State-imposed forced labour (1.8.1)  Address risk   %.3  Supply chains  \
# 0                                     -1.0           0.3   4.8            0.0
# 1                                     -1.0           1.5  21.4            0.0
# 2                                     -1.0           1.8  26.2            0.0
#
#    %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0  0.0      0.4     -2.0   -5.6              D
# 1  0.0      1.4     -2.0   -2.0              D
# 2  0.0      5.0     -2.0   10.7              C
#
# [3 rows x 27 columns]

# %% [markdown]
# ## 3.1 Remove white space at the end of string

# %%
slavery_index.columns = slavery_index.columns.str.strip()
slavery_index.columns
# Out:
# Index(['Country',
#        'Population \n(from United Nations Population Division, World Population Prospects)',
#        'Region',
#        'Est. prevalence of population in modern slavery (victims per 1,000 population)',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %%
slavery_index.dtypes
# Out:
# Country                                                                                object
# Population \n(from United Nations Population Division, World Population Prospects)     object
# Region                                                                                 object
# Est. prevalence of population in modern slavery (victims per 1,000 population)        float64
# Est. number of people in modern slavery                                                object
# Factor One Governance Issues                                                          float64
# Factor Two Nourishment and Access                                                     float64
# Factor Three Inequality                                                               float64
# Factor Four Disenfranchised Groups                                                    float64
# Factor Five Effects of Conflict                                                       float64
# Final overall (normalised, weighted) vulnerability score                              float64
# Support survivors                                                                     float64
# %                                                                                     float64
# Criminal justice                                                                      float64
# %.1                                                                                   float64
# Coordination                                                                          float64
# %.2                                                                                   float64
# NEG Government  complicity (1.4.3)                                                    float64
# NEG State-imposed forced labour (1.8.1)                                               float64
# Address risk                                                                          float64
# %.3                                                                                   float64
# Supply chains                                                                         float64
# %.4                                                                                   float64
# SUM/104                                                                               float64
# SUM Neg                                                                               float64
# TOTAL                                                                                 float64
# Credit rating                                                                          object
# dtype: object

# %% [markdown]
# ## 3.2 Rename columns

# %%
slavery_index.rename(columns={"Est. prevalence of population in modern slavery (victims per 1,000 population)": "Victims_per_1000_population"}, inplace=True)

slavery_index.rename(columns={"Population \n(from United Nations Population Division, World Population Prospects)": "total_population"}, inplace=True)

# %%
slavery_index.columns
# Out:
# Index(['Country', 'total_population', 'Region', 'Victims_per_1000_population',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating'],
#       dtype='object')

# %% [markdown]
# # 4. 1st Model
# ## Merge `Slavery Index` with `Education` DataFrame

# %%
merged= pd.merge(slavery_index, newdf, on="Country" )
merged
# Out:
#                               Country total_population  \
# 0                             Eritrea        4,847,000
# 1                             Burundi       10,199,000
# 2            Central African Republic        4,546,000
# 3                         Afghanistan       33,736,000
# 4                          Mauritania        4,182,000
# ..                                ...              ...
# 163                       Saint Lucia          177,000
# 164                             Malta          428,000
# 165  Saint Vincent and the Grenadines          109,000
# 166                           Vanuatu          265,000
# 167                        Seychelles           94,000
#
#                       Region  Victims_per_1000_population  \
# 0                     Africa                         93.0
# 1                     Africa                         40.0
# 2                     Africa                         22.3
# 3       Asia and the Pacific                         22.2
# 4                     Africa                         21.4
# ..                       ...                          ...
# 163                 Americas                          NaN
# 164  Europe and Central Asia                          NaN
# 165                 Americas                          NaN
# 166     Asia and the Pacific                          NaN
# 167                   Africa                          NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   451,000                          71.0
# 1                                   408,000                          72.4
# 2                                   101,000                          85.4
# 3                                   749,000                          81.0
# 4                                    90,000                          67.3
# ..                                      ...                           ...
# 163                                     NaN                           NaN
# 164                                     NaN                           NaN
# 165                                     NaN                           NaN
# 166                                     NaN                           NaN
# 167                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 50.6                     33.7
# 1                                 42.6                     42.1
# 2                                 50.2                     62.7
# 3                                 41.3                     64.7
# 4                                 33.7                     39.3
# ..                                 ...                      ...
# 163                                NaN                      NaN
# 164                                NaN                      NaN
# 165                                NaN                      NaN
# 166                                NaN                      NaN
# 167                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             25.9  ...
# 1                                  48.1                             41.7  ...
# 2                                  58.0                             81.6  ...
# 3                                  46.0                             92.6  ...
# 4                                  50.5                             22.3  ...
# ..                                  ...                              ...  ...
# 163                                 NaN                              NaN  ...
# 164                                 NaN                              NaN  ...
# 165                                 NaN                              NaN  ...
# 166                                 NaN                              NaN  ...
# 167                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.5  21.4
# 1                                       -1.0           1.8  26.2
# 2                                        0.0           1.5  21.4
# 3                                        NaN           NaN   NaN
# 4                                        0.0           2.5  35.7
# ..                                       ...           ...   ...
# 163                                      NaN           NaN   NaN
# 164                                      NaN           NaN   NaN
# 165                                      NaN           NaN   NaN
# 166                                      NaN           NaN   NaN
# 167                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating  \
# 0              0.0  0.0      1.4     -2.0   -2.0              D
# 1              0.0  0.0      5.0     -2.0   10.7              C
# 2              0.0  0.0      1.7     -1.0    2.5              D
# 3              NaN  NaN      NaN      NaN    NaN            NaN
# 4              0.0  0.0      5.3     -1.0   15.5              C
# ..             ...  ...      ...      ...    ...            ...
# 163            NaN  NaN      NaN      NaN    NaN            NaN
# 164            NaN  NaN      NaN      NaN    NaN            NaN
# 165            NaN  NaN      NaN      NaN    NaN            NaN
# 166            NaN  NaN      NaN      NaN    NaN            NaN
# 167            NaN  NaN      NaN      NaN    NaN            NaN
#
#      Education_Access_Score
# 0                  0.227514
# 1                  0.370089
# 2                  0.317867
# 3                  0.365333
# 4                  0.352278
# ..                      ...
# 163                0.631431
# 164                0.732538
# 165                0.656834
# 166                0.595511
# 167                0.635929
#
# [168 rows x 28 columns]

# %% [markdown]
# ## 4.1 Show correlation table

# %%
merged.corr()
# Out:
#                                                     Victims_per_1000_population  \
# Victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.379444
# Factor Two Nourishment and Access                                      0.423225
# Factor Three Inequality                                                0.111686
# Factor Four Disenfranchised Groups                                     0.294802
# Factor Five Effects of Conflict                                        0.197003
# Final overall (normalised, weighted) vulnerabil...                     0.406846
# Support survivors                                                     -0.377257
# %                                                                     -0.376439
# Criminal justice                                                      -0.392226
# %.1                                                                   -0.391494
# Coordination                                                          -0.365449
# %.2                                                                   -0.364524
# NEG Government  complicity (1.4.3)                                    -0.234737
# NEG State-imposed forced labour (1.8.1)                               -0.355021
# Address risk                                                          -0.370284
# %.3                                                                   -0.369202
# Supply chains                                                         -0.159504
# %.4                                                                   -0.157498
# SUM/104                                                               -0.441590
# SUM Neg                                                               -0.363597
# TOTAL                                                                 -0.465029
# Education_Access_Score                                                -0.416617
#
#                                                     Factor One Governance Issues  \
# Victims_per_1000_population                                             0.379444
# Factor One Governance Issues                                            1.000000
# Factor Two Nourishment and Access                                       0.595208
# Factor Three Inequality                                                 0.502648
# Factor Four Disenfranchised Groups                                      0.468657
# Factor Five Effects of Conflict                                         0.460542
# Final overall (normalised, weighted) vulnerabil...                      0.929781
# Support survivors                                                      -0.718463
# %                                                                      -0.719307
# Criminal justice                                                       -0.643288
# %.1                                                                    -0.644600
# Coordination                                                           -0.593959
# %.2                                                                    -0.594188
# NEG Government  complicity (1.4.3)                                     -0.444631
# NEG State-imposed forced labour (1.8.1)                                -0.267512
# Address risk                                                           -0.658122
# %.3                                                                    -0.656610
# Supply chains                                                          -0.573796
# %.4                                                                    -0.561784
# SUM/104                                                                -0.794816
# SUM Neg                                                                -0.483502
# TOTAL                                                                  -0.814466
# Education_Access_Score                                                 -0.733245
#
#                                                     Factor Two Nourishment and Access  \
# Victims_per_1000_population                                                  0.423225
# Factor One Governance Issues                                                 0.595208
# Factor Two Nourishment and Access                                            1.000000
# Factor Three Inequality                                                      0.374382
# Factor Four Disenfranchised Groups                                           0.416182
# Factor Five Effects of Conflict                                              0.327446
# Final overall (normalised, weighted) vulnerabil...                           0.736855
# Support survivors                                                           -0.481210
# %                                                                           -0.480159
# Criminal justice                                                            -0.439673
# %.1                                                                         -0.439634
# Coordination                                                                -0.440369
# %.2                                                                         -0.442043
# NEG Government  complicity (1.4.3)                                          -0.345587
# NEG State-imposed forced labour (1.8.1)                                     -0.106736
# Address risk                                                                -0.523452
# %.3                                                                         -0.518601
# Supply chains                                                               -0.395159
# %.4                                                                         -0.385736
# SUM/104                                                                     -0.563055
# SUM Neg                                                                     -0.324523
# TOTAL                                                                       -0.575496
# Education_Access_Score                                                      -0.779522
#
#                                                     Factor Three Inequality  \
# Victims_per_1000_population                                        0.111686
# Factor One Governance Issues                                       0.502648
# Factor Two Nourishment and Access                                  0.374382
# Factor Three Inequality                                            1.000000
# Factor Four Disenfranchised Groups                                 0.436054
# Factor Five Effects of Conflict                                    0.372882
# Final overall (normalised, weighted) vulnerabil...                 0.649680
# Support survivors                                                 -0.278501
# %                                                                 -0.280180
# Criminal justice                                                  -0.251601
# %.1                                                               -0.250351
# Coordination                                                      -0.271686
# %.2                                                               -0.268109
# NEG Government  complicity (1.4.3)                                -0.284602
# NEG State-imposed forced labour (1.8.1)                            0.001839
# Address risk                                                      -0.182037
# %.3                                                               -0.179726
# Supply chains                                                     -0.318625
# %.4                                                               -0.303547
# SUM/104                                                           -0.298557
# SUM Neg                                                           -0.221779
# TOTAL                                                             -0.312195
# Education_Access_Score                                            -0.485061
#
#                                                     Factor Four Disenfranchised Groups  \
# Victims_per_1000_population                                                   0.294802
# Factor One Governance Issues                                                  0.468657
# Factor Two Nourishment and Access                                             0.416182
# Factor Three Inequality                                                       0.436054
# Factor Four Disenfranchised Groups                                            1.000000
# Factor Five Effects of Conflict                                               0.232622
# Final overall (normalised, weighted) vulnerabil...                            0.613947
# Support survivors                                                            -0.289656
# %                                                                            -0.289535
# Criminal justice                                                             -0.312353
# %.1                                                                          -0.314049
# Coordination                                                                 -0.274764
# %.2                                                                          -0.278307
# NEG Government  complicity (1.4.3)                                           -0.151045
# NEG State-imposed forced labour (1.8.1)                                      -0.041067
# Address risk                                                                 -0.301425
# %.3                                                                          -0.297696
# Supply chains                                                                -0.269741
# %.4                                                                          -0.279464
# SUM/104                                                                      -0.352921
# SUM Neg                                                                      -0.139008
# TOTAL                                                                        -0.351394
# Education_Access_Score                                                       -0.449591
#
#                                                     Factor Five Effects of Conflict  \
# Victims_per_1000_population                                                0.197003
# Factor One Governance Issues                                               0.460542
# Factor Two Nourishment and Access                                          0.327446
# Factor Three Inequality                                                    0.372882
# Factor Four Disenfranchised Groups                                         0.232622
# Factor Five Effects of Conflict                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                         0.630298
# Support survivors                                                         -0.211623
# %                                                                         -0.211027
# Criminal justice                                                          -0.147979
# %.1                                                                       -0.145110
# Coordination                                                              -0.111431
# %.2                                                                       -0.106631
# NEG Government  complicity (1.4.3)                                        -0.360252
# NEG State-imposed forced labour (1.8.1)                                   -0.213621
# Address risk                                                              -0.254158
# %.3                                                                       -0.253146
# Supply chains                                                             -0.217195
# %.4                                                                       -0.206653
# SUM/104                                                                   -0.228068
# SUM Neg                                                                   -0.390164
# TOTAL                                                                     -0.268848
# Education_Access_Score                                                    -0.410084
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# Victims_per_1000_population                                                                  0.406846
# Factor One Governance Issues                                                                 0.929781
# Factor Two Nourishment and Access                                                            0.736855
# Factor Three Inequality                                                                      0.649680
# Factor Four Disenfranchised Groups                                                           0.613947
# Factor Five Effects of Conflict                                                              0.630298
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# Support survivors                                                                           -0.651196
# %                                                                                           -0.651541
# Criminal justice                                                                            -0.585350
# %.1                                                                                         -0.585601
# Coordination                                                                                -0.546765
# %.2                                                                                         -0.546344
# NEG Government  complicity (1.4.3)                                                          -0.471877
# NEG State-imposed forced labour (1.8.1)                                                     -0.227035
# Address risk                                                                                -0.622873
# %.3                                                                                         -0.619768
# Supply chains                                                                               -0.551788
# %.4                                                                                         -0.539987
# SUM/104                                                                                     -0.729949
# SUM Neg                                                                                     -0.484311
# TOTAL                                                                                       -0.754005
# Education_Access_Score                                                                      -0.804421
#
#                                                     Support survivors  \
# Victims_per_1000_population                                 -0.377257
# Factor One Governance Issues                                -0.718463
# Factor Two Nourishment and Access                           -0.481210
# Factor Three Inequality                                     -0.278501
# Factor Four Disenfranchised Groups                          -0.289656
# Factor Five Effects of Conflict                             -0.211623
# Final overall (normalised, weighted) vulnerabil...          -0.651196
# Support survivors                                            1.000000
# %                                                            0.999876
# Criminal justice                                             0.710247
# %.1                                                          0.712385
# Coordination                                                 0.577469
# %.2                                                          0.576801
# NEG Government  complicity (1.4.3)                           0.315491
# NEG State-imposed forced labour (1.8.1)                      0.185547
# Address risk                                                 0.571494
# %.3                                                          0.570977
# Supply chains                                                0.423228
# %.4                                                          0.422001
# SUM/104                                                      0.897757
# SUM Neg                                                      0.340910
# TOTAL                                                        0.890594
# Education_Access_Score                                       0.595888
#
#                                                            %  \
# Victims_per_1000_population                        -0.376439
# Factor One Governance Issues                       -0.719307
# Factor Two Nourishment and Access                  -0.480159
# Factor Three Inequality                            -0.280180
# Factor Four Disenfranchised Groups                 -0.289535
# Factor Five Effects of Conflict                    -0.211027
# Final overall (normalised, weighted) vulnerabil... -0.651541
# Support survivors                                   0.999876
# %                                                   1.000000
# Criminal justice                                    0.710026
# %.1                                                 0.712154
# Coordination                                        0.577449
# %.2                                                 0.576822
# NEG Government  complicity (1.4.3)                  0.315203
# NEG State-imposed forced labour (1.8.1)             0.183192
# Address risk                                        0.572400
# %.3                                                 0.571926
# Supply chains                                       0.424052
# %.4                                                 0.422626
# SUM/104                                             0.898056
# SUM Neg                                             0.339491
# TOTAL                                               0.890667
# Education_Access_Score                              0.596111
#
#                                                     Criminal justice  ...  \
# Victims_per_1000_population                                -0.392226  ...
# Factor One Governance Issues                               -0.643288  ...
# Factor Two Nourishment and Access                          -0.439673  ...
# Factor Three Inequality                                    -0.251601  ...
# Factor Four Disenfranchised Groups                         -0.312353  ...
# Factor Five Effects of Conflict                            -0.147979  ...
# Final overall (normalised, weighted) vulnerabil...         -0.585350  ...
# Support survivors                                           0.710247  ...
# %                                                           0.710026  ...
# Criminal justice                                            1.000000  ...
# %.1                                                         0.999653  ...
# Coordination                                                0.586818  ...
# %.2                                                         0.586714  ...
# NEG Government  complicity (1.4.3)                          0.221510  ...
# NEG State-imposed forced labour (1.8.1)                     0.231919  ...
# Address risk                                                0.612633  ...
# %.3                                                         0.612278  ...
# Supply chains                                               0.392304  ...
# %.4                                                         0.390696  ...
# SUM/104                                                     0.863833  ...
# SUM Neg                                                     0.290865  ...
# TOTAL                                                       0.852355  ...
# Education_Access_Score                                      0.544045  ...
#
#                                                     NEG Government  complicity (1.4.3)  \
# Victims_per_1000_population                                                  -0.234737
# Factor One Governance Issues                                                 -0.444631
# Factor Two Nourishment and Access                                            -0.345587
# Factor Three Inequality                                                      -0.284602
# Factor Four Disenfranchised Groups                                           -0.151045
# Factor Five Effects of Conflict                                              -0.360252
# Final overall (normalised, weighted) vulnerabil...                           -0.471877
# Support survivors                                                             0.315491
# %                                                                             0.315203
# Criminal justice                                                              0.221510
# %.1                                                                           0.218370
# Coordination                                                                  0.333867
# %.2                                                                           0.331330
# NEG Government  complicity (1.4.3)                                            1.000000
# NEG State-imposed forced labour (1.8.1)                                       0.164971
# Address risk                                                                  0.278687
# %.3                                                                           0.277820
# Supply chains                                                                 0.285842
# %.4                                                                           0.277685
# SUM/104                                                                       0.343359
# SUM Neg                                                                       0.866136
# TOTAL                                                                         0.444153
# Education_Access_Score                                                        0.339317
#
#                                                     NEG State-imposed forced labour (1.8.1)  \
# Victims_per_1000_population                                                       -0.355021
# Factor One Governance Issues                                                      -0.267512
# Factor Two Nourishment and Access                                                 -0.106736
# Factor Three Inequality                                                            0.001839
# Factor Four Disenfranchised Groups                                                -0.041067
# Factor Five Effects of Conflict                                                   -0.213621
# Final overall (normalised, weighted) vulnerabil...                                -0.227035
# Support survivors                                                                  0.185547
# %                                                                                  0.183192
# Criminal justice                                                                   0.231919
# %.1                                                                                0.230707
# Coordination                                                                       0.164576
# %.2                                                                                0.164407
# NEG Government  complicity (1.4.3)                                                 0.164971
# NEG State-imposed forced labour (1.8.1)                                            1.000000
# Address risk                                                                       0.146865
# %.3                                                                                0.146013
# Supply chains                                                                     -0.007212
# %.4                                                                               -0.011222
# SUM/104                                                                            0.210349
# SUM Neg                                                                            0.635848
# TOTAL                                                                              0.286018
# Education_Access_Score                                                             0.096140
#
#                                                     Address risk       %.3  \
# Victims_per_1000_population                            -0.370284 -0.369202
# Factor One Governance Issues                           -0.658122 -0.656610
# Factor Two Nourishment and Access                      -0.523452 -0.518601
# Factor Three Inequality                                -0.182037 -0.179726
# Factor Four Disenfranchised Groups                     -0.301425 -0.297696
# Factor Five Effects of Conflict                        -0.254158 -0.253146
# Final overall (normalised, weighted) vulnerabil...     -0.622873 -0.619768
# Support survivors                                       0.571494  0.570977
# %                                                       0.572400  0.571926
# Criminal justice                                        0.612633  0.612278
# %.1                                                     0.613075  0.612731
# Coordination                                            0.561575  0.561523
# %.2                                                     0.562687  0.562642
# NEG Government  complicity (1.4.3)                      0.278687  0.277820
# NEG State-imposed forced labour (1.8.1)                 0.146865  0.146013
# Address risk                                            1.000000  0.999745
# %.3                                                     0.999745  1.000000
# Supply chains                                           0.372106  0.369387
# %.4                                                     0.371305  0.368495
# SUM/104                                                 0.805265  0.804930
# SUM Neg                                                 0.292507  0.291397
# TOTAL                                                   0.796952  0.796452
# Education_Access_Score                                  0.559672  0.556106
#
#                                                     Supply chains       %.4  \
# Victims_per_1000_population                             -0.159504 -0.157498
# Factor One Governance Issues                            -0.573796 -0.561784
# Factor Two Nourishment and Access                       -0.395159 -0.385736
# Factor Three Inequality                                 -0.318625 -0.303547
# Factor Four Disenfranchised Groups                      -0.269741 -0.279464
# Factor Five Effects of Conflict                         -0.217195 -0.206653
# Final overall (normalised, weighted) vulnerabil...      -0.551788 -0.539987
# Support survivors                                        0.423228  0.422001
# %                                                        0.424052  0.422626
# Criminal justice                                         0.392304  0.390696
# %.1                                                      0.393951  0.392812
# Coordination                                             0.464809  0.456012
# %.2                                                      0.464161  0.455811
# NEG Government  complicity (1.4.3)                       0.285842  0.277685
# NEG State-imposed forced labour (1.8.1)                 -0.007212 -0.011222
# Address risk                                             0.372106  0.371305
# %.3                                                      0.369387  0.368495
# Supply chains                                            1.000000  0.997488
# %.4                                                      0.997488  1.000000
# SUM/104                                                  0.520516  0.518007
# SUM Neg                                                  0.220027  0.211612
# TOTAL                                                    0.519543  0.515909
# Education_Access_Score                                   0.506888  0.496392
#
#                                                      SUM/104   SUM Neg  \
# Victims_per_1000_population                        -0.441590 -0.363597
# Factor One Governance Issues                       -0.794816 -0.483502
# Factor Two Nourishment and Access                  -0.563055 -0.324523
# Factor Three Inequality                            -0.298557 -0.221779
# Factor Four Disenfranchised Groups                 -0.352921 -0.139008
# Factor Five Effects of Conflict                    -0.228068 -0.390164
# Final overall (normalised, weighted) vulnerabil... -0.729949 -0.484311
# Support survivors                                   0.897757  0.340910
# %                                                   0.898056  0.339491
# Criminal justice                                    0.863833  0.290865
# %.1                                                 0.865420  0.287794
# Coordination                                        0.763327  0.344662
# %.2                                                 0.763514  0.342592
# NEG Government  complicity (1.4.3)                  0.343359  0.866136
# NEG State-imposed forced labour (1.8.1)             0.210349  0.635848
# Address risk                                        0.805265  0.292507
# %.3                                                 0.804930  0.291397
# Supply chains                                       0.520516  0.220027
# %.4                                                 0.518007  0.211612
# SUM/104                                             1.000000  0.375285
# SUM Neg                                             0.375285  1.000000
# TOTAL                                               0.991451  0.492506
# Education_Access_Score                              0.657073  0.314247
#
#                                                        TOTAL  \
# Victims_per_1000_population                        -0.465029
# Factor One Governance Issues                       -0.814466
# Factor Two Nourishment and Access                  -0.575496
# Factor Three Inequality                            -0.312195
# Factor Four Disenfranchised Groups                 -0.351394
# Factor Five Effects of Conflict                    -0.268848
# Final overall (normalised, weighted) vulnerabil... -0.754005
# Support survivors                                   0.890594
# %                                                   0.890667
# Criminal justice                                    0.852355
# %.1                                                 0.853403
# Coordination                                        0.765316
# %.2                                                 0.765159
# NEG Government  complicity (1.4.3)                  0.444153
# NEG State-imposed forced labour (1.8.1)             0.286018
# Address risk                                        0.796952
# %.3                                                 0.796452
# Supply chains                                       0.519543
# %.4                                                 0.515909
# SUM/104                                             0.991451
# SUM Neg                                             0.492506
# TOTAL                                               1.000000
# Education_Access_Score                              0.662586
#
#                                                     Education_Access_Score
# Victims_per_1000_population                                      -0.416617
# Factor One Governance Issues                                     -0.733245
# Factor Two Nourishment and Access                                -0.779522
# Factor Three Inequality                                          -0.485061
# Factor Four Disenfranchised Groups                               -0.449591
# Factor Five Effects of Conflict                                  -0.410084
# Final overall (normalised, weighted) vulnerabil...               -0.804421
# Support survivors                                                 0.595888
# %                                                                 0.596111
# Criminal justice                                                  0.544045
# %.1                                                               0.543130
# Coordination                                                      0.452691
# %.2                                                               0.452608
# NEG Government  complicity (1.4.3)                                0.339317
# NEG State-imposed forced labour (1.8.1)                           0.096140
# Address risk                                                      0.559672
# %.3                                                               0.556106
# Supply chains                                                     0.506888
# %.4                                                               0.496392
# SUM/104                                                           0.657073
# SUM Neg                                                           0.314247
# TOTAL                                                             0.662586
# Education_Access_Score                                            1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# ## 4.2 Plots

# %% [markdown]
# ### Scatter plot

# %%
ax = sns.scatterplot(data=merged,
                x="Education_Access_Score",
                y="Victims_per_1000_population");

# %% [markdown]
# ### Regplot

# %%
ax= sns.regplot(data=merged,
                x="Education_Access_Score",
                y="Victims_per_1000_population");

# %% [markdown]
# ## 4.3 Drop `null` values

# %%
merged_new= merged[["Education_Access_Score", "Victims_per_1000_population"]].copy()
merged_new.dropna(inplace=True)

# %% [markdown]
# ## 4.4 OLS Regression Results

# %%
x = sm.add_constant(merged_new.Education_Access_Score)
model = sm.OLS(merged_new.Victims_per_1000_population,x)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.174
# Model:                                     OLS   Adj. R-squared:                  0.168
# Method:                          Least Squares   F-statistic:                     31.29
# Date:                         Mon, 13 Jul 2020   Prob (F-statistic):           1.03e-07
# Time:                                 00:49:37   Log-Likelihood:                -524.90
# No. Observations:                          151   AIC:                             1054.
# Df Residuals:                              149   BIC:                             1060.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     18.0953      2.291      7.900      0.000      13.569      22.621
# Education_Access_Score   -19.9532      3.567     -5.594      0.000     -27.001     -12.905
# ==============================================================================
# Omnibus:                      249.117   Durbin-Watson:                   0.601
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31182.481
# Skew:                           7.292   Prob(JB):                         0.00
# Kurtosis:                      71.873   Cond. No.                         7.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 5. 2nd Model

# %% [markdown]
# ## 5.1 Education DataFrame
# ### New Data Frame with `Country` and `HDI Rank` in the columns

# %%
hdidf= education[["Country","HDI Rank"]].copy()

# Remove special characters from rows
hdidf= hdidf.replace("..", np.nan)

# Remove missing values
hdidf.dropna(inplace=True)

print(hdidf, hdidf.dtypes)
# Out:
#                                 Country  HDI Rank
# 0                           Afghanistan     169.0
# 1                               Albania      95.0
# 2                               Algeria      93.0
# 3                               Andorra      37.0
# 4                                Angola     149.0
# ..                                  ...       ...
# 190  Venezuela (Bolivarian Republic of)      67.0
# 191                             Vietnam     121.0
# 192                               Yemen     154.0
# 193                              Zambia     141.0
# 194                            Zimbabwe     156.0
#
# [187 rows x 2 columns] Country      object
# HDI Rank    float64
# dtype: object

# %%
# Rename column
hdidf.rename(columns={"HDI Rank": "HDI_Rank"}, inplace=True)

# %% [markdown]
# ## 5.2 Merging Tables

# %% [markdown]
# ## `slavery_index` table with `hdidf` table

# %%
merge_2= pd.merge(slavery_index, hdidf, on="Country" )
merge_2
# Out:
#                               Country total_population  \
# 0                             Eritrea        4,847,000
# 1                             Burundi       10,199,000
# 2            Central African Republic        4,546,000
# 3                         Afghanistan       33,736,000
# 4                          Mauritania        4,182,000
# ..                                ...              ...
# 163                       Saint Lucia          177,000
# 164                             Malta          428,000
# 165  Saint Vincent and the Grenadines          109,000
# 166                           Vanuatu          265,000
# 167                        Seychelles           94,000
#
#                       Region  Victims_per_1000_population  \
# 0                     Africa                         93.0
# 1                     Africa                         40.0
# 2                     Africa                         22.3
# 3       Asia and the Pacific                         22.2
# 4                     Africa                         21.4
# ..                       ...                          ...
# 163                 Americas                          NaN
# 164  Europe and Central Asia                          NaN
# 165                 Americas                          NaN
# 166     Asia and the Pacific                          NaN
# 167                   Africa                          NaN
#
#     Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                   451,000                          71.0
# 1                                   408,000                          72.4
# 2                                   101,000                          85.4
# 3                                   749,000                          81.0
# 4                                    90,000                          67.3
# ..                                      ...                           ...
# 163                                     NaN                           NaN
# 164                                     NaN                           NaN
# 165                                     NaN                           NaN
# 166                                     NaN                           NaN
# 167                                     NaN                           NaN
#
#      Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                                 50.6                     33.7
# 1                                 42.6                     42.1
# 2                                 50.2                     62.7
# 3                                 41.3                     64.7
# 4                                 33.7                     39.3
# ..                                 ...                      ...
# 163                                NaN                      NaN
# 164                                NaN                      NaN
# 165                                NaN                      NaN
# 166                                NaN                      NaN
# 167                                NaN                      NaN
#
#      Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                  48.1                             25.9  ...
# 1                                  48.1                             41.7  ...
# 2                                  58.0                             81.6  ...
# 3                                  46.0                             92.6  ...
# 4                                  50.5                             22.3  ...
# ..                                  ...                              ...  ...
# 163                                 NaN                              NaN  ...
# 164                                 NaN                              NaN  ...
# 165                                 NaN                              NaN  ...
# 166                                 NaN                              NaN  ...
# 167                                 NaN                              NaN  ...
#
#      NEG State-imposed forced labour (1.8.1)  Address risk   %.3  \
# 0                                       -1.0           1.5  21.4
# 1                                       -1.0           1.8  26.2
# 2                                        0.0           1.5  21.4
# 3                                        NaN           NaN   NaN
# 4                                        0.0           2.5  35.7
# ..                                       ...           ...   ...
# 163                                      NaN           NaN   NaN
# 164                                      NaN           NaN   NaN
# 165                                      NaN           NaN   NaN
# 166                                      NaN           NaN   NaN
# 167                                      NaN           NaN   NaN
#
#      Supply chains  %.4  SUM/104  SUM Neg  TOTAL  Credit rating  HDI_Rank
# 0              0.0  0.0      1.4     -2.0   -2.0              D     182.0
# 1              0.0  0.0      5.0     -2.0   10.7              C     180.0
# 2              0.0  0.0      1.7     -1.0    2.5              D     185.0
# 3              NaN  NaN      NaN      NaN    NaN            NaN     169.0
# 4              0.0  0.0      5.3     -1.0   15.5              C     161.0
# ..             ...  ...      ...      ...    ...            ...       ...
# 163            NaN  NaN      NaN      NaN    NaN            NaN      97.0
# 164            NaN  NaN      NaN      NaN    NaN            NaN      39.0
# 165            NaN  NaN      NaN      NaN    NaN            NaN      91.0
# 166            NaN  NaN      NaN      NaN    NaN            NaN     131.0
# 167            NaN  NaN      NaN      NaN    NaN            NaN      71.0
#
# [168 rows x 28 columns]

# %% [markdown]
# ## 5.3 Correlations between `merge_2` table

# %%
merge_2.corr()
# Out:
#                                                     Victims_per_1000_population  \
# Victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.379444
# Factor Two Nourishment and Access                                      0.423225
# Factor Three Inequality                                                0.111686
# Factor Four Disenfranchised Groups                                     0.294802
# Factor Five Effects of Conflict                                        0.197003
# Final overall (normalised, weighted) vulnerabil...                     0.406846
# Support survivors                                                     -0.377257
# %                                                                     -0.376439
# Criminal justice                                                      -0.392226
# %.1                                                                   -0.391494
# Coordination                                                          -0.365449
# %.2                                                                   -0.364524
# NEG Government  complicity (1.4.3)                                    -0.234737
# NEG State-imposed forced labour (1.8.1)                               -0.355021
# Address risk                                                          -0.370284
# %.3                                                                   -0.369202
# Supply chains                                                         -0.159504
# %.4                                                                   -0.157498
# SUM/104                                                               -0.441590
# SUM Neg                                                               -0.363597
# TOTAL                                                                 -0.465029
# HDI_Rank                                                               0.393452
#
#                                                     Factor One Governance Issues  \
# Victims_per_1000_population                                             0.379444
# Factor One Governance Issues                                            1.000000
# Factor Two Nourishment and Access                                       0.595208
# Factor Three Inequality                                                 0.502648
# Factor Four Disenfranchised Groups                                      0.468657
# Factor Five Effects of Conflict                                         0.460542
# Final overall (normalised, weighted) vulnerabil...                      0.929781
# Support survivors                                                      -0.718463
# %                                                                      -0.719307
# Criminal justice                                                       -0.643288
# %.1                                                                    -0.644600
# Coordination                                                           -0.593959
# %.2                                                                    -0.594188
# NEG Government  complicity (1.4.3)                                     -0.444631
# NEG State-imposed forced labour (1.8.1)                                -0.267512
# Address risk                                                           -0.658122
# %.3                                                                    -0.656610
# Supply chains                                                          -0.573796
# %.4                                                                    -0.561784
# SUM/104                                                                -0.794816
# SUM Neg                                                                -0.483502
# TOTAL                                                                  -0.814466
# HDI_Rank                                                                0.748468
#
#                                                     Factor Two Nourishment and Access  \
# Victims_per_1000_population                                                  0.423225
# Factor One Governance Issues                                                 0.595208
# Factor Two Nourishment and Access                                            1.000000
# Factor Three Inequality                                                      0.374382
# Factor Four Disenfranchised Groups                                           0.416182
# Factor Five Effects of Conflict                                              0.327446
# Final overall (normalised, weighted) vulnerabil...                           0.736855
# Support survivors                                                           -0.481210
# %                                                                           -0.480159
# Criminal justice                                                            -0.439673
# %.1                                                                         -0.439634
# Coordination                                                                -0.440369
# %.2                                                                         -0.442043
# NEG Government  complicity (1.4.3)                                          -0.345587
# NEG State-imposed forced labour (1.8.1)                                     -0.106736
# Address risk                                                                -0.523452
# %.3                                                                         -0.518601
# Supply chains                                                               -0.395159
# %.4                                                                         -0.385736
# SUM/104                                                                     -0.563055
# SUM Neg                                                                     -0.324523
# TOTAL                                                                       -0.575496
# HDI_Rank                                                                     0.816940
#
#                                                     Factor Three Inequality  \
# Victims_per_1000_population                                        0.111686
# Factor One Governance Issues                                       0.502648
# Factor Two Nourishment and Access                                  0.374382
# Factor Three Inequality                                            1.000000
# Factor Four Disenfranchised Groups                                 0.436054
# Factor Five Effects of Conflict                                    0.372882
# Final overall (normalised, weighted) vulnerabil...                 0.649680
# Support survivors                                                 -0.278501
# %                                                                 -0.280180
# Criminal justice                                                  -0.251601
# %.1                                                               -0.250351
# Coordination                                                      -0.271686
# %.2                                                               -0.268109
# NEG Government  complicity (1.4.3)                                -0.284602
# NEG State-imposed forced labour (1.8.1)                            0.001839
# Address risk                                                      -0.182037
# %.3                                                               -0.179726
# Supply chains                                                     -0.318625
# %.4                                                               -0.303547
# SUM/104                                                           -0.298557
# SUM Neg                                                           -0.221779
# TOTAL                                                             -0.312195
# HDI_Rank                                                           0.534871
#
#                                                     Factor Four Disenfranchised Groups  \
# Victims_per_1000_population                                                   0.294802
# Factor One Governance Issues                                                  0.468657
# Factor Two Nourishment and Access                                             0.416182
# Factor Three Inequality                                                       0.436054
# Factor Four Disenfranchised Groups                                            1.000000
# Factor Five Effects of Conflict                                               0.232622
# Final overall (normalised, weighted) vulnerabil...                            0.613947
# Support survivors                                                            -0.289656
# %                                                                            -0.289535
# Criminal justice                                                             -0.312353
# %.1                                                                          -0.314049
# Coordination                                                                 -0.274764
# %.2                                                                          -0.278307
# NEG Government  complicity (1.4.3)                                           -0.151045
# NEG State-imposed forced labour (1.8.1)                                      -0.041067
# Address risk                                                                 -0.301425
# %.3                                                                          -0.297696
# Supply chains                                                                -0.269741
# %.4                                                                          -0.279464
# SUM/104                                                                      -0.352921
# SUM Neg                                                                      -0.139008
# TOTAL                                                                        -0.351394
# HDI_Rank                                                                      0.526088
#
#                                                     Factor Five Effects of Conflict  \
# Victims_per_1000_population                                                0.197003
# Factor One Governance Issues                                               0.460542
# Factor Two Nourishment and Access                                          0.327446
# Factor Three Inequality                                                    0.372882
# Factor Four Disenfranchised Groups                                         0.232622
# Factor Five Effects of Conflict                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                         0.630298
# Support survivors                                                         -0.211623
# %                                                                         -0.211027
# Criminal justice                                                          -0.147979
# %.1                                                                       -0.145110
# Coordination                                                              -0.111431
# %.2                                                                       -0.106631
# NEG Government  complicity (1.4.3)                                        -0.360252
# NEG State-imposed forced labour (1.8.1)                                   -0.213621
# Address risk                                                              -0.254158
# %.3                                                                       -0.253146
# Supply chains                                                             -0.217195
# %.4                                                                       -0.206653
# SUM/104                                                                   -0.228068
# SUM Neg                                                                   -0.390164
# TOTAL                                                                     -0.268848
# HDI_Rank                                                                   0.384580
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# Victims_per_1000_population                                                                  0.406846
# Factor One Governance Issues                                                                 0.929781
# Factor Two Nourishment and Access                                                            0.736855
# Factor Three Inequality                                                                      0.649680
# Factor Four Disenfranchised Groups                                                           0.613947
# Factor Five Effects of Conflict                                                              0.630298
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# Support survivors                                                                           -0.651196
# %                                                                                           -0.651541
# Criminal justice                                                                            -0.585350
# %.1                                                                                         -0.585601
# Coordination                                                                                -0.546765
# %.2                                                                                         -0.546344
# NEG Government  complicity (1.4.3)                                                          -0.471877
# NEG State-imposed forced labour (1.8.1)                                                     -0.227035
# Address risk                                                                                -0.622873
# %.3                                                                                         -0.619768
# Supply chains                                                                               -0.551788
# %.4                                                                                         -0.539987
# SUM/104                                                                                     -0.729949
# SUM Neg                                                                                     -0.484311
# TOTAL                                                                                       -0.754005
# HDI_Rank                                                                                     0.834111
#
#                                                     Support survivors  \
# Victims_per_1000_population                                 -0.377257
# Factor One Governance Issues                                -0.718463
# Factor Two Nourishment and Access                           -0.481210
# Factor Three Inequality                                     -0.278501
# Factor Four Disenfranchised Groups                          -0.289656
# Factor Five Effects of Conflict                             -0.211623
# Final overall (normalised, weighted) vulnerabil...          -0.651196
# Support survivors                                            1.000000
# %                                                            0.999876
# Criminal justice                                             0.710247
# %.1                                                          0.712385
# Coordination                                                 0.577469
# %.2                                                          0.576801
# NEG Government  complicity (1.4.3)                           0.315491
# NEG State-imposed forced labour (1.8.1)                      0.185547
# Address risk                                                 0.571494
# %.3                                                          0.570977
# Supply chains                                                0.423228
# %.4                                                          0.422001
# SUM/104                                                      0.897757
# SUM Neg                                                      0.340910
# TOTAL                                                        0.890594
# HDI_Rank                                                    -0.582376
#
#                                                            %  \
# Victims_per_1000_population                        -0.376439
# Factor One Governance Issues                       -0.719307
# Factor Two Nourishment and Access                  -0.480159
# Factor Three Inequality                            -0.280180
# Factor Four Disenfranchised Groups                 -0.289535
# Factor Five Effects of Conflict                    -0.211027
# Final overall (normalised, weighted) vulnerabil... -0.651541
# Support survivors                                   0.999876
# %                                                   1.000000
# Criminal justice                                    0.710026
# %.1                                                 0.712154
# Coordination                                        0.577449
# %.2                                                 0.576822
# NEG Government  complicity (1.4.3)                  0.315203
# NEG State-imposed forced labour (1.8.1)             0.183192
# Address risk                                        0.572400
# %.3                                                 0.571926
# Supply chains                                       0.424052
# %.4                                                 0.422626
# SUM/104                                             0.898056
# SUM Neg                                             0.339491
# TOTAL                                               0.890667
# HDI_Rank                                           -0.582441
#
#                                                     Criminal justice  ...  \
# Victims_per_1000_population                                -0.392226  ...
# Factor One Governance Issues                               -0.643288  ...
# Factor Two Nourishment and Access                          -0.439673  ...
# Factor Three Inequality                                    -0.251601  ...
# Factor Four Disenfranchised Groups                         -0.312353  ...
# Factor Five Effects of Conflict                            -0.147979  ...
# Final overall (normalised, weighted) vulnerabil...         -0.585350  ...
# Support survivors                                           0.710247  ...
# %                                                           0.710026  ...
# Criminal justice                                            1.000000  ...
# %.1                                                         0.999653  ...
# Coordination                                                0.586818  ...
# %.2                                                         0.586714  ...
# NEG Government  complicity (1.4.3)                          0.221510  ...
# NEG State-imposed forced labour (1.8.1)                     0.231919  ...
# Address risk                                                0.612633  ...
# %.3                                                         0.612278  ...
# Supply chains                                               0.392304  ...
# %.4                                                         0.390696  ...
# SUM/104                                                     0.863833  ...
# SUM Neg                                                     0.290865  ...
# TOTAL                                                       0.852355  ...
# HDI_Rank                                                   -0.509307  ...
#
#                                                     NEG Government  complicity (1.4.3)  \
# Victims_per_1000_population                                                  -0.234737
# Factor One Governance Issues                                                 -0.444631
# Factor Two Nourishment and Access                                            -0.345587
# Factor Three Inequality                                                      -0.284602
# Factor Four Disenfranchised Groups                                           -0.151045
# Factor Five Effects of Conflict                                              -0.360252
# Final overall (normalised, weighted) vulnerabil...                           -0.471877
# Support survivors                                                             0.315491
# %                                                                             0.315203
# Criminal justice                                                              0.221510
# %.1                                                                           0.218370
# Coordination                                                                  0.333867
# %.2                                                                           0.331330
# NEG Government  complicity (1.4.3)                                            1.000000
# NEG State-imposed forced labour (1.8.1)                                       0.164971
# Address risk                                                                  0.278687
# %.3                                                                           0.277820
# Supply chains                                                                 0.285842
# %.4                                                                           0.277685
# SUM/104                                                                       0.343359
# SUM Neg                                                                       0.866136
# TOTAL                                                                         0.444153
# HDI_Rank                                                                     -0.358483
#
#                                                     NEG State-imposed forced labour (1.8.1)  \
# Victims_per_1000_population                                                       -0.355021
# Factor One Governance Issues                                                      -0.267512
# Factor Two Nourishment and Access                                                 -0.106736
# Factor Three Inequality                                                            0.001839
# Factor Four Disenfranchised Groups                                                -0.041067
# Factor Five Effects of Conflict                                                   -0.213621
# Final overall (normalised, weighted) vulnerabil...                                -0.227035
# Support survivors                                                                  0.185547
# %                                                                                  0.183192
# Criminal justice                                                                   0.231919
# %.1                                                                                0.230707
# Coordination                                                                       0.164576
# %.2                                                                                0.164407
# NEG Government  complicity (1.4.3)                                                 0.164971
# NEG State-imposed forced labour (1.8.1)                                            1.000000
# Address risk                                                                       0.146865
# %.3                                                                                0.146013
# Supply chains                                                                     -0.007212
# %.4                                                                               -0.011222
# SUM/104                                                                            0.210349
# SUM Neg                                                                            0.635848
# TOTAL                                                                              0.286018
# HDI_Rank                                                                          -0.139441
#
#                                                     Address risk       %.3  \
# Victims_per_1000_population                            -0.370284 -0.369202
# Factor One Governance Issues                           -0.658122 -0.656610
# Factor Two Nourishment and Access                      -0.523452 -0.518601
# Factor Three Inequality                                -0.182037 -0.179726
# Factor Four Disenfranchised Groups                     -0.301425 -0.297696
# Factor Five Effects of Conflict                        -0.254158 -0.253146
# Final overall (normalised, weighted) vulnerabil...     -0.622873 -0.619768
# Support survivors                                       0.571494  0.570977
# %                                                       0.572400  0.571926
# Criminal justice                                        0.612633  0.612278
# %.1                                                     0.613075  0.612731
# Coordination                                            0.561575  0.561523
# %.2                                                     0.562687  0.562642
# NEG Government  complicity (1.4.3)                      0.278687  0.277820
# NEG State-imposed forced labour (1.8.1)                 0.146865  0.146013
# Address risk                                            1.000000  0.999745
# %.3                                                     0.999745  1.000000
# Supply chains                                           0.372106  0.369387
# %.4                                                     0.371305  0.368495
# SUM/104                                                 0.805265  0.804930
# SUM Neg                                                 0.292507  0.291397
# TOTAL                                                   0.796952  0.796452
# HDI_Rank                                               -0.512684 -0.508240
#
#                                                     Supply chains       %.4  \
# Victims_per_1000_population                             -0.159504 -0.157498
# Factor One Governance Issues                            -0.573796 -0.561784
# Factor Two Nourishment and Access                       -0.395159 -0.385736
# Factor Three Inequality                                 -0.318625 -0.303547
# Factor Four Disenfranchised Groups                      -0.269741 -0.279464
# Factor Five Effects of Conflict                         -0.217195 -0.206653
# Final overall (normalised, weighted) vulnerabil...      -0.551788 -0.539987
# Support survivors                                        0.423228  0.422001
# %                                                        0.424052  0.422626
# Criminal justice                                         0.392304  0.390696
# %.1                                                      0.393951  0.392812
# Coordination                                             0.464809  0.456012
# %.2                                                      0.464161  0.455811
# NEG Government  complicity (1.4.3)                       0.285842  0.277685
# NEG State-imposed forced labour (1.8.1)                 -0.007212 -0.011222
# Address risk                                             0.372106  0.371305
# %.3                                                      0.369387  0.368495
# Supply chains                                            1.000000  0.997488
# %.4                                                      0.997488  1.000000
# SUM/104                                                  0.520516  0.518007
# SUM Neg                                                  0.220027  0.211612
# TOTAL                                                    0.519543  0.515909
# HDI_Rank                                                -0.514157 -0.504536
#
#                                                      SUM/104   SUM Neg  \
# Victims_per_1000_population                        -0.441590 -0.363597
# Factor One Governance Issues                       -0.794816 -0.483502
# Factor Two Nourishment and Access                  -0.563055 -0.324523
# Factor Three Inequality                            -0.298557 -0.221779
# Factor Four Disenfranchised Groups                 -0.352921 -0.139008
# Factor Five Effects of Conflict                    -0.228068 -0.390164
# Final overall (normalised, weighted) vulnerabil... -0.729949 -0.484311
# Support survivors                                   0.897757  0.340910
# %                                                   0.898056  0.339491
# Criminal justice                                    0.863833  0.290865
# %.1                                                 0.865420  0.287794
# Coordination                                        0.763327  0.344662
# %.2                                                 0.763514  0.342592
# NEG Government  complicity (1.4.3)                  0.343359  0.866136
# NEG State-imposed forced labour (1.8.1)             0.210349  0.635848
# Address risk                                        0.805265  0.292507
# %.3                                                 0.804930  0.291397
# Supply chains                                       0.520516  0.220027
# %.4                                                 0.518007  0.211612
# SUM/104                                             1.000000  0.375285
# SUM Neg                                             0.375285  1.000000
# TOTAL                                               0.991451  0.492506
# HDI_Rank                                           -0.620846 -0.351188
#
#                                                        TOTAL  HDI_Rank
# Victims_per_1000_population                        -0.465029  0.393452
# Factor One Governance Issues                       -0.814466  0.748468
# Factor Two Nourishment and Access                  -0.575496  0.816940
# Factor Three Inequality                            -0.312195  0.534871
# Factor Four Disenfranchised Groups                 -0.351394  0.526088
# Factor Five Effects of Conflict                    -0.268848  0.384580
# Final overall (normalised, weighted) vulnerabil... -0.754005  0.834111
# Support survivors                                   0.890594 -0.582376
# %                                                   0.890667 -0.582441
# Criminal justice                                    0.852355 -0.509307
# %.1                                                 0.853403 -0.509229
# Coordination                                        0.765316 -0.405059
# %.2                                                 0.765159 -0.405771
# NEG Government  complicity (1.4.3)                  0.444153 -0.358483
# NEG State-imposed forced labour (1.8.1)             0.286018 -0.139441
# Address risk                                        0.796952 -0.512684
# %.3                                                 0.796452 -0.508240
# Supply chains                                       0.519543 -0.514157
# %.4                                                 0.515909 -0.504536
# SUM/104                                             0.991451 -0.620846
# SUM Neg                                             0.492506 -0.351188
# TOTAL                                               1.000000 -0.633602
# HDI_Rank                                           -0.633602  1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# ## 5.4 Plots

# %%
ax = sns.scatterplot(data=merge_2,
                x="HDI_Rank",
                y="Victims_per_1000_population");

# %%
ax= sns.regplot(data=merge_2,
                x="HDI_Rank",
                y="Victims_per_1000_population");

# %%
merged_n= merge_2[["HDI_Rank", "Victims_per_1000_population"]].copy()

# Remove missing values
merged_n.dropna(inplace=True)
merged_n.head()
# Out:
#    HDI_Rank  Victims_per_1000_population
# 0     182.0                         93.0
# 1     180.0                         40.0
# 2     185.0                         22.3
# 3     169.0                         22.2
# 4     161.0                         21.4

# %% [markdown]
# ## 5.5 OLS Regression Model

# %%
x = sm.add_constant(merged_n.HDI_Rank)
model = sm.OLS(merged_n.Victims_per_1000_population,x)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.155
# Model:                                     OLS   Adj. R-squared:                  0.149
# Method:                          Least Squares   F-statistic:                     27.29
# Date:                         Mon, 13 Jul 2020   Prob (F-statistic):           5.80e-07
# Time:                                 00:49:39   Log-Likelihood:                -526.60
# No. Observations:                          151   AIC:                             1057.
# Df Residuals:                              149   BIC:                             1063.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1769      1.256      0.141      0.888      -2.304       2.658
# HDI_Rank       0.0602      0.012      5.224      0.000       0.037       0.083
# ==============================================================================
# Omnibus:                      257.061   Durbin-Watson:                   0.527
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36155.445
# Skew:                           7.698   Prob(JB):                         0.00
# Kurtosis:                      77.226   Cond. No.                         211.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 6. 3rd Model

# %% [markdown]
# ## 6.1 Access to Education DataFrame

# %%
education_df= education[["HDI Rank","Country","2013"]].copy()

# %% [markdown]
# # 6.2 Clean the DataFrame

# %%
# Replace special characters
education_df= education_df.replace("..", np.nan)

# Remove missing values
education_df.dropna(inplace=True)

# Replace special characters and convert series into floats
education_df["2013"]= education_df["2013"].str.replace(',','.')
education_df=education_df.astype({"HDI Rank":float, "2013" :float})

#Rename columns
education_df.rename(columns={"HDI Rank": "HDI_Rank","2013": "Education_Access_Score"}, inplace=True)

education_df, education_df.dtypes
# Out:
# (     HDI_Rank                             Country  Education_Access_Score
#  0       169.0                         Afghanistan                0.365333
#  1        95.0                             Albania                0.608519
#  2        93.0                             Algeria                0.642589
#  3        37.0                             Andorra                0.670287
#  4       149.0                              Angola                0.474212
#  ..        ...                                 ...                     ...
#  190      67.0  Venezuela (Bolivarian Republic of)                0.682483
#  191     121.0                             Vietnam                0.513489
#  192     154.0                               Yemen                0.339222
#  193     141.0                              Zambia                0.591333
#  194     156.0                            Zimbabwe                0.499933
#
#  [187 rows x 3 columns],
#  HDI_Rank                  float64
#  Country                    object
#  Education_Access_Score    float64
#  dtype: object)

# %% [markdown]
# ## 6.3 Clean the Slavery index DataFrame

# %%
slavery_index.rename(columns={"Population \n(from United Nations Population Division, World Population Prospects)": "total_population"}, inplace=True)
slavery_index['total_population'] = slavery_index['total_population'].astype('str') 
slavery_index['total_population']=slavery_index['total_population'].str.replace(',','')
slavery_index=slavery_index.astype({"total_population" :float})

# %%
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].astype('str')
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace(",","")
slavery_index["Est. number of people in modern slavery"] = slavery_index["Est. number of people in modern slavery"].str.replace("<","")
slavery_index=slavery_index.astype({"Est. number of people in modern slavery" :float})
slavery_index.head()
# Out:
#                                   Country  total_population  \
# 0  Korea, Democratic People's Republic of        25244000.0
# 1                                 Eritrea         4847000.0
# 2                                 Burundi        10199000.0
# 3                Central African Republic         4546000.0
# 4                             Afghanistan        33736000.0
#
#                  Region  Victims_per_1000_population  \
# 0  Asia and the Pacific                        104.6
# 1                Africa                         93.0
# 2                Africa                         40.0
# 3                Africa                         22.3
# 4  Asia and the Pacific                         22.2
#
#    Est. number of people in modern slavery  Factor One Governance Issues  \
# 0                                2640000.0                          87.6
# 1                                 451000.0                          71.0
# 2                                 408000.0                          72.4
# 3                                 101000.0                          85.4
# 4                                 749000.0                          81.0
#
#    Factor Two Nourishment and Access  Factor Three Inequality  \
# 0                               52.0                     30.3
# 1                               50.6                     33.7
# 2                               42.6                     42.1
# 3                               50.2                     62.7
# 4                               41.3                     64.7
#
#    Factor Four Disenfranchised Groups  Factor Five Effects of Conflict  ...  \
# 0                                32.4                             12.3  ...
# 1                                48.1                             25.9  ...
# 2                                48.1                             41.7  ...
# 3                                58.0                             81.6  ...
# 4                                46.0                             92.6  ...
#
#    NEG Government  complicity (1.4.3)  \
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
# 3                                -1.0
# 4                                 NaN
#
#    NEG State-imposed forced labour (1.8.1)  Address risk   %.3  Supply chains  \
# 0                                     -1.0           0.3   4.8            0.0
# 1                                     -1.0           1.5  21.4            0.0
# 2                                     -1.0           1.8  26.2            0.0
# 3                                      0.0           1.5  21.4            0.0
# 4                                      NaN           NaN   NaN            NaN
#
#    %.4  SUM/104  SUM Neg  TOTAL  Credit rating
# 0  0.0      0.4     -2.0   -5.6              D
# 1  0.0      1.4     -2.0   -2.0              D
# 2  0.0      5.0     -2.0   10.7              C
# 3  0.0      1.7     -1.0    2.5              D
# 4  NaN      NaN      NaN    NaN            NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 6.4 Merge Datasets (Slavery Index, Education)

# %%
# merging both tables
merge_3= pd.merge(slavery_index, education_df, on="Country" )
merge_3.columns
# Out:
# Index(['Country', 'total_population', 'Region', 'Victims_per_1000_population',
#        'Est. number of people in modern slavery',
#        'Factor One Governance Issues', 'Factor Two Nourishment and Access',
#        'Factor Three Inequality', 'Factor Four Disenfranchised Groups',
#        'Factor Five Effects of Conflict',
#        'Final overall (normalised, weighted) vulnerability score',
#        'Support survivors', '%', 'Criminal justice', '%.1', 'Coordination',
#        '%.2', 'NEG Government  complicity (1.4.3)',
#        'NEG State-imposed forced labour (1.8.1)', 'Address risk', '%.3',
#        'Supply chains', '%.4', 'SUM/104', 'SUM Neg', 'TOTAL', 'Credit rating',
#        'HDI_Rank', 'Education_Access_Score'],
#       dtype='object')

# %%
# Remove missing values
merge_3.dropna(inplace=True)

# %% [markdown]
# ## 6.5 Define Regression Function

# %%
def run_regression(df, y_col, X_cols):
    y = df[y_col]
    X = df[X_cols]
    X = sm.add_constant(X)
    
    l = sm.OLS(y, X)
    return l.fit()

# %% [markdown]
# ## 6.6 OLS Regression Model

# %%
y_col = "Victims_per_1000_population"
run_regression(merge_3, y_col, ["Education_Access_Score", "HDI_Rank"]).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.172
# Model:                                     OLS   Adj. R-squared:                  0.160
# Method:                          Least Squares   F-statistic:                     14.95
# Date:                         Mon, 13 Jul 2020   Prob (F-statistic):           1.26e-06
# Time:                                 00:49:41   Log-Likelihood:                -511.24
# No. Observations:                          147   AIC:                             1028.
# Df Residuals:                              144   BIC:                             1037.
# Df Model:                                    2
# Covariance Type:                     nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     19.5619     10.017      1.953      0.053      -0.238      39.362
# Education_Access_Score   -21.5246     11.075     -1.944      0.054     -43.415       0.366
# HDI_Rank                  -0.0053      0.035     -0.150      0.881      -0.075       0.064
# ==============================================================================
# Omnibus:                      245.996   Durbin-Watson:                   0.612
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31169.051
# Skew:                           7.403   Prob(JB):                         0.00
# Kurtosis:                      72.783   Cond. No.                     2.46e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # 7. Load GDP Data into a new Data Frame

# %%
df_gdp = pd.read_csv("../data/gdp_data.csv")
df_gdp.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016          2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.936264e+10  2.019176e+10  1.948438e+10  1.910135e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  9.463542e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527808e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 64 columns]

# %% [markdown]
# ## 7.1 Rename columns names

# %%
df_gdp.rename(columns={"Country Name": "Country", "2017":"gdp_2017"}, inplace=True)

# %%
# Show datatypes
df_gdp.dtypes
# Out:
# Country            object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2015              float64
# 2016              float64
# gdp_2017          float64
# 2018              float64
# 2019              float64
# Length: 64, dtype: object

# %% [markdown]
# ## 7.2 Drop the NaN values

# %%
df_gdp_new = df_gdp[["Country", "gdp_2017"]].copy()
df_gdp_new.dropna(inplace=True)
df_gdp_new.head()
# Out:
#        Country      gdp_2017
# 0        Aruba  3.056425e+09
# 1  Afghanistan  2.019176e+10
# 2       Angola  1.221240e+11
# 3      Albania  1.301969e+10
# 4      Andorra  3.000181e+09

# %% [markdown]
# # 8. 4th Model
# ## Merge 3 Datasets (Education, Slavery Index, GDP)

# %%
merge_4 = pd.merge(merge_3, df_gdp_new, on="Country")

# %% [markdown]
# ## 8.1 Create a new column GDP per Capita

# %%
merge_4['gdp_per_capita'] = merge_4.apply(lambda row: row.gdp_2017 / row.total_population, axis=1)
merge_4.gdp_per_capita = merge_4.gdp_per_capita.round()
merge_4
# Out:
#                       Country  total_population                Region  \
# 0                     Burundi        10199000.0                Africa
# 1    Central African Republic         4546000.0                Africa
# 2                  Mauritania         4182000.0                Africa
# 3                    Pakistan       189381000.0  Asia and the Pacific
# 4                    Cambodia        15518000.0  Asia and the Pacific
# ..                        ...               ...                   ...
# 133                     Chile        17763000.0              Americas
# 134                 Australia        23800000.0  Asia and the Pacific
# 135               New Zealand         4615000.0  Asia and the Pacific
# 136                    Canada        35950000.0              Americas
# 137                     Japan       127975000.0  Asia and the Pacific
#
#      Victims_per_1000_population  Est. number of people in modern slavery  \
# 0                           40.0                                 408000.0
# 1                           22.3                                 101000.0
# 2                           21.4                                  90000.0
# 3                           16.8                                3186000.0
# 4                           16.8                                 261000.0
# ..                           ...                                      ...
# 133                          0.8                                  14000.0
# 134                          0.6                                  15000.0
# 135                          0.6                                   3000.0
# 136                          0.5                                  17000.0
# 137                          0.3                                  37000.0
#
#      Factor One Governance Issues  Factor Two Nourishment and Access  \
# 0                            72.4                               42.6
# 1                            85.4                               50.2
# 2                            67.3                               33.7
# 3                            56.8                               36.2
# 4                            66.3                               38.5
# ..                            ...                                ...
# 133                          28.5                               13.8
# 134                          11.9                               15.7
# 135                          12.2                               18.4
# 136                          16.6                               20.7
# 137                          21.5                               13.1
#
#      Factor Three Inequality  Factor Four Disenfranchised Groups  \
# 0                       42.1                                48.1
# 1                       62.7                                58.0
# 2                       39.3                                50.5
# 3                       45.9                                55.3
# 4                       41.6                                56.7
# ..                       ...                                 ...
# 133                     50.0                                23.5
# 134                     20.7                                12.0
# 135                     16.2                                 7.0
# 136                     20.1                                 9.2
# 137                     15.5                                31.9
#
#      Factor Five Effects of Conflict  ...  Supply chains  %.4  SUM/104  \
# 0                               41.7  ...            0.0  0.0      5.0
# 1                               81.6  ...            0.0  0.0      1.7
# 2                               22.3  ...            0.0  0.0      5.3
# 3                               92.8  ...            0.0  0.0      6.2
# 4                               14.8  ...            0.0  0.0     10.5
# ..                               ...  ...            ...  ...      ...
# 133                             20.3  ...            0.0  0.0     17.5
# 134                             13.0  ...            0.0  0.0     17.9
# 135                              7.0  ...            0.0  0.0     16.1
# 136                             21.5  ...            0.0  0.0     16.4
# 137                             17.8  ...            0.0  0.0     11.3
#
#      SUM Neg  TOTAL  Credit rating  HDI_Rank  Education_Access_Score  \
# 0       -2.0   10.7              C     180.0                0.370089
# 1       -1.0    2.5              D     185.0                0.317867
# 2       -1.0   15.5              C     161.0                0.352278
# 3       -1.0   18.6              C     146.0                0.371667
# 4        0.0   37.6            CCC     136.0                0.495178
# ..       ...    ...            ...       ...                     ...
# 133      0.0   62.3            BBB      41.0                0.745675
# 134      0.0   63.8            BBB       2.0                0.926536
# 135      0.0   57.6             BB       7.0                0.916767
# 136      0.0   58.6             BB       8.0                0.850300
# 137     -1.0   36.6            CCC      17.0                0.808000
#
#          gdp_2017  gdp_per_capita
# 0    3.172292e+09           311.0
# 1    2.072350e+09           456.0
# 2    6.758391e+09          1616.0
# 3    3.045670e+11          1608.0
# 4    2.217720e+10          1429.0
# ..            ...             ...
# 133  2.770450e+11         15597.0
# 134  1.330140e+12         55888.0
# 135  2.054160e+11         44511.0
# 136  1.649880e+12         45894.0
# 137  4.866860e+12         38030.0
#
# [138 rows x 31 columns]

# %% [markdown]
# ## 8.2 Show correlations

# %%
merge_4[["Victims_per_1000_population",
         "Factor One Governance Issues", 
         "HDI_Rank",
         "Factor Three Inequality",
         "Final overall (normalised, weighted) vulnerability score",
         "gdp_per_capita", 
         "Education_Access_Score",
         "Criminal justice"]].corr(method='pearson')
# Out:
#                                                     Victims_per_1000_population  \
# Victims_per_1000_population                                            1.000000
# Factor One Governance Issues                                           0.522369
# HDI_Rank                                                               0.510094
# Factor Three Inequality                                                0.210582
# Final overall (normalised, weighted) vulnerabil...                     0.587627
# gdp_per_capita                                                        -0.380121
# Education_Access_Score                                                -0.486700
# Criminal justice                                                      -0.418467
#
#                                                     Factor One Governance Issues  \
# Victims_per_1000_population                                             0.522369
# Factor One Governance Issues                                            1.000000
# HDI_Rank                                                                0.736616
# Factor Three Inequality                                                 0.471129
# Final overall (normalised, weighted) vulnerabil...                      0.922739
# gdp_per_capita                                                         -0.689256
# Education_Access_Score                                                 -0.720322
# Criminal justice                                                       -0.632332
#
#                                                     HDI_Rank  \
# Victims_per_1000_population                         0.510094
# Factor One Governance Issues                        0.736616
# HDI_Rank                                            1.000000
# Factor Three Inequality                             0.541685
# Final overall (normalised, weighted) vulnerabil...  0.845792
# gdp_per_capita                                     -0.747347
# Education_Access_Score                             -0.945600
# Criminal justice                                   -0.491626
#
#                                                     Factor Three Inequality  \
# Victims_per_1000_population                                        0.210582
# Factor One Governance Issues                                       0.471129
# HDI_Rank                                                           0.541685
# Factor Three Inequality                                            1.000000
# Final overall (normalised, weighted) vulnerabil...                 0.621527
# gdp_per_capita                                                    -0.606970
# Education_Access_Score                                            -0.486627
# Criminal justice                                                  -0.251043
#
#                                                     Final overall (normalised, weighted) vulnerability score  \
# Victims_per_1000_population                                                                  0.587627
# Factor One Governance Issues                                                                 0.922739
# HDI_Rank                                                                                     0.845792
# Factor Three Inequality                                                                      0.621527
# Final overall (normalised, weighted) vulnerabil...                                           1.000000
# gdp_per_capita                                                                              -0.771283
# Education_Access_Score                                                                      -0.810045
# Criminal justice                                                                            -0.570416
#
#                                                     gdp_per_capita  \
# Victims_per_1000_population                              -0.380121
# Factor One Governance Issues                             -0.689256
# HDI_Rank                                                 -0.747347
# Factor Three Inequality                                  -0.606970
# Final overall (normalised, weighted) vulnerabil...       -0.771283
# gdp_per_capita                                            1.000000
# Education_Access_Score                                    0.639031
# Criminal justice                                          0.308439
#
#                                                     Education_Access_Score  \
# Victims_per_1000_population                                      -0.486700
# Factor One Governance Issues                                     -0.720322
# HDI_Rank                                                         -0.945600
# Factor Three Inequality                                          -0.486627
# Final overall (normalised, weighted) vulnerabil...               -0.810045
# gdp_per_capita                                                    0.639031
# Education_Access_Score                                            1.000000
# Criminal justice                                                  0.527980
#
#                                                     Criminal justice
# Victims_per_1000_population                                -0.418467
# Factor One Governance Issues                               -0.632332
# HDI_Rank                                                   -0.491626
# Factor Three Inequality                                    -0.251043
# Final overall (normalised, weighted) vulnerabil...         -0.570416
# gdp_per_capita                                              0.308439
# Education_Access_Score                                      0.527980
# Criminal justice                                            1.000000

# %% [markdown]
# ## 8.3 Plots
# ## Plot 1
# ### Victims /1000 population - Factor Five Effects of Conflict

# %%
ax = sns.scatterplot(data=merge_4,
                x="Factor Five Effects of Conflict",
                y="Victims_per_1000_population");

# %%
ax= sns.regplot(data=merge_4,
                x="Factor Five Effects of Conflict",
                y="Victims_per_1000_population");

# %%
ax= sns.regplot(data=merge_4,
                x="Factor Five Effects of Conflict",
                y="Victims_per_1000_population");

# %% [markdown]
# # Plot 2
# ## Victims /1000 population - Education Access Score

# %%
ax= sns.regplot(data=merge_4,
                x="Education_Access_Score",
                y="Victims_per_1000_population");

# %% [markdown]
# # Plot 3
# ## Victims /1000 population - Criminal justice

# %%
ax= sns.regplot(data=merge_4,
                x="Criminal justice",
                y="Victims_per_1000_population");

# %% [markdown]
# # Plot 4
# ## GDP per Capita - Victims /1000 population

# %%
ax= sns.regplot(data=merge_4,
                x="gdp_per_capita",
                y="Victims_per_1000_population");

# %% [markdown]
# ## 8.4 OLS Regression Model

# %%
#Run regression function
run_regression(merge_4, y_col, ["Factor One Governance Issues", 
                                "HDI_Rank",
                                "Education_Access_Score",
                                "gdp_per_capita"]).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Victims_per_1000_population   R-squared:                       0.314
# Model:                                     OLS   Adj. R-squared:                  0.293
# Method:                          Least Squares   F-statistic:                     15.22
# Date:                         Mon, 13 Jul 2020   Prob (F-statistic):           2.87e-10
# Time:                                 00:49:45   Log-Likelihood:                -386.34
# No. Observations:                          138   AIC:                             782.7
# Df Residuals:                              133   BIC:                             797.3
# Df Model:                                    4
# Covariance Type:                     nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -5.7389      6.562     -0.875      0.383     -18.717       7.240
# Factor One Governance Issues     0.0985      0.031      3.222      0.002       0.038       0.159
# HDI_Rank                         0.0396      0.023      1.728      0.086      -0.006       0.085
# Education_Access_Score           3.5228      6.447      0.546      0.586      -9.229      16.274
# gdp_per_capita                3.189e-05   2.81e-05      1.134      0.259   -2.37e-05    8.75e-05
# ==============================================================================
# Omnibus:                      145.866   Durbin-Watson:                   0.632
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3367.756
# Skew:                           3.745   Prob(JB):                         0.00
# Kurtosis:                      26.013   Cond. No.                     6.90e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
