# %%
import pandas as pd  
import numpy as np  
import matplotlib as plt  
import seaborn 
# %matplotlib inline

# %%
df=pd.read_csv(r'API_KOF')

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 1  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 2  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 3  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 4  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
#
#    1961  1962  1963  1964  1965  ...          2011          2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  4.881564e+08 -3.146927e+08
# 1   NaN   NaN   NaN   NaN   NaN  ...  5.217342e+07  5.682366e+07
# 2   NaN   NaN   NaN   NaN   NaN  ... -3.023771e+09 -1.464628e+09
# ...

# %%
for v in df['Indicator Name']:
    methodology=[]
    methodology.append(v)
    break
print(methodology)
# Out:
# ['Foreign direct investment, net inflows (BoP, current US$)']

# %%
df.drop(columns=['Indicator Name','Indicator Code','Unnamed: 64'])
# Out:
#      Country Name Country Code  1960  1961  1962  1963  1964  1965  1966  \
# 0           Aruba          ABW   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          Angola          AGO   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3         Albania          ALB   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4         Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..            ...          ...   ...   ...   ...   ...   ...   ...   ...
# 259        Kosovo          XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 260   Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 261  South Africa          ZAF   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262        Zambia          ZMB   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263      Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1967  ...          2010          2011          2012          2013  \
# ...

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Unnamed: 64       float64
# Length: 65, dtype: object

# %%
df2=pd.DataFrame(df,columns=['Country Name','Country Code','2017'])

# %%
df2
# Out:
#      Country Name Country Code          2017
# 0           Aruba          ABW  1.624636e+08
# 1     Afghanistan          AFG  5.153390e+07
# 2          Angola          AGO -7.397295e+09
# 3         Albania          ALB  1.022758e+09
# 4         Andorra          AND           NaN
# ..            ...          ...           ...
# 259        Kosovo          XKX  2.868352e+08
# 260   Yemen, Rep.          YEM -2.698500e+08
# 261  South Africa          ZAF  2.058580e+09
# 262        Zambia          ZMB  1.107520e+09
# 263      Zimbabwe          ZWE  2.471877e+08
#
# [264 rows x 3 columns]

# %%
slavery=pd.read_csv(r'..//Data/clean_slavery_index.csv',header=1)

# %%
slav2=(
slavery.rename(columns={
                    'Population \n(from United Nations Population Division, World Population Prospects)':'population',
                    'Est. prevalence of population in modern slavery (victims per 1,000 population)':'est victims per 1,000',
                    'Est. number of people in modern slavery':'est slavery population',
                    'Final overall (normalised, weighted) vulnerability score':'vulnerability score',
                    'Country':'cont',
})
    .dropna()
)

# %%
slav2.head()
# Out:
#                                  Country   population                Region  \
# 0  Korea, Democratic People's Republic of  25,244,000  Asia and the Pacific
# 1                                 Eritrea   4,847,000                Africa
# 2                                 Burundi  10,199,000                Africa
# 3                Central African Republic   4,546,000                Africa
# 5                              Mauritania   4,182,000                Africa
#
#    est victims per 1,000 est slavery population  \
# 0                  104.6              2,640,000
# 1                   93.0                451,000
# 2                   40.0                408,000
# 3                   22.3                101,000
# 5                   21.4                 90,000
#
#    Factor One Governance Issues   Factor Two Nourishment and Access   \
# 0                           87.6                                52.0
# 1                           71.0                                50.6
# ...

# %%
slav2.dtypes
# Out:
# Country                                     object
# population                                  object
# Region                                      object
# est victims per 1,000                      float64
# est slavery population                      object
# Factor One Governance Issues               float64
# Factor Two Nourishment and Access          float64
# Factor Three Inequality                    float64
# Factor Four Disenfranchised Groups         float64
# Factor Five Effects of Conflict            float64
# vulnerability score                        float64
# Support survivors                          float64
# %                                          float64
# Criminal justice                           float64
# %.1                                        float64
# Coordination                               float64
# %.2                                        float64
# NEG Government  complicity (1.4.3)         float64
# ...

# %%
pd.DataFrame(slav2,columns=['population','Region','est victims per 1,000','est slavery population','TOTAL','Credit rating'])
# Out:
#       population                Region  est victims per 1,000  \
# 0     25,244,000  Asia and the Pacific                  104.6
# 1      4,847,000                Africa                   93.0
# 2     10,199,000                Africa                   40.0
# 3      4,546,000                Africa                   22.3
# 5      4,182,000                Africa                   21.4
# ..           ...                   ...                    ...
# 162   23,800,000  Asia and the Pacific                    0.6
# 163    4,615,000  Asia and the Pacific                    0.6
# 164   23,486,000  Asia and the Pacific                    0.5
# 165   35,950,000              Americas                    0.5
# 166  127,975,000  Asia and the Pacific                    0.3
#
#     est slavery population  TOTAL Credit rating
# 0                2,640,000   -5.6             D
# 1                  451,000   -2.0             D
# 2                  408,000   10.7             C
# ...

# %%
slav3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c5888dd1f517> in <module>
# ----> 1 slav3
#
# NameError: name 'slav3' is not defined

# %%
pd.DataFrame(slavery,columns=['Country ','Population \n(from United Nations Population Division, World Population Prospects)','Region','Est. prevalence of population in modern slavery (victims per 1,000 population)'
